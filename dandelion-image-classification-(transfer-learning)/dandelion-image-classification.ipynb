# %% [markdown]
# ## Dandelion Image Classification using Transfer Learning
#
# Given images of grass, let's try to predict whether there are **dandelions** in a given image.
#
# We will use a tensorflow/keras pretrained convolutional neural network to make our predictions.
#
# Data source: https://www.kaggle.com/datasets/coloradokb/dandelionimages

# %% [markdown]
# ### Getting Started

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import tensorflow as tf

from sklearn.metrics import accuracy_score, f1_score
# Out:
# 2024-09-15 12:23:44.871696: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
image_dir = Path("Images")

# %% [markdown]
# ### Creating File DataFrame

# %%
filepaths = list(image_dir.glob(r'**/*.jpg'))
filepaths
# Out:
# [PosixPath('Images/other/IMG_5663.jpg'),
#  PosixPath('Images/other/IMG_5468.jpg'),
#  PosixPath('Images/other/IMG_6262.jpg'),
#  PosixPath('Images/other/IMG_5915.jpg'),
#  PosixPath('Images/other/IMG_6520.jpg'),
#  PosixPath('Images/other/IMG_6158.jpg'),
#  PosixPath('Images/other/IMG_5963.jpg'),
#  PosixPath('Images/other/IMG_5622.jpg'),
#  PosixPath('Images/other/IMG_5824.jpg'),
#  PosixPath('Images/other/IMG_6649.jpg'),
#  PosixPath('Images/other/IMG_6813.jpg'),
#  PosixPath('Images/other/IMG_6251.jpg'),
#  PosixPath('Images/other/IMG_5988.jpg'),
#  PosixPath('Images/other/IMG_5974.jpg'),
#  PosixPath('Images/other/IMG_5880.jpg'),
#  PosixPath('Images/other/IMG_5980.jpg'),
#  PosixPath('Images/other/IMG_6789.jpg'),
#  PosixPath('Images/other/IMG_5955.jpg'),
#  PosixPath('Images/other/IMG_5905.jpg'),
#  PosixPath('Images/other/IMG_5790.jpg'),
#  PosixPath('Images/other/IMG_6811.jpg'),
#  PosixPath('Images/other/IMG_6218.jpg'),
#  PosixPath('Images/other/IMG_6826.jpg'),
#  PosixPath('Images/other/IMG_6804.jpg'),
#  PosixPath('Images/other/IMG_5989.jpg'),
#  PosixPath('Images/other/IMG_5620.jpg'),
#  PosixPath('Images/other/IMG_6285.jpg'),
#  PosixPath('Images/other/IMG_6151.jpg'),
#  PosixPath('Images/other/IMG_5653.jpg'),
#  PosixPath('Images/other/IMG_5816.jpg'),
#  PosixPath('Images/other/IMG_6185.jpg'),
#  PosixPath('Images/other/IMG_5614.jpg'),
#  PosixPath('Images/other/IMG_5493.jpg'),
#  PosixPath('Images/other/IMG_5892.jpg'),
#  PosixPath('Images/other/IMG_5481.jpg'),
#  PosixPath('Images/other/IMG_5819.jpg'),
#  PosixPath('Images/other/IMG_5456.jpg'),
#  PosixPath('Images/other/IMG_5837.jpg'),
#  PosixPath('Images/other/IMG_5998.jpg'),
#  PosixPath('Images/other/IMG_6260.jpg'),
#  PosixPath('Images/other/IMG_5877.jpg'),
#  PosixPath('Images/other/IMG_5471.jpg'),
#  PosixPath('Images/other/IMG_5849.jpg'),
#  PosixPath('Images/other/IMG_5703.jpg'),
#  PosixPath('Images/other/IMG_5490.jpg'),
#  PosixPath('Images/other/IMG_5782.jpg'),
#  PosixPath('Images/other/IMG_6219.jpg'),
#  PosixPath('Images/other/IMG_5804.jpg'),
#  PosixPath('Images/other/IMG_7516.jpg'),
#  PosixPath('Images/other/IMG_5740.jpg'),
#  PosixPath('Images/other/IMG_5765.jpg'),
#  PosixPath('Images/other/IMG_6776.jpg'),
#  PosixPath('Images/other/IMG_6805.jpg'),
#  PosixPath('Images/other/IMG_6815.jpg'),
#  PosixPath('Images/other/IMG_5962.jpg'),
#  PosixPath('Images/other/IMG_7512.jpg'),
#  PosixPath('Images/other/IMG_6018.jpg'),
#  PosixPath('Images/other/IMG_5472.jpg'),
#  PosixPath('Images/other/IMG_6648.jpg'),
#  PosixPath('Images/other/IMG_5668.jpg'),
#  PosixPath('Images/other/IMG_5744.jpg'),
#  PosixPath('Images/other/IMG_5888.jpg'),
#  PosixPath('Images/other/IMG_5613.jpg'),
#  PosixPath('Images/other/IMG_6209.jpg'),
#  PosixPath('Images/other/IMG_5459.jpg'),
#  PosixPath('Images/other/IMG_5887.jpg'),
#  PosixPath('Images/other/IMG_6238.jpg'),
#  PosixPath('Images/other/IMG_6827.jpg'),
#  PosixPath('Images/other/IMG_6653.jpg'),
#  PosixPath('Images/other/IMG_6161.jpg'),
#  PosixPath('Images/other/IMG_5958.jpg'),
#  PosixPath('Images/other/IMG_6034.jpg'),
#  PosixPath('Images/other/IMG_5615.jpg'),
#  PosixPath('Images/other/IMG_6188.jpg'),
#  PosixPath('Images/other/IMG_6163.jpg'),
#  PosixPath('Images/other/IMG_5801.jpg'),
#  PosixPath('Images/other/IMG_5664.jpg'),
#  PosixPath('Images/other/IMG_6799.jpg'),
#  PosixPath('Images/other/IMG_6025.jpg'),
#  PosixPath('Images/other/IMG_6793.jpg'),
#  PosixPath('Images/other/IMG_5792.jpg'),
#  PosixPath('Images/other/IMG_6263.jpg'),
#  PosixPath('Images/other/IMG_6026.jpg'),
#  PosixPath('Images/other/IMG_6273.jpg'),
#  PosixPath('Images/other/IMG_6167.jpg'),
#  PosixPath('Images/other/IMG_5675.jpg'),
#  PosixPath('Images/other/IMG_5785.jpg'),
#  PosixPath('Images/other/IMG_5639.jpg'),
#  PosixPath('Images/other/IMG_6656.jpg'),
#  PosixPath('Images/other/IMG_6243.jpg'),
#  PosixPath('Images/other/IMG_6191.jpg'),
#  PosixPath('Images/other/IMG_6247.jpg'),
#  PosixPath('Images/other/IMG_5713.jpg'),
#  PosixPath('Images/other/IMG_5789.jpg'),
#  PosixPath('Images/other/IMG_5521.jpg'),
#  PosixPath('Images/other/IMG_5951.jpg'),
#  PosixPath('Images/other/IMG_7525.jpg'),
#  PosixPath('Images/other/IMG_5993.jpg'),
#  PosixPath('Images/other/IMG_5711.jpg'),
#  PosixPath('Images/other/IMG_5856.jpg'),
#  PosixPath('Images/other/IMG_5722.jpg'),
#  PosixPath('Images/other/IMG_5978.jpg'),
#  PosixPath('Images/other/IMG_6210.jpg'),
#  PosixPath('Images/other/IMG_6791.jpg'),
#  PosixPath('Images/other/IMG_5996.jpg'),
#  PosixPath('Images/other/IMG_5477.jpg'),
#  PosixPath('Images/other/IMG_6189.jpg'),
#  PosixPath('Images/other/IMG_6283.jpg'),
#  PosixPath('Images/other/IMG_6278.jpg'),
#  PosixPath('Images/other/IMG_5517.jpg'),
#  PosixPath('Images/other/IMG_5999.jpg'),
#  PosixPath('Images/other/IMG_6028.jpg'),
#  PosixPath('Images/other/IMG_5872.jpg'),
#  PosixPath('Images/other/IMG_6775.jpg'),
#  PosixPath('Images/other/IMG_5982.jpg'),
#  PosixPath('Images/other/IMG_5927.jpg'),
#  PosixPath('Images/other/IMG_5512.jpg'),
#  PosixPath('Images/other/IMG_7523.jpg'),
#  PosixPath('Images/other/IMG_5624.jpg'),
#  PosixPath('Images/other/IMG_5818.jpg'),
#  PosixPath('Images/other/IMG_5617.jpg'),
#  PosixPath('Images/other/IMG_5518.jpg'),
#  PosixPath('Images/other/IMG_5991.jpg'),
#  PosixPath('Images/other/IMG_5780.jpg'),
#  PosixPath('Images/other/IMG_6363.jpg'),
#  PosixPath('Images/other/IMG_5805.jpg'),
#  PosixPath('Images/other/IMG_6244.jpg'),
#  PosixPath('Images/other/IMG_5890.jpg'),
#  PosixPath('Images/other/IMG_5889.jpg'),
#  PosixPath('Images/other/IMG_5973.jpg'),
#  PosixPath('Images/other/IMG_5488.jpg'),
#  PosixPath('Images/other/IMG_5611.jpg'),
#  PosixPath('Images/other/IMG_6236.jpg'),
#  PosixPath('Images/other/IMG_6812.jpg'),
#  PosixPath('Images/other/IMG_5829.jpg'),
#  PosixPath('Images/other/IMG_5715.jpg'),
#  PosixPath('Images/other/IMG_5473.jpg'),
#  PosixPath('Images/other/IMG_6001.jpg'),
#  PosixPath('Images/other/IMG_6831.jpg'),
#  PosixPath('Images/other/IMG_6300.jpg'),
#  PosixPath('Images/other/IMG_5489.jpg'),
#  PosixPath('Images/other/IMG_5838.jpg'),
#  PosixPath('Images/other/IMG_5788.jpg'),
#  PosixPath('Images/other/IMG_5922.jpg'),
#  PosixPath('Images/other/IMG_6814.jpg'),
#  PosixPath('Images/other/IMG_5891.jpg'),
#  PosixPath('Images/other/IMG_5867.jpg'),
#  PosixPath('Images/other/IMG_6255.jpg'),
#  PosixPath('Images/other/IMG_5466.jpg'),
#  PosixPath('Images/other/IMG_5791.jpg'),
#  PosixPath('Images/other/IMG_5864.jpg'),
#  PosixPath('Images/other/IMG_5745.jpg'),
#  PosixPath('Images/other/IMG_5693.jpg'),
#  PosixPath('Images/other/IMG_5749.jpg'),
#  PosixPath('Images/other/IMG_6347.jpg'),
#  PosixPath('Images/other/IMG_5968.jpg'),
#  PosixPath('Images/other/IMG_6249.jpg'),
#  PosixPath('Images/other/IMG_5628.jpg'),
#  PosixPath('Images/other/IMG_6020.jpg'),
#  PosixPath('Images/other/IMG_6798.jpg'),
#  PosixPath('Images/other/IMG_5983.jpg'),
#  PosixPath('Images/other/IMG_6786.jpg'),
#  PosixPath('Images/other/IMG_6036.jpg'),
#  PosixPath('Images/other/IMG_5987.jpg'),
#  PosixPath('Images/other/IMG_6237.jpg'),
#  PosixPath('Images/other/IMG_6024.jpg'),
#  PosixPath('Images/other/IMG_5650.jpg'),
#  PosixPath('Images/other/IMG_5884.jpg'),
#  PosixPath('Images/other/IMG_5817.jpg'),
#  PosixPath('Images/other/IMG_5767.jpg'),
#  PosixPath('Images/other/IMG_6259.jpg'),
#  PosixPath('Images/other/IMG_6254.jpg'),
#  PosixPath('Images/other/IMG_6835.jpg'),
#  PosixPath('Images/other/IMG_5665.jpg'),
#  PosixPath('Images/other/IMG_6245.jpg'),
#  PosixPath('Images/other/IMG_5969.jpg'),
#  PosixPath('Images/other/IMG_5470.jpg'),
#  PosixPath('Images/other/IMG_5692.jpg'),
#  PosixPath('Images/other/IMG_5718.jpg'),
#  PosixPath('Images/other/IMG_6842.jpg'),
#  PosixPath('Images/other/IMG_6214.jpg'),
#  PosixPath('Images/other/IMG_5626.jpg'),
#  PosixPath('Images/other/IMG_5970.jpg'),
#  PosixPath('Images/other/IMG_6234.jpg'),
#  PosixPath('Images/other/IMG_5898.jpg'),
#  PosixPath('Images/other/IMG_5752.jpg'),
#  PosixPath('Images/other/IMG_5759.jpg'),
#  PosixPath('Images/other/IMG_6184.jpg'),
#  PosixPath('Images/other/IMG_5971.jpg'),
#  PosixPath('Images/other/IMG_5904.jpg'),
#  PosixPath('Images/other/IMG_5458.jpg'),
#  PosixPath('Images/other/IMG_5874.jpg'),
#  PosixPath('Images/other/IMG_5667.jpg'),
#  PosixPath('Images/other/IMG_5825.jpg'),
#  PosixPath('Images/other/IMG_5868.jpg'),
#  PosixPath('Images/other/IMG_6011.jpg'),
#  PosixPath('Images/other/IMG_6220.jpg'),
#  PosixPath('Images/other/IMG_5977.jpg'),
#  PosixPath('Images/other/IMG_6809.jpg'),
#  PosixPath('Images/other/IMG_5513.jpg'),
#  PosixPath('Images/other/IMG_6787.jpg'),
#  PosixPath('Images/other/IMG_5766.jpg'),
#  PosixPath('Images/other/IMG_5862.jpg'),
#  PosixPath('Images/other/IMG_6800.jpg'),
#  PosixPath('Images/other/IMG_5494.jpg'),
#  PosixPath('Images/other/IMG_5875.jpg'),
#  PosixPath('Images/other/IMG_5831.jpg'),
#  PosixPath('Images/other/IMG_5953.jpg'),
#  PosixPath('Images/other/IMG_5861.jpg'),
#  PosixPath('Images/other/IMG_5800.jpg'),
#  PosixPath('Images/other/IMG_5764.jpg'),
#  PosixPath('Images/other/IMG_6819.jpg'),
#  PosixPath('Images/other/IMG_5461.jpg'),
#  PosixPath('Images/other/IMG_5463.jpg'),
#  PosixPath('Images/other/IMG_6346.jpg'),
#  PosixPath('Images/other/IMG_5691.jpg'),
#  PosixPath('Images/other/IMG_6250.jpg'),
#  PosixPath('Images/other/IMG_5515.jpg'),
#  PosixPath('Images/other/IMG_6297.jpg'),
#  PosixPath('Images/other/IMG_5469.jpg'),
#  PosixPath('Images/other/IMG_5519.jpg'),
#  PosixPath('Images/other/IMG_6652.jpg'),
#  PosixPath('Images/other/IMG_5907.jpg'),
#  PosixPath('Images/other/IMG_6781.jpg'),
#  PosixPath('Images/other/IMG_5834.jpg'),
#  PosixPath('Images/other/IMG_6186.jpg'),
#  PosixPath('Images/other/IMG_5662.jpg'),
#  PosixPath('Images/other/IMG_6014.jpg'),
#  PosixPath('Images/other/IMG_5986.jpg'),
#  PosixPath('Images/other/IMG_6031.jpg'),
#  PosixPath('Images/other/IMG_5863.jpg'),
#  PosixPath('Images/other/IMG_6828.jpg'),
#  PosixPath('Images/other/IMG_5497.jpg'),
#  PosixPath('Images/other/IMG_6838.jpg'),
#  PosixPath('Images/other/IMG_6807.jpg'),
#  PosixPath('Images/other/IMG_6246.jpg'),
#  PosixPath('Images/other/IMG_5514.jpg'),
#  PosixPath('Images/other/IMG_6264.jpg'),
#  PosixPath('Images/other/IMG_5948.jpg'),
#  PosixPath('Images/other/IMG_5779.jpg'),
#  PosixPath('Images/other/IMG_5920.jpg'),
#  PosixPath('Images/other/IMG_5676.jpg'),
#  PosixPath('Images/other/IMG_5616.jpg'),
#  PosixPath('Images/other/IMG_5476.jpg'),
#  PosixPath('Images/other/IMG_6035.jpg'),
#  PosixPath('Images/other/IMG_5753.jpg'),
#  PosixPath('Images/other/IMG_5660.jpg'),
#  PosixPath('Images/other/IMG_5815.jpg'),
#  PosixPath('Images/other/IMG_5690.jpg'),
#  PosixPath('Images/other/IMG_6271.jpg'),
#  PosixPath('Images/other/IMG_6212.jpg'),
#  PosixPath('Images/other/IMG_7519.jpg'),
#  PosixPath('Images/other/IMG_5917.jpg'),
#  PosixPath('Images/other/IMG_5976.jpg'),
#  PosixPath('Images/other/IMG_5739.jpg'),
#  PosixPath('Images/other/IMG_5994.jpg'),
#  PosixPath('Images/other/IMG_5940.jpg'),
#  PosixPath('Images/other/IMG_6280.jpg'),
#  PosixPath('Images/other/IMG_5671.jpg'),
#  PosixPath('Images/other/IMG_5775.jpg'),
#  PosixPath('Images/other/IMG_5949.jpg'),
#  PosixPath('Images/other/IMG_5852.jpg'),
#  PosixPath('Images/other/IMG_5474.jpg'),
#  PosixPath('Images/other/IMG_5846.jpg'),
#  PosixPath('Images/other/IMG_5478.jpg'),
#  PosixPath('Images/other/IMG_5492.jpg'),
#  PosixPath('Images/other/IMG_5707.jpg'),
#  PosixPath('Images/other/IMG_6027.jpg'),
#  PosixPath('Images/other/IMG_6366.jpg'),
#  PosixPath('Images/other/IMG_6187.jpg'),
#  PosixPath('Images/other/IMG_5638.jpg'),
#  PosixPath('Images/other/IMG_6820.jpg'),
#  PosixPath('Images/other/IMG_5841.jpg'),
#  PosixPath('Images/other/IMG_5997.jpg'),
#  PosixPath('Images/other/IMG_6253.jpg'),
#  PosixPath('Images/other/IMG_5480.jpg'),
#  PosixPath('Images/other/IMG_5952.jpg'),
#  PosixPath('Images/other/IMG_5794.jpg'),
#  PosixPath('Images/other/IMG_6242.jpg'),
#  PosixPath('Images/other/IMG_5649.jpg'),
#  PosixPath('Images/other/IMG_5811.jpg'),
#  PosixPath('Images/other/IMG_5670.jpg'),
#  PosixPath('Images/other/IMG_6792.jpg'),
#  PosixPath('Images/other/IMG_7530.jpg'),
#  PosixPath('Images/other/IMG_5704.jpg'),
#  PosixPath('Images/other/IMG_6248.jpg'),
#  PosixPath('Images/other/IMG_6160.jpg'),
#  PosixPath('Images/other/IMG_5906.jpg'),
#  PosixPath('Images/other/IMG_5882.jpg'),
#  PosixPath('Images/other/IMG_6647.jpg'),
#  PosixPath('Images/other/IMG_5857.jpg'),
#  PosixPath('Images/other/IMG_6224.jpg'),
#  PosixPath('Images/other/IMG_6197.jpg'),
#  PosixPath('Images/other/IMG_5869.jpg'),
#  PosixPath('Images/other/IMG_5642.jpg'),
#  PosixPath('Images/other/IMG_7520.jpg'),
#  PosixPath('Images/other/IMG_5850.jpg'),
#  PosixPath('Images/other/IMG_5823.jpg'),
#  PosixPath('Images/other/IMG_5918.jpg'),
#  PosixPath('Images/other/IMG_6782.jpg'),
#  PosixPath('Images/other/IMG_6165.jpg'),
#  PosixPath('Images/other/IMG_5522.jpg'),
#  PosixPath('Images/other/IMG_6841.jpg'),
#  PosixPath('Images/other/IMG_5652.jpg'),
#  PosixPath('Images/other/IMG_6256.jpg'),
#  PosixPath('Images/other/IMG_6361.jpg'),
#  PosixPath('Images/other/IMG_5635.jpg'),
#  PosixPath('Images/other/IMG_5770.jpg'),
#  PosixPath('Images/other/IMG_6834.jpg'),
#  PosixPath('Images/other/IMG_5516.jpg'),
#  PosixPath('Images/other/IMG_6017.jpg'),
#  PosixPath('Images/other/IMG_5870.jpg'),
#  PosixPath('Images/other/IMG_5795.jpg'),
#  PosixPath('Images/other/IMG_6362.jpg'),
#  PosixPath('Images/other/IMG_6790.jpg'),
#  PosixPath('Images/other/IMG_6279.jpg'),
#  PosixPath('Images/other/IMG_5972.jpg'),
#  PosixPath('Images/other/IMG_6153.jpg'),
#  PosixPath('Images/other/IMG_5959.jpg'),
#  PosixPath('Images/other/IMG_6796.jpg'),
#  PosixPath('Images/other/IMG_5661.jpg'),
#  PosixPath('Images/other/IMG_6195.jpg'),
#  PosixPath('Images/other/IMG_5754.jpg'),
#  PosixPath('Images/other/IMG_5743.jpg'),
#  PosixPath('Images/other/IMG_5981.jpg'),
#  PosixPath('Images/other/IMG_5465.jpg'),
#  PosixPath('Images/other/IMG_6193.jpg'),
#  PosixPath('Images/other/IMG_6802.jpg'),
#  PosixPath('Images/other/IMG_6779.jpg'),
#  PosixPath('Images/other/IMG_5486.jpg'),
#  PosixPath('Images/other/IMG_5975.jpg'),
#  PosixPath('Images/other/IMG_5866.jpg'),
#  PosixPath('Images/other/IMG_6840.jpg'),
#  PosixPath('Images/other/IMG_6650.jpg'),
#  PosixPath('Images/other/IMG_5630.jpg'),
#  PosixPath('Images/other/IMG_5636.jpg'),
#  PosixPath('Images/other/IMG_5716.jpg'),
#  PosixPath('Images/other/IMG_5774.jpg'),
#  PosixPath('Images/other/IMG_5844.jpg'),
#  PosixPath('Images/other/IMG_5629.jpg'),
#  PosixPath('Images/other/IMG_5826.jpg'),
#  PosixPath('Images/other/IMG_5669.jpg'),
#  PosixPath('Images/other/IMG_5742.jpg'),
#  PosixPath('Images/other/IMG_5796.jpg'),
#  PosixPath('Images/other/IMG_6282.jpg'),
#  PosixPath('Images/other/IMG_5678.jpg'),
#  PosixPath('Images/other/IMG_5760.jpg'),
#  PosixPath('Images/other/IMG_7524.jpg'),
#  PosixPath('Images/other/IMG_5803.jpg'),
#  PosixPath('Images/other/IMG_5835.jpg'),
#  PosixPath('Images/other/IMG_5487.jpg'),
#  PosixPath('Images/other/IMG_5482.jpg'),
#  PosixPath('Images/other/IMG_5954.jpg'),
#  PosixPath('Images/other/IMG_6778.jpg'),
#  PosixPath('Images/other/IMG_5483.jpg'),
#  PosixPath('Images/other/IMG_6019.jpg'),
#  PosixPath('Images/other/IMG_6416.jpg'),
#  PosixPath('Images/other/IMG_5694.jpg'),
#  PosixPath('Images/other/IMG_6033.jpg'),
#  PosixPath('Images/other/IMG_5883.jpg'),
#  PosixPath('Images/other/IMG_5921.jpg'),
#  PosixPath('Images/other/IMG_6269.jpg'),
#  PosixPath('Images/other/IMG_7532.jpg'),
#  PosixPath('Images/other/IMG_5510.jpg'),
#  PosixPath('Images/other/IMG_7529.jpg'),
#  PosixPath('Images/other/IMG_6801.jpg'),
#  PosixPath('Images/other/IMG_5809.jpg'),
#  PosixPath('Images/other/IMG_5769.jpg'),
#  PosixPath('Images/other/IMG_6803.jpg'),
#  PosixPath('Images/other/IMG_6215.jpg'),
#  PosixPath('Images/other/IMG_5455.jpg'),
#  PosixPath('Images/other/IMG_5646.jpg'),
#  PosixPath('Images/other/IMG_5656.jpg'),
#  PosixPath('Images/other/IMG_6221.jpg'),
#  PosixPath('Images/other/IMG_7531.jpg'),
#  PosixPath('Images/other/IMG_5721.jpg'),
#  PosixPath('Images/other/IMG_5508.jpg'),
#  PosixPath('Images/other/IMG_5475.jpg'),
#  PosixPath('Images/other/IMG_5919.jpg'),
#  PosixPath('Images/other/IMG_6252.jpg'),
#  PosixPath('Images/other/IMG_5894.jpg'),
#  PosixPath('Images/other/IMG_7511.jpg'),
#  PosixPath('Images/other/IMG_6008.jpg'),
#  PosixPath('Images/other/IMG_6783.jpg'),
#  PosixPath('Images/other/IMG_6304.jpg'),
#  PosixPath('Images/other/IMG_7517.jpg'),
#  PosixPath('Images/other/IMG_6829.jpg'),
#  PosixPath('Images/other/IMG_5845.jpg'),
#  PosixPath('Images/other/IMG_6823.jpg'),
#  PosixPath('Images/other/IMG_6200.jpg'),
#  PosixPath('Images/other/IMG_6817.jpg'),
#  PosixPath('Images/other/IMG_6012.jpg'),
#  PosixPath('Images/other/IMG_5793.jpg'),
#  PosixPath('Images/other/IMG_5914.jpg'),
#  PosixPath('Images/other/IMG_5873.jpg'),
#  PosixPath('Images/other/IMG_6226.jpg'),
#  PosixPath('Images/other/IMG_5659.jpg'),
#  PosixPath('Images/other/IMG_5619.jpg'),
#  PosixPath('Images/other/IMG_6655.jpg'),
#  PosixPath('Images/other/IMG_5495.jpg'),
#  PosixPath('Images/other/IMG_5865.jpg'),
#  PosixPath('Images/other/IMG_5710.jpg'),
#  PosixPath('Images/other/IMG_5640.jpg'),
#  PosixPath('Images/other/IMG_5648.jpg'),
#  PosixPath('Images/other/IMG_5839.jpg'),
#  PosixPath('Images/other/IMG_6587.jpg'),
#  PosixPath('Images/other/IMG_5696.jpg'),
#  PosixPath('Images/other/IMG_5786.jpg'),
#  PosixPath('Images/other/IMG_5674.jpg'),
#  PosixPath('Images/other/IMG_6231.jpg'),
#  PosixPath('Images/other/IMG_6303.jpg'),
#  PosixPath('Images/other/IMG_5967.jpg'),
#  PosixPath('Images/other/IMG_6162.jpg'),
#  PosixPath('Images/other/IMG_6223.jpg'),
#  PosixPath('Images/other/IMG_6360.jpg'),
#  PosixPath('Images/other/IMG_7522.jpg'),
#  PosixPath('Images/other/IMG_6646.jpg'),
#  PosixPath('Images/other/IMG_6795.jpg'),
#  PosixPath('Images/other/IMG_5464.jpg'),
#  PosixPath('Images/other/IMG_5858.jpg'),
#  PosixPath('Images/other/IMG_5843.jpg'),
#  PosixPath('Images/other/IMG_6784.jpg'),
#  PosixPath('Images/other/IMG_6770.jpg'),
#  PosixPath('Images/other/IMG_5757.jpg'),
#  PosixPath('Images/other/IMG_6821.jpg'),
#  PosixPath('Images/other/IMG_5634.jpg'),
#  PosixPath('Images/other/IMG_6266.jpg'),
#  PosixPath('Images/other/IMG_5897.jpg'),
#  PosixPath('Images/other/IMG_5618.jpg'),
#  PosixPath('Images/other/IMG_6806.jpg'),
#  PosixPath('Images/other/IMG_5621.jpg'),
#  PosixPath('Images/other/IMG_6327.jpg'),
#  PosixPath('Images/other/IMG_5709.jpg'),
#  PosixPath('Images/other/IMG_6029.jpg'),
#  PosixPath('Images/other/IMG_6213.jpg'),
#  PosixPath('Images/other/IMG_5500.jpg'),
#  PosixPath('Images/other/IMG_7521.jpg'),
#  PosixPath('Images/other/IMG_6833.jpg'),
#  PosixPath('Images/other/IMG_6272.jpg'),
#  PosixPath('Images/other/IMG_5802.jpg'),
#  PosixPath('Images/other/IMG_7518.jpg'),
#  PosixPath('Images/other/IMG_6004.jpg'),
#  PosixPath('Images/other/IMG_6824.jpg'),
#  PosixPath('Images/other/IMG_5502.jpg'),
#  PosixPath('Images/other/IMG_5738.jpg'),
#  PosixPath('Images/other/IMG_5946.jpg'),
#  PosixPath('Images/other/IMG_5947.jpg'),
#  PosixPath('Images/other/IMG_5723.jpg'),
#  PosixPath('Images/other/IMG_5720.jpg'),
#  PosixPath('Images/other/IMG_5658.jpg'),
#  PosixPath('Images/other/IMG_5787.jpg'),
#  PosixPath('Images/other/IMG_5706.jpg'),
#  PosixPath('Images/other/IMG_5485.jpg'),
#  PosixPath('Images/other/IMG_5806.jpg'),
#  PosixPath('Images/other/IMG_5768.jpg'),
#  PosixPath('Images/other/IMG_5871.jpg'),
#  PosixPath('Images/other/IMG_5627.jpg'),
#  PosixPath('Images/other/IMG_5781.jpg'),
#  PosixPath('Images/other/IMG_5762.jpg'),
#  PosixPath('Images/other/IMG_5501.jpg'),
#  PosixPath('Images/other/IMG_5836.jpg'),
#  PosixPath('Images/other/IMG_5654.jpg'),
#  PosixPath('Images/other/IMG_5772.jpg'),
#  PosixPath('Images/other/IMG_6261.jpg'),
#  PosixPath('Images/other/IMG_5851.jpg'),
#  PosixPath('Images/other/IMG_5504.jpg'),
#  PosixPath('Images/other/IMG_6773.jpg'),
#  PosixPath('Images/other/IMG_5840.jpg'),
#  PosixPath('Images/other/IMG_6837.jpg'),
#  PosixPath('Images/other/IMG_5632.jpg'),
#  PosixPath('Images/other/IMG_5778.jpg'),
#  PosixPath('Images/other/IMG_5833.jpg'),
#  PosixPath('Images/other/IMG_5807.jpg'),
#  PosixPath('Images/other/IMG_5467.jpg'),
#  PosixPath('Images/other/IMG_5881.jpg'),
#  PosixPath('Images/other/IMG_5832.jpg'),
#  PosixPath('Images/other/IMG_5995.jpg'),
#  PosixPath('Images/other/IMG_5655.jpg'),
#  PosixPath('Images/other/IMG_6777.jpg'),
#  PosixPath('Images/other/IMG_5462.jpg'),
#  PosixPath('Images/other/IMG_5820.jpg'),
#  PosixPath('Images/other/IMG_5810.jpg'),
#  PosixPath('Images/other/IMG_5830.jpg'),
#  PosixPath('Images/other/IMG_6030.jpg'),
#  PosixPath('Images/other/IMG_5672.jpg'),
#  PosixPath('Images/other/IMG_5509.jpg'),
#  PosixPath('Images/other/IMG_5506.jpg'),
#  PosixPath('Images/other/IMG_6459.jpg'),
#  PosixPath('Images/other/IMG_5714.jpg'),
#  PosixPath('Images/other/IMG_6797.jpg'),
#  PosixPath('Images/other/IMG_5453.jpg'),
#  PosixPath('Images/other/IMG_5507.jpg'),
#  PosixPath('Images/other/IMG_5813.jpg'),
#  PosixPath('Images/other/IMG_5984.jpg'),
#  PosixPath('Images/other/IMG_6310.jpg'),
#  PosixPath('Images/other/IMG_5798.jpg'),
#  PosixPath('Images/other/IMG_7515.jpg'),
#  PosixPath('Images/other/IMG_5641.jpg'),
#  PosixPath('Images/other/IMG_5992.jpg'),
#  PosixPath('Images/other/IMG_5821.jpg'),
#  PosixPath('Images/other/IMG_5511.jpg'),
#  PosixPath('Images/other/IMG_6810.jpg'),
#  PosixPath('Images/other/IMG_5916.jpg'),
#  PosixPath('Images/other/IMG_6774.jpg'),
#  PosixPath('Images/other/IMG_5763.jpg'),
#  PosixPath('Images/other/IMG_6794.jpg'),
#  PosixPath('Images/other/IMG_5454.jpg'),
#  PosixPath('Images/other/IMG_6836.jpg'),
#  PosixPath('Images/other/IMG_6785.jpg'),
#  PosixPath('Images/other/IMG_5961.jpg'),
#  PosixPath('Images/other/IMG_6772.jpg'),
#  PosixPath('Images/other/IMG_5520.jpg'),
#  PosixPath('Images/other/IMG_5643.jpg'),
#  PosixPath('Images/other/IMG_5965.jpg'),
#  PosixPath('Images/other/IMG_5677.jpg'),
#  PosixPath('Images/other/IMG_6788.jpg'),
#  PosixPath('Images/other/IMG_6164.jpg'),
#  PosixPath('Images/other/IMG_6411.jpg'),
#  PosixPath('Images/other/IMG_5499.jpg'),
#  PosixPath('Images/other/IMG_5771.jpg'),
#  PosixPath('Images/other/IMG_7534.jpg'),
#  PosixPath('Images/other/IMG_5623.jpg'),
#  PosixPath('Images/other/IMG_5612.jpg'),
#  PosixPath('Images/other/IMG_5717.jpg'),
#  PosixPath('Images/other/IMG_6634.jpg'),
#  PosixPath('Images/other/IMG_6194.jpg'),
#  PosixPath('Images/other/IMG_5633.jpg'),
#  PosixPath('Images/other/IMG_7528.jpg'),
#  PosixPath('Images/other/IMG_5908.jpg'),
#  PosixPath('Images/other/IMG_6839.jpg'),
#  PosixPath('Images/other/IMG_6818.jpg'),
#  PosixPath('Images/other/IMG_5879.jpg'),
#  PosixPath('Images/other/IMG_7533.jpg'),
#  PosixPath('Images/other/IMG_6013.jpg'),
#  PosixPath('Images/other/IMG_6825.jpg'),
#  PosixPath('Images/other/IMG_6651.jpg'),
#  PosixPath('Images/other/IMG_6196.jpg'),
#  PosixPath('Images/other/IMG_5903.jpg'),
#  PosixPath('Images/other/IMG_5505.jpg'),
#  PosixPath('Images/other/IMG_7514.jpg'),
#  PosixPath('Images/other/IMG_5934.jpg'),
#  PosixPath('Images/other/IMG_6021.jpg'),
#  PosixPath('Images/other/IMG_6159.jpg'),
#  PosixPath('Images/other/IMG_6298.jpg'),
#  PosixPath('Images/other/IMG_5705.jpg'),
#  PosixPath('Images/other/IMG_5741.jpg'),
#  PosixPath('Images/other/IMG_5784.jpg'),
#  PosixPath('Images/other/IMG_6832.jpg'),
#  PosixPath('Images/other/IMG_5855.jpg'),
#  PosixPath('Images/other/IMG_6822.jpg'),
#  PosixPath('Images/other/IMG_5979.jpg'),
#  PosixPath('Images/other/IMG_5498.jpg'),
#  PosixPath('Images/other/IMG_5842.jpg'),
#  PosixPath('Images/other/IMG_6780.jpg'),
#  PosixPath('Images/other/IMG_5950.jpg'),
#  PosixPath('Images/other/IMG_5496.jpg'),
#  PosixPath('Images/other/IMG_5860.jpg'),
#  PosixPath('Images/other/IMG_5761.jpg'),
#  PosixPath('Images/other/IMG_6284.jpg'),
#  PosixPath('Images/other/IMG_5941.jpg'),
#  PosixPath('Images/other/IMG_5644.jpg'),
#  PosixPath('Images/other/IMG_6808.jpg'),
#  PosixPath('Images/other/IMG_5758.jpg'),
#  PosixPath('Images/other/IMG_6302.jpg'),
#  PosixPath('Images/other/IMG_5651.jpg'),
#  PosixPath('Images/other/IMG_5460.jpg'),
#  PosixPath('Images/other/IMG_6152.jpg'),
#  PosixPath('Images/other/IMG_6299.jpg'),
#  PosixPath('Images/other/IMG_5719.jpg'),
#  PosixPath('Images/other/IMG_6222.jpg'),
#  PosixPath('Images/other/IMG_5747.jpg'),
#  PosixPath('Images/other/IMG_5479.jpg'),
#  PosixPath('Images/other/IMG_5673.jpg'),
#  PosixPath('Images/other/IMG_6032.jpg'),
#  PosixPath('Images/other/IMG_5808.jpg'),
#  PosixPath('Images/other/IMG_5848.jpg'),
#  PosixPath('Images/other/IMG_6241.jpg'),
#  PosixPath('Images/other/IMG_6410.jpg'),
#  PosixPath('Images/other/IMG_6225.jpg'),
#  PosixPath('Images/other/IMG_5957.jpg'),
#  PosixPath('Images/other/IMG_5625.jpg'),
#  PosixPath('Images/other/IMG_5893.jpg'),
#  PosixPath('Images/other/IMG_6830.jpg'),
#  PosixPath('Images/other/IMG_5900.jpg'),
#  PosixPath('Images/other/IMG_6233.jpg'),
#  PosixPath('Images/other/IMG_5822.jpg'),
#  PosixPath('Images/other/IMG_5491.jpg'),
#  PosixPath('Images/other/IMG_5631.jpg'),
#  PosixPath('Images/other/IMG_5645.jpg'),
#  PosixPath('Images/other/IMG_6003.jpg'),
#  PosixPath('Images/other/IMG_5956.jpg'),
#  PosixPath('Images/other/IMG_5666.jpg'),
#  PosixPath('Images/other/IMG_6309.jpg'),
#  PosixPath('Images/other/IMG_5966.jpg'),
#  PosixPath('Images/other/IMG_5657.jpg'),
#  PosixPath('Images/other/IMG_5748.jpg'),
#  PosixPath('Images/other/IMG_5923.jpg'),
#  PosixPath('Images/other/IMG_5751.jpg'),
#  PosixPath('Images/other/IMG_5484.jpg'),
#  PosixPath('Images/other/IMG_6239.jpg'),
#  PosixPath('Images/other/IMG_6257.jpg'),
#  PosixPath('Images/other/IMG_5610.jpg'),
#  PosixPath('Images/other/IMG_5797.jpg'),
#  PosixPath('Images/other/IMG_5990.jpg'),
#  PosixPath('Images/other/IMG_5814.jpg'),
#  PosixPath('Images/other/IMG_5876.jpg'),
#  PosixPath('Images/other/IMG_5647.jpg'),
#  PosixPath('Images/other/IMG_7526.jpg'),
#  PosixPath('Images/other/IMG_6281.jpg'),
#  PosixPath('Images/other/IMG_5812.jpg'),
#  PosixPath('Images/other/IMG_5913.jpg'),
#  PosixPath('Images/other/IMG_5503.jpg'),
#  PosixPath('Images/other/IMG_5783.jpg'),
#  PosixPath('Images/other/IMG_5755.jpg'),
#  PosixPath('Images/other/IMG_6235.jpg'),
#  PosixPath('Images/other/IMG_6301.jpg'),
#  PosixPath('Images/other/IMG_5773.jpg'),
#  PosixPath('Images/other/IMG_7513.jpg'),
#  PosixPath('Images/other/IMG_6816.jpg'),
#  PosixPath('Images/other/IMG_6771.jpg'),
#  PosixPath('Images/other/IMG_7527.jpg'),
#  PosixPath('Images/other/IMG_6409.jpg'),
#  PosixPath('Images/other/IMG_6168.jpg'),
#  PosixPath('Images/other/IMG_5935.jpg'),
#  PosixPath('Images/other/IMG_5457.jpg'),
#  PosixPath('Images/other/IMG_5756.jpg'),
#  PosixPath('Images/other/IMG_6232.jpg'),
#  PosixPath('Images/dandelion/IMG_3922.jpg'),
#  PosixPath('Images/dandelion/IMG_6756.jpg'),
#  PosixPath('Images/dandelion/IMG_6092.jpg'),
#  PosixPath('Images/dandelion/IMG_5896.jpg'),
#  PosixPath('Images/dandelion/IMG_6681.jpg'),
#  PosixPath('Images/dandelion/IMG_5564.jpg'),
#  PosixPath('Images/dandelion/IMG_6676.jpg'),
#  PosixPath('Images/dandelion/IMG_6156.jpg'),
#  PosixPath('Images/dandelion/IMG_1195.jpg'),
#  PosixPath('Images/dandelion/IMG_5409.jpg'),
#  PosixPath('Images/dandelion/IMG_6107.jpg'),
#  PosixPath('Images/dandelion/IMG_1246.jpg'),
#  PosixPath('Images/dandelion/IMG_1282.jpg'),
#  PosixPath('Images/dandelion/IMG_5421.jpg'),
#  PosixPath('Images/dandelion/IMG_1118.jpg'),
#  PosixPath('Images/dandelion/IMG_6754.jpg'),
#  PosixPath('Images/dandelion/IMG_3937.jpg'),
#  PosixPath('Images/dandelion/IMG_5438.jpg'),
#  PosixPath('Images/dandelion/IMG_6095.jpg'),
#  PosixPath('Images/dandelion/IMG_6100.jpg'),
#  PosixPath('Images/dandelion/IMG_5929.jpg'),
#  PosixPath('Images/dandelion/IMG_3863.jpg'),
#  PosixPath('Images/dandelion/IMG_1233.jpg'),
#  PosixPath('Images/dandelion/IMG_1296.jpg'),
#  PosixPath('Images/dandelion/IMG_6120.jpg'),
#  PosixPath('Images/dandelion/IMG_6707.jpg'),
#  PosixPath('Images/dandelion/IMG_1186.jpg'),
#  PosixPath('Images/dandelion/IMG_5928.jpg'),
#  PosixPath('Images/dandelion/IMG_5408.jpg'),
#  PosixPath('Images/dandelion/IMG_1146.jpg'),
#  PosixPath('Images/dandelion/IMG_1245.jpg'),
#  PosixPath('Images/dandelion/IMG_6130.jpg'),
#  PosixPath('Images/dandelion/IMG_5407.jpg'),
#  PosixPath('Images/dandelion/IMG_5523.jpg'),
#  PosixPath('Images/dandelion/IMG_5590.jpg'),
#  PosixPath('Images/dandelion/IMG_6097.jpg'),
#  PosixPath('Images/dandelion/IMG_1139.jpg'),
#  PosixPath('Images/dandelion/IMG_1144.jpg'),
#  PosixPath('Images/dandelion/IMG_6748.jpg'),
#  PosixPath('Images/dandelion/IMG_3862.jpg'),
#  PosixPath('Images/dandelion/IMG_5578.jpg'),
#  PosixPath('Images/dandelion/IMG_5750.jpg'),
#  PosixPath('Images/dandelion/IMG_5555.jpg'),
#  PosixPath('Images/dandelion/IMG_3953.jpg'),
#  PosixPath('Images/dandelion/IMG_1128.jpg'),
#  PosixPath('Images/dandelion/IMG_3856.jpg'),
#  PosixPath('Images/dandelion/IMG_6099.jpg'),
#  PosixPath('Images/dandelion/IMG_1179.jpg'),
#  PosixPath('Images/dandelion/IMG_1165.jpg'),
#  PosixPath('Images/dandelion/IMG_1273.jpg'),
#  PosixPath('Images/dandelion/IMG_6190.jpg'),
#  PosixPath('Images/dandelion/IMG_3943.jpg'),
#  PosixPath('Images/dandelion/IMG_3894.jpg'),
#  PosixPath('Images/dandelion/IMG_5695.jpg'),
#  PosixPath('Images/dandelion/IMG_3854.jpg'),
#  PosixPath('Images/dandelion/IMG_1158.jpg'),
#  PosixPath('Images/dandelion/IMG_3915.jpg'),
#  PosixPath('Images/dandelion/IMG_1156.jpg'),
#  PosixPath('Images/dandelion/IMG_5933.jpg'),
#  PosixPath('Images/dandelion/IMG_6678.jpg'),
#  PosixPath('Images/dandelion/IMG_3866.jpg'),
#  PosixPath('Images/dandelion/IMG_7516.jpg'),
#  PosixPath('Images/dandelion/IMG_3948.jpg'),
#  PosixPath('Images/dandelion/IMG_6125.jpg'),
#  PosixPath('Images/dandelion/IMG_1235.jpg'),
#  PosixPath('Images/dandelion/IMG_1333.jpg'),
#  PosixPath('Images/dandelion/IMG_6720.jpg'),
#  PosixPath('Images/dandelion/IMG_7512.jpg'),
#  PosixPath('Images/dandelion/IMG_3930.jpg'),
#  PosixPath('Images/dandelion/IMG_1227.jpg'),
#  PosixPath('Images/dandelion/IMG_3950.jpg'),
#  PosixPath('Images/dandelion/IMG_6764.jpg'),
#  PosixPath('Images/dandelion/IMG_6117.jpg'),
#  PosixPath('Images/dandelion/IMG_1306.jpg'),
#  PosixPath('Images/dandelion/IMG_6737.jpg'),
#  PosixPath('Images/dandelion/IMG_1166.jpg'),
#  PosixPath('Images/dandelion/IMG_5568.jpg'),
#  PosixPath('Images/dandelion/IMG_6752.jpg'),
#  PosixPath('Images/dandelion/IMG_6701.jpg'),
#  PosixPath('Images/dandelion/IMG_1191.jpg'),
#  PosixPath('Images/dandelion/IMG_3917.jpg'),
#  PosixPath('Images/dandelion/IMG_6741.jpg'),
#  PosixPath('Images/dandelion/IMG_1200.jpg'),
#  PosixPath('Images/dandelion/IMG_1216.jpg'),
#  PosixPath('Images/dandelion/IMG_6704.jpg'),
#  PosixPath('Images/dandelion/IMG_1294.jpg'),
#  PosixPath('Images/dandelion/IMG_3885.jpg'),
#  PosixPath('Images/dandelion/IMG_3860.jpg'),
#  PosixPath('Images/dandelion/IMG_3934.jpg'),
#  PosixPath('Images/dandelion/IMG_6693.jpg'),
#  PosixPath('Images/dandelion/IMG_3846.jpg'),
#  PosixPath('Images/dandelion/IMG_3954.jpg'),
#  PosixPath('Images/dandelion/IMG_3897.jpg'),
#  PosixPath('Images/dandelion/IMG_6686.jpg'),
#  PosixPath('Images/dandelion/IMG_6691.jpg'),
#  PosixPath('Images/dandelion/IMG_3911.jpg'),
#  PosixPath('Images/dandelion/IMG_3952.jpg'),
#  PosixPath('Images/dandelion/IMG_5401.jpg'),
#  PosixPath('Images/dandelion/IMG_6084.jpg'),
#  PosixPath('Images/dandelion/IMG_6680.jpg'),
#  PosixPath('Images/dandelion/IMG_1314.jpg'),
#  PosixPath('Images/dandelion/IMG_6745.jpg'),
#  PosixPath('Images/dandelion/IMG_3848.jpg'),
#  PosixPath('Images/dandelion/IMG_1189.jpg'),
#  PosixPath('Images/dandelion/IMG_3849.jpg'),
#  PosixPath('Images/dandelion/IMG_1126.jpg'),
#  PosixPath('Images/dandelion/IMG_3858.jpg'),
#  PosixPath('Images/dandelion/IMG_6761.jpg'),
#  PosixPath('Images/dandelion/IMG_6105.jpg'),
#  PosixPath('Images/dandelion/IMG_7525.jpg'),
#  PosixPath('Images/dandelion/IMG_1174.jpg'),
#  PosixPath('Images/dandelion/IMG_5399.jpg'),
#  PosixPath('Images/dandelion/IMG_5895.jpg'),
#  PosixPath('Images/dandelion/IMG_3914.jpg'),
#  PosixPath('Images/dandelion/IMG_3900.jpg'),
#  PosixPath('Images/dandelion/IMG_1215.jpg'),
#  PosixPath('Images/dandelion/IMG_5606.jpg'),
#  PosixPath('Images/dandelion/IMG_6757.jpg'),
#  PosixPath('Images/dandelion/IMG_5593.jpg'),
#  PosixPath('Images/dandelion/IMG_6727.jpg'),
#  PosixPath('Images/dandelion/IMG_5450.jpg'),
#  PosixPath('Images/dandelion/IMG_5547.jpg'),
#  PosixPath('Images/dandelion/IMG_5447.jpg'),
#  PosixPath('Images/dandelion/IMG_1190.jpg'),
#  PosixPath('Images/dandelion/IMG_1151.jpg'),
#  PosixPath('Images/dandelion/IMG_1255.jpg'),
#  PosixPath('Images/dandelion/IMG_6090.jpg'),
#  PosixPath('Images/dandelion/IMG_1153.jpg'),
#  PosixPath('Images/dandelion/IMG_5395.jpg'),
#  PosixPath('Images/dandelion/IMG_1193.jpg'),
#  PosixPath('Images/dandelion/IMG_1257.jpg'),
#  PosixPath('Images/dandelion/IMG_5577.jpg'),
#  PosixPath('Images/dandelion/IMG_7523.jpg'),
#  PosixPath('Images/dandelion/IMG_5433.jpg'),
#  PosixPath('Images/dandelion/IMG_6726.jpg'),
#  PosixPath('Images/dandelion/IMG_3883.jpg'),
#  PosixPath('Images/dandelion/IMG_1308.jpg'),
#  PosixPath('Images/dandelion/IMG_1329.jpg'),
#  PosixPath('Images/dandelion/IMG_5566.jpg'),
#  PosixPath('Images/dandelion/IMG_3868.jpg'),
#  PosixPath('Images/dandelion/IMG_5595.jpg'),
#  PosixPath('Images/dandelion/IMG_6268.jpg'),
#  PosixPath('Images/dandelion/IMG_6722.jpg'),
#  PosixPath('Images/dandelion/IMG_1250.jpg'),
#  PosixPath('Images/dandelion/IMG_1204.jpg'),
#  PosixPath('Images/dandelion/IMG_5572.jpg'),
#  PosixPath('Images/dandelion/IMG_1167.jpg'),
#  PosixPath('Images/dandelion/IMG_5426.jpg'),
#  PosixPath('Images/dandelion/IMG_3940.jpg'),
#  PosixPath('Images/dandelion/IMG_3949.jpg'),
#  PosixPath('Images/dandelion/IMG_6086.jpg'),
#  PosixPath('Images/dandelion/IMG_5594.jpg'),
#  PosixPath('Images/dandelion/IMG_3884.jpg'),
#  PosixPath('Images/dandelion/IMG_6135.jpg'),
#  PosixPath('Images/dandelion/IMG_3944.jpg'),
#  PosixPath('Images/dandelion/IMG_3857.jpg'),
#  PosixPath('Images/dandelion/IMG_1125.jpg'),
#  PosixPath('Images/dandelion/IMG_6679.jpg'),
#  PosixPath('Images/dandelion/IMG_1298.jpg'),
#  PosixPath('Images/dandelion/IMG_5570.jpg'),
#  PosixPath('Images/dandelion/IMG_5442.jpg'),
#  PosixPath('Images/dandelion/IMG_3877.jpg'),
#  PosixPath('Images/dandelion/IMG_6747.jpg'),
#  PosixPath('Images/dandelion/IMG_3919.jpg'),
#  PosixPath('Images/dandelion/IMG_6684.jpg'),
#  PosixPath('Images/dandelion/IMG_1143.jpg'),
#  PosixPath('Images/dandelion/IMG_3871.jpg'),
#  PosixPath('Images/dandelion/IMG_5567.jpg'),
#  PosixPath('Images/dandelion/IMG_1254.jpg'),
#  PosixPath('Images/dandelion/IMG_6123.jpg'),
#  PosixPath('Images/dandelion/IMG_6129.jpg'),
#  PosixPath('Images/dandelion/IMG_5698.jpg'),
#  PosixPath('Images/dandelion/IMG_1129.jpg'),
#  PosixPath('Images/dandelion/IMG_1305.jpg'),
#  PosixPath('Images/dandelion/IMG_1220.jpg'),
#  PosixPath('Images/dandelion/IMG_5607.jpg'),
#  PosixPath('Images/dandelion/IMG_3899.jpg'),
#  PosixPath('Images/dandelion/IMG_6093.jpg'),
#  PosixPath('Images/dandelion/IMG_3875.jpg'),
#  PosixPath('Images/dandelion/IMG_3916.jpg'),
#  PosixPath('Images/dandelion/IMG_5556.jpg'),
#  PosixPath('Images/dandelion/IMG_6116.jpg'),
#  PosixPath('Images/dandelion/IMG_3925.jpg'),
#  PosixPath('Images/dandelion/IMG_3847.jpg'),
#  PosixPath('Images/dandelion/IMG_1149.jpg'),
#  PosixPath('Images/dandelion/IMG_3932.jpg'),
#  PosixPath('Images/dandelion/IMG_1150.jpg'),
#  PosixPath('Images/dandelion/IMG_5581.jpg'),
#  PosixPath('Images/dandelion/IMG_3945.jpg'),
#  PosixPath('Images/dandelion/IMG_5552.jpg'),
#  PosixPath('Images/dandelion/IMG_6735.jpg'),
#  PosixPath('Images/dandelion/IMG_3938.jpg'),
#  PosixPath('Images/dandelion/IMG_5431.jpg'),
#  PosixPath('Images/dandelion/IMG_1334.jpg'),
#  PosixPath('Images/dandelion/IMG_6718.jpg'),
#  PosixPath('Images/dandelion/IMG_6119.jpg'),
#  PosixPath('Images/dandelion/IMG_5702.jpg'),
#  PosixPath('Images/dandelion/IMG_1281.jpg'),
#  PosixPath('Images/dandelion/IMG_3942.jpg'),
#  PosixPath('Images/dandelion/IMG_6673.jpg'),
#  PosixPath('Images/dandelion/IMG_1299.jpg'),
#  PosixPath('Images/dandelion/IMG_1303.jpg'),
#  PosixPath('Images/dandelion/IMG_5410.jpg'),
#  PosixPath('Images/dandelion/IMG_1328.jpg'),
#  PosixPath('Images/dandelion/IMG_6700.jpg'),
#  PosixPath('Images/dandelion/IMG_5557.jpg'),
#  PosixPath('Images/dandelion/IMG_6763.jpg'),
#  PosixPath('Images/dandelion/IMG_1275.jpg'),
#  PosixPath('Images/dandelion/IMG_5592.jpg'),
#  PosixPath('Images/dandelion/IMG_5437.jpg'),
#  PosixPath('Images/dandelion/IMG_3870.jpg'),
#  PosixPath('Images/dandelion/IMG_5924.jpg'),
#  PosixPath('Images/dandelion/IMG_1309.jpg'),
#  PosixPath('Images/dandelion/IMG_6767.jpg'),
#  PosixPath('Images/dandelion/IMG_6674.jpg'),
#  PosixPath('Images/dandelion/IMG_6134.jpg'),
#  PosixPath('Images/dandelion/IMG_5404.jpg'),
#  PosixPath('Images/dandelion/IMG_3909.jpg'),
#  PosixPath('Images/dandelion/IMG_5423.jpg'),
#  PosixPath('Images/dandelion/IMG_3939.jpg'),
#  PosixPath('Images/dandelion/IMG_1202.jpg'),
#  PosixPath('Images/dandelion/IMG_6677.jpg'),
#  PosixPath('Images/dandelion/IMG_1142.jpg'),
#  PosixPath('Images/dandelion/IMG_1124.jpg'),
#  PosixPath('Images/dandelion/IMG_1228.jpg'),
#  PosixPath('Images/dandelion/IMG_6717.jpg'),
#  PosixPath('Images/dandelion/IMG_3878.jpg'),
#  PosixPath('Images/dandelion/IMG_3941.jpg'),
#  PosixPath('Images/dandelion/IMG_6725.jpg'),
#  PosixPath('Images/dandelion/IMG_1304.jpg'),
#  PosixPath('Images/dandelion/IMG_6270.jpg'),
#  PosixPath('Images/dandelion/IMG_1279.jpg'),
#  PosixPath('Images/dandelion/IMG_5551.jpg'),
#  PosixPath('Images/dandelion/IMG_5558.jpg'),
#  PosixPath('Images/dandelion/IMG_1318.jpg'),
#  PosixPath('Images/dandelion/IMG_5939.jpg'),
#  PosixPath('Images/dandelion/IMG_1315.jpg'),
#  PosixPath('Images/dandelion/IMG_1219.jpg'),
#  PosixPath('Images/dandelion/IMG_5943.jpg'),
#  PosixPath('Images/dandelion/IMG_1276.jpg'),
#  PosixPath('Images/dandelion/IMG_3924.jpg'),
#  PosixPath('Images/dandelion/IMG_3855.jpg'),
#  PosixPath('Images/dandelion/IMG_6751.jpg'),
#  PosixPath('Images/dandelion/IMG_3865.jpg'),
#  PosixPath('Images/dandelion/IMG_6740.jpg'),
#  PosixPath('Images/dandelion/IMG_5418.jpg'),
#  PosixPath('Images/dandelion/IMG_5405.jpg'),
#  PosixPath('Images/dandelion/IMG_1131.jpg'),
#  PosixPath('Images/dandelion/IMG_1224.jpg'),
#  PosixPath('Images/dandelion/IMG_1199.jpg'),
#  PosixPath('Images/dandelion/IMG_3929.jpg'),
#  PosixPath('Images/dandelion/IMG_6089.jpg'),
#  PosixPath('Images/dandelion/IMG_1201.jpg'),
#  PosixPath('Images/dandelion/IMG_6758.jpg'),
#  PosixPath('Images/dandelion/IMG_5828.jpg'),
#  PosixPath('Images/dandelion/IMG_5601.jpg'),
#  PosixPath('Images/dandelion/IMG_3936.jpg'),
#  PosixPath('Images/dandelion/IMG_5532.jpg'),
#  PosixPath('Images/dandelion/IMG_3852.jpg'),
#  PosixPath('Images/dandelion/IMG_5936.jpg'),
#  PosixPath('Images/dandelion/IMG_1251.jpg'),
#  PosixPath('Images/dandelion/IMG_5932.jpg'),
#  PosixPath('Images/dandelion/IMG_3882.jpg'),
#  PosixPath('Images/dandelion/IMG_3890.jpg'),
#  PosixPath('Images/dandelion/IMG_5424.jpg'),
#  PosixPath('Images/dandelion/IMG_1155.jpg'),
#  PosixPath('Images/dandelion/IMG_5441.jpg'),
#  PosixPath('Images/dandelion/IMG_5412.jpg'),
#  PosixPath('Images/dandelion/IMG_5699.jpg'),
#  PosixPath('Images/dandelion/IMG_5604.jpg'),
#  PosixPath('Images/dandelion/IMG_3908.jpg'),
#  PosixPath('Images/dandelion/IMG_6697.jpg'),
#  PosixPath('Images/dandelion/IMG_1236.jpg'),
#  PosixPath('Images/dandelion/IMG_1160.jpg'),
#  PosixPath('Images/dandelion/IMG_1183.jpg'),
#  PosixPath('Images/dandelion/IMG_1130.jpg'),
#  PosixPath('Images/dandelion/IMG_6688.jpg'),
#  PosixPath('Images/dandelion/IMG_1285.jpg'),
#  PosixPath('Images/dandelion/IMG_1133.jpg'),
#  PosixPath('Images/dandelion/IMG_3869.jpg'),
#  PosixPath('Images/dandelion/IMG_5700.jpg'),
#  PosixPath('Images/dandelion/IMG_5588.jpg'),
#  PosixPath('Images/dandelion/IMG_1302.jpg'),
#  PosixPath('Images/dandelion/IMG_5960.jpg'),
#  PosixPath('Images/dandelion/IMG_5432.jpg'),
#  PosixPath('Images/dandelion/IMG_6085.jpg'),
#  PosixPath('Images/dandelion/IMG_5533.jpg'),
#  PosixPath('Images/dandelion/IMG_1295.jpg'),
#  PosixPath('Images/dandelion/IMG_6724.jpg'),
#  PosixPath('Images/dandelion/IMG_7519.jpg'),
#  PosixPath('Images/dandelion/IMG_1256.jpg'),
#  PosixPath('Images/dandelion/IMG_1162.jpg'),
#  PosixPath('Images/dandelion/IMG_1284.jpg'),
#  PosixPath('Images/dandelion/IMG_1134.jpg'),
#  PosixPath('Images/dandelion/IMG_6765.jpg'),
#  PosixPath('Images/dandelion/IMG_5587.jpg'),
#  PosixPath('Images/dandelion/IMG_1240.jpg'),
#  PosixPath('Images/dandelion/IMG_5434.jpg'),
#  PosixPath('Images/dandelion/IMG_6709.jpg'),
#  PosixPath('Images/dandelion/IMG_1331.jpg'),
#  PosixPath('Images/dandelion/IMG_6103.jpg'),
#  PosixPath('Images/dandelion/IMG_5931.jpg'),
#  PosixPath('Images/dandelion/IMG_1221.jpg'),
#  PosixPath('Images/dandelion/IMG_6124.jpg'),
#  PosixPath('Images/dandelion/IMG_6154.jpg'),
#  PosixPath('Images/dandelion/IMG_1269.jpg'),
#  PosixPath('Images/dandelion/IMG_5580.jpg'),
#  PosixPath('Images/dandelion/IMG_3888.jpg'),
#  PosixPath('Images/dandelion/IMG_6101.jpg'),
#  PosixPath('Images/dandelion/IMG_1180.jpg'),
#  PosixPath('Images/dandelion/IMG_1123.jpg'),
#  PosixPath('Images/dandelion/IMG_6759.jpg'),
#  PosixPath('Images/dandelion/IMG_3895.jpg'),
#  PosixPath('Images/dandelion/IMG_3850.jpg'),
#  PosixPath('Images/dandelion/IMG_6712.jpg'),
#  PosixPath('Images/dandelion/IMG_1163.jpg'),
#  PosixPath('Images/dandelion/IMG_6721.jpg'),
#  PosixPath('Images/dandelion/IMG_6687.jpg'),
#  PosixPath('Images/dandelion/IMG_1326.jpg'),
#  PosixPath('Images/dandelion/IMG_6683.jpg'),
#  PosixPath('Images/dandelion/IMG_1242.jpg'),
#  PosixPath('Images/dandelion/IMG_7530.jpg'),
#  PosixPath('Images/dandelion/IMG_6690.jpg'),
#  PosixPath('Images/dandelion/IMG_1218.jpg'),
#  PosixPath('Images/dandelion/IMG_5599.jpg'),
#  PosixPath('Images/dandelion/IMG_1154.jpg'),
#  PosixPath('Images/dandelion/IMG_6706.jpg'),
#  PosixPath('Images/dandelion/IMG_3873.jpg'),
#  PosixPath('Images/dandelion/IMG_6696.jpg'),
#  PosixPath('Images/dandelion/IMG_7520.jpg'),
#  PosixPath('Images/dandelion/IMG_6110.jpg'),
#  PosixPath('Images/dandelion/IMG_3889.jpg'),
#  PosixPath('Images/dandelion/IMG_6716.jpg'),
#  PosixPath('Images/dandelion/IMG_3853.jpg'),
#  PosixPath('Images/dandelion/IMG_1152.jpg'),
#  PosixPath('Images/dandelion/IMG_1283.jpg'),
#  PosixPath('Images/dandelion/IMG_1244.jpg'),
#  PosixPath('Images/dandelion/IMG_5598.jpg'),
#  PosixPath('Images/dandelion/IMG_1310.jpg'),
#  PosixPath('Images/dandelion/IMG_5576.jpg'),
#  PosixPath('Images/dandelion/IMG_1122.jpg'),
#  PosixPath('Images/dandelion/IMG_1330.jpg'),
#  PosixPath('Images/dandelion/IMG_6128.jpg'),
#  PosixPath('Images/dandelion/IMG_1297.jpg'),
#  PosixPath('Images/dandelion/IMG_1248.jpg'),
#  PosixPath('Images/dandelion/IMG_3957.jpg'),
#  PosixPath('Images/dandelion/IMG_6723.jpg'),
#  PosixPath('Images/dandelion/IMG_3874.jpg'),
#  PosixPath('Images/dandelion/IMG_1164.jpg'),
#  PosixPath('Images/dandelion/IMG_1181.jpg'),
#  PosixPath('Images/dandelion/IMG_1325.jpg'),
#  PosixPath('Images/dandelion/IMG_1161.jpg'),
#  PosixPath('Images/dandelion/IMG_1140.jpg'),
#  PosixPath('Images/dandelion/IMG_5444.jpg'),
#  PosixPath('Images/dandelion/IMG_6126.jpg'),
#  PosixPath('Images/dandelion/IMG_6760.jpg'),
#  PosixPath('Images/dandelion/IMG_6695.jpg'),
#  PosixPath('Images/dandelion/IMG_3913.jpg'),
#  PosixPath('Images/dandelion/IMG_5429.jpg'),
#  PosixPath('Images/dandelion/IMG_1178.jpg'),
#  PosixPath('Images/dandelion/IMG_7524.jpg'),
#  PosixPath('Images/dandelion/IMG_5589.jpg'),
#  PosixPath('Images/dandelion/IMG_6685.jpg'),
#  PosixPath('Images/dandelion/IMG_1223.jpg'),
#  PosixPath('Images/dandelion/IMG_3910.jpg'),
#  PosixPath('Images/dandelion/IMG_6122.jpg'),
#  PosixPath('Images/dandelion/IMG_1136.jpg'),
#  PosixPath('Images/dandelion/IMG_5585.jpg'),
#  PosixPath('Images/dandelion/IMG_1272.jpg'),
#  PosixPath('Images/dandelion/IMG_7532.jpg'),
#  PosixPath('Images/dandelion/IMG_5403.jpg'),
#  PosixPath('Images/dandelion/IMG_7529.jpg'),
#  PosixPath('Images/dandelion/IMG_1119.jpg'),
#  ...]

# %%
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))
labels
# Out:
# ['other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  'dandelion',
#  ...]

# %%
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

image_df = pd.concat([filepaths, labels], axis=1)
image_df
# Out:
#                            Filepath      Label
# 0         Images/other/IMG_5663.jpg      other
# 1         Images/other/IMG_5468.jpg      other
# 2         Images/other/IMG_6262.jpg      other
# 3         Images/other/IMG_5915.jpg      other
# 4         Images/other/IMG_6520.jpg      other
# ...                             ...        ...
# 1257  Images/dandelion/IMG_1289.jpg  dandelion
# 1258  Images/dandelion/IMG_1307.jpg  dandelion
# 1259  Images/dandelion/IMG_1173.jpg  dandelion
# 1260  Images/dandelion/IMG_1270.jpg  dandelion
# 1261  Images/dandelion/IMG_1336.jpg  dandelion
#
# [1262 rows x 2 columns]

# %%
train_df, test_df = train_test_split(image_df, train_size=0.7, shuffle=True, random_state=1)

# %%
train_df
# Out:
#                            Filepath      Label
# 491       Images/other/IMG_5507.jpg      other
# 1091  Images/dandelion/IMG_5397.jpg  dandelion
# 512       Images/other/IMG_5643.jpg      other
# 919   Images/dandelion/IMG_1284.jpg  dandelion
# 741   Images/dandelion/IMG_3900.jpg  dandelion
# ...                             ...        ...
# 715   Images/dandelion/IMG_3934.jpg  dandelion
# 905   Images/dandelion/IMG_1133.jpg  dandelion
# 1096  Images/dandelion/IMG_3931.jpg  dandelion
# 235       Images/other/IMG_6246.jpg      other
# 1061  Images/dandelion/IMG_5605.jpg  dandelion
#
# [883 rows x 2 columns]

# %%
test_df
# Out:
#                            Filepath      Label
# 1180  Images/dandelion/IMG_1252.jpg  dandelion
# 255       Images/other/IMG_5994.jpg      other
# 304       Images/other/IMG_6256.jpg      other
# 403       Images/other/IMG_5648.jpg      other
# 75        Images/other/IMG_5801.jpg      other
# ...                             ...        ...
# 37        Images/other/IMG_5837.jpg      other
# 320       Images/other/IMG_5661.jpg      other
# 823   Images/dandelion/IMG_5702.jpg  dandelion
# 1017  Images/dandelion/IMG_1312.jpg  dandelion
# 584       Images/other/IMG_6233.jpg      other
#
# [379 rows x 2 columns]

# %% [markdown]
# ### Creating Generators

# %%
train_generator = ImageDataGenerator(
    preprocessing_function = tf.keras.applications.mobilenet_v2.preprocess_input,
    validation_split=0.2
)

test_generator = ImageDataGenerator(
    preprocessing_function = tf.keras.applications.mobilenet_v2.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode = 'rgb',
    class_mode = 'binary',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode = 'rgb',
    class_mode = 'binary',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='validation'
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode = 'rgb',
    class_mode = 'binary',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 707 validated image filenames belonging to 2 classes.
# Found 176 validated image filenames belonging to 2 classes.
# Found 379 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Downloading the Feature Extractor

# %%
feature_extractor = tf.keras.applications.MobileNetV2(
    input_shape = (224, 224, 3),
    weights = 'imagenet',
    include_top=False,
    pooling='avg'
)

feature_extractor.trainable = False
# Out:
# 2024-09-15 13:31:02.910462: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 7s 1us/step

# %% [markdown]
# ### Training

# %%
inputs = feature_extractor.input
x = tf.keras.layers.Dense(128, activation='relu')(feature_extractor.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)
outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
model = tf.keras.Model(inputs=inputs, outputs=outputs)
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 112, 112, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 112, 112, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 112, 112, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 112, 112, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 112, 112, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 112, 112, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 113, 113, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 56, 56, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 56, 56, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 56, 56, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 56, 56, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 56, 56, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 56, 56, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 56, 56, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 56, 56, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 56, 56, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 56, 56, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 56, 56, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 56, 56, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 56, 56, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 57, 57, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 28, 28, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 28, 28, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 28, 28, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 28, 28, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 28, 28, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 28, 28, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 28, 28, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 28, 28, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 28, 28, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 28, 28, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 28, 28, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 28, 28, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 28, 28, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 28, 28, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 29, 29, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 14, 14, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 14, 14, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 14, 14, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 14, 14, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 14, 14, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 14, 14, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 14, 14, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 14, 14, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 14, 14, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 14, 14, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 14, 14, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 14, 14, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 14, 14, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 14, 14, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 14, 14, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 14, 14, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 14, 14, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 14, 14, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 14, 14, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 14, 14, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 14, 14, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 14, 14, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 14, 14, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 14, 14, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 14, 14, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 14, 14, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 14, 14, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 14, 14, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 14, 14, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 15, 15, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 7, 7, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 7, 7, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 7, 7, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 7, 7, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 7, 7, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 7, 7, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 7, 7, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 7, 7, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 7, 7, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 7, 7, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 7, 7, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 7, 7, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 7, 7, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 7, 7, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 7, 7, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 7, 7, 1280)   0           ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['out_relu[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 128)          163968      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 128)          16512       ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 1)            129         ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 2,438,593
# Trainable params: 180,609
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________
# None

# %%
history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=100,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/100
# 2024-09-15 13:38:51.776434: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 23/23 [==============================] - ETA: 0s - loss: 0.5687 - accuracy: 0.6818
# 2024-09-15 13:42:10.121510: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 23/23 [==============================] - 250s 11s/step - loss: 0.5687 - accuracy: 0.6818 - val_loss: 0.4673 - val_accuracy: 0.7330
# Epoch 2/100
# 23/23 [==============================] - 286s 13s/step - loss: 0.3784 - accuracy: 0.8147 - val_loss: 0.4098 - val_accuracy: 0.7500
# Epoch 3/100
# 23/23 [==============================] - 233s 10s/step - loss: 0.2959 - accuracy: 0.8699 - val_loss: 0.3577 - val_accuracy: 0.8068
# Epoch 4/100
# 23/23 [==============================] - 266s 12s/step - loss: 0.2627 - accuracy: 0.8883 - val_loss: 0.3508 - val_accuracy: 0.8125
# Epoch 5/100
# 23/23 [==============================] - 266s 12s/step - loss: 0.2140 - accuracy: 0.9066 - val_loss: 0.3221 - val_accuracy: 0.8466
# Epoch 6/100
# 23/23 [==============================] - 232s 10s/step - loss: 0.1617 - accuracy: 0.9364 - val_loss: 0.3168 - val_accuracy: 0.8466
# Epoch 7/100
# 23/23 [==============================] - 230s 10s/step - loss: 0.2302 - accuracy: 0.9038 - val_loss: 0.3284 - val_accuracy: 0.8636
# Epoch 8/100
# 23/23 [==============================] - 232s 10s/step - loss: 0.1716 - accuracy: 0.9321 - val_loss: 0.3537 - val_accuracy: 0.8523
# Epoch 9/100
# 23/23 [==============================] - 232s 10s/step - loss: 0.1542 - accuracy: 0.9335 - val_loss: 0.3905 - val_accuracy: 0.8125

# %% [markdown]
# ### Results

# %%
predictions = np.squeeze(model.predict(test_images))
predictions = (predictions >= 0.5).astype(np.int32)

acc = accuracy_score(test_images.labels, predictions)
f1 = f1_score(test_images.labels, predictions)

print("Accuracy: {:.2f}%".format(acc * 100))
print("F1-Score: {:.5f}".format(f1))
# Out:
# 2024-09-15 15:11:35.355559: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 12/12 [==============================] - 116s 10s/step
# Accuracy: 84.96%
# F1-Score: 0.84718
