# %% [markdown]
# ## Netherlands Rent Prediction
#
# Given data about properties in the Netherlands, let's try to predict the rent for a given property.
#
# We will use a random forest pipeline regression model to make our predictions.
#
# Data source: https://www.kaggle.com/datasets/juangesino/netherlands-rent-properties?select=properties.json

# %% [markdown]
# ### Getting Started

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.ensemble import RandomForestRegressor

# %%
data = pd.read_json('properties.json', lines=True)
data
# Out:
#                                         _id      externalId areaRaw  areaSqm  \
# 0      {'$oid': '5d2b113a43cbfd7c77a998f4'}    room-1686123   14 m2       14
# 1      {'$oid': '5d2b113a43cbfd7c77a9991a'}  studio-1691193   30 m2       30
# 2      {'$oid': '5d2b113a43cbfd7c77a99931'}    room-1690545   11 m2       11
# 3      {'$oid': '5d2b113a43cbfd7c77a9994a'}    room-1680036   16 m2       16
# 4      {'$oid': '5d2b113b43cbfd7c77a9997c'}    room-1691356   22 m2       22
# ...                                     ...             ...     ...      ...
# 46717  {'$oid': '5e5dada77fc8c93d83042924'}    room-1774711   28 m2       28
# 46718  {'$oid': '5e5daddf7fc8c93d83043cfd'}    room-1774600   16 m2       16
# 46719  {'$oid': '5e5dade07fc8c93d83043d2d'}    room-1774595   30 m2       30
# 46720  {'$oid': '5e5dade27fc8c93d83043e7b'}    room-1774582   35 m2       35
# 46721  {'$oid': '5e5db1ad7fc8c93d8305b134'}  studio-1765323   25 m2       25
#
#             city                                      coverImageUrl  \
# 0      Rotterdam  https://resources.kamernet.nl/image/913b4b03-5...
# 1      Amsterdam  https://resources.kamernet.nl/image/5e11d6b5-8...
# 2      Amsterdam  https://resources.kamernet.nl/image/74b93a27-a...
# 3          Assen  https://resources.kamernet.nl/image/84e95365-6...
# 4      Rotterdam  https://resources.kamernet.nl/Content/images/p...
# ...          ...                                                ...
# 46717  Rotterdam  https://resources.kamernet.nl/image/198697b0-6...
# 46718   Harmelen  https://resources.kamernet.nl/image/8d75725a-d...
# 46719  Rotterdam  https://resources.kamernet.nl/image/481fb7dd-a...
# 46720  Rotterdam  https://resources.kamernet.nl/image/809ca8b1-c...
# 46721  Rotterdam  https://resources.kamernet.nl/image/203d5d86-9...
#
#       crawlStatus                                  crawledAt  \
# 0            done  {'$date': '2019-07-26T22:18:23.018+0000'}
# 1            done  {'$date': '2019-08-10T22:28:46.099+0000'}
# 2            done  {'$date': '2019-10-02T22:00:33.141+0000'}
# 3            done  {'$date': '2019-07-18T22:00:31.018+0000'}
# 4            done  {'$date': '2019-08-12T02:06:14.635+0000'}
# ...           ...                                        ...
# 46717        done  {'$date': '2020-03-03T01:06:47.516+0000'}
# 46718        done  {'$date': '2020-03-03T01:07:43.775+0000'}
# 46719        done  {'$date': '2020-03-03T01:07:43.947+0000'}
# 46720        done  {'$date': '2020-03-03T01:07:45.950+0000'}
# 46721        done  {'$date': '2020-03-03T01:23:57.716+0000'}
#
#                                           datesPublished  \
# 0      [{'$date': '2019-07-14T11:25:46.511+0000'}, {'...
# 1      [{'$date': '2019-07-14T11:25:46.677+0000'}, {'...
# 2      [{'$date': '2019-07-14T11:25:46.834+0000'}, {'...
# 3      [{'$date': '2019-07-14T11:25:46.988+0000'}, {'...
# 4      [{'$date': '2019-07-14T11:25:47.193+0000'}, {'...
# ...                                                  ...
# 46717        [{'$date': '2020-03-03T01:06:47.640+0000'}]
# 46718        [{'$date': '2020-03-03T01:07:43.898+0000'}]
# 46719        [{'$date': '2020-03-03T01:07:44.071+0000'}]
# 46720        [{'$date': '2020-03-03T01:07:46.072+0000'}]
# 46721        [{'$date': '2020-03-03T01:23:57.836+0000'}]
#
#                                      firstSeenAt      furnish  \
# 0      {'$date': '2019-07-14T11:25:46.511+0000'}  Unfurnished
# 1      {'$date': '2019-07-14T11:25:46.677+0000'}    Furnished
# 2      {'$date': '2019-07-14T11:25:46.834+0000'}    Furnished
# 3      {'$date': '2019-07-14T11:25:46.988+0000'}  Unfurnished
# 4      {'$date': '2019-07-14T11:25:47.193+0000'}  Unfurnished
# ...                                          ...          ...
# 46717  {'$date': '2020-03-03T01:06:47.640+0000'}    Furnished
# 46718  {'$date': '2020-03-03T01:07:43.898+0000'}    Furnished
# 46719  {'$date': '2020-03-03T01:07:44.071+0000'}    Furnished
# 46720  {'$date': '2020-03-03T01:07:46.072+0000'}    Furnished
# 46721  {'$date': '2020-03-03T01:23:57.836+0000'}    Furnished
#
#                                       lastSeenAt   latitude  longitude  \
# 0      {'$date': '2019-07-26T22:18:23.142+0000'}  51.896601   4.514993
# 1      {'$date': '2019-08-10T22:28:46.229+0000'}  52.370200   4.920721
# 2      {'$date': '2019-10-02T22:00:33.264+0000'}  52.350880   4.854786
# 3      {'$date': '2019-07-18T22:00:31.174+0000'}  53.013494   6.561012
# 4      {'$date': '2019-08-12T02:06:14.755+0000'}  51.932871   4.479732
# ...                                          ...        ...        ...
# 46717  {'$date': '2020-03-03T01:06:47.640+0000'}  51.928624   4.507187
# 46718  {'$date': '2020-03-03T01:07:43.898+0000'}  52.086568   4.959942
# 46719  {'$date': '2020-03-03T01:07:44.071+0000'}  51.928624   4.507187
# 46720  {'$date': '2020-03-03T01:07:46.072+0000'}  51.928624   4.507187
# 46721  {'$date': '2020-03-03T01:23:57.836+0000'}  51.921077   4.463528
#
#       postalCode postedAgo propertyType                rawAvailability  rent  \
# 0         3074HN        4w         Room  26-06-'19 - Indefinite period   500
# 1         1018AS        4w       Studio  15-08-'19 - Indefinite period   950
# 2         1075SB    09 Jul         Room  01-08-'19 - Indefinite period  1000
# 3         9407BG    17 Jun         Room  16-06-'19 - Indefinite period   290
# 4         3035AK        4w         Room  01-08-'19 - Indefinite period   475
# ...          ...       ...          ...                            ...   ...
# 46717     3061AG        2d         Room  01-03-'20 - Indefinite period   800
# 46718     3481VE        3d         Room  08-02-'20 - Indefinite period   400
# 46719     3061AG        3d         Room  01-03-'20 - Indefinite period   950
# 46720     3061AG        3d         Room  01-03-'20 - Indefinite period  1050
# 46721     3014CD        2w       Studio  01-05-'20 - Indefinite period   738
#
#             rentDetail                    rentRaw    source  \
# 0                                         € 500,-  kamernet
# 1      Utilities incl.   € 950,-  Utilities incl.  kamernet
# 2      Utilities incl.  € 1000,-  Utilities incl.  kamernet
# 3      Utilities incl.   € 290,-  Utilities incl.  kamernet
# 4      Utilities incl.   € 475,-  Utilities incl.  kamernet
# ...                ...                        ...       ...
# 46717                                     € 800,-  kamernet
# 46718  Utilities incl.   € 400,-  Utilities incl.  kamernet
# 46719                                     € 950,-  kamernet
# 46720  Utilities incl.  € 1050,-  Utilities incl.  kamernet
# 46721  Utilities incl.   € 738,-  Utilities incl.  kamernet
#
#                       title  \
# 0      West-Varkenoordseweg
# 1               Parelstraat
# 2                Zeilstraat
# 3               Ruiterakker
# 4           Zwart Janstraat
# ...                     ...
# 46717              Oudedijk
# 46718        Wilhelminalaan
# 46719              Oudedijk
# 46720              Oudedijk
# 46721        Henegouwerlaan
#
#                                                      url  additionalCosts  \
# 0      https://kamernet.nl/en/for-rent/room-rotterdam...             50.0
# 1      https://kamernet.nl/en/for-rent/studio-amsterd...              0.0
# 2      https://kamernet.nl/en/for-rent/room-amsterdam...              NaN
# 3      https://kamernet.nl/en/for-rent/room-assen/rui...              NaN
# 4      https://kamernet.nl/en/for-rent/room-rotterdam...              NaN
# ...                                                  ...              ...
# 46717  https://kamernet.nl/en/for-rent/room-rotterdam...            200.0
# 46718  https://kamernet.nl/en/for-rent/room-harmelen/...              NaN
# 46719  https://kamernet.nl/en/for-rent/room-rotterdam...            300.0
# 46720  https://kamernet.nl/en/for-rent/room-rotterdam...            300.0
# 46721  https://kamernet.nl/en/for-rent/studio-rotterd...              NaN
#
#                                       additionalCostsRaw  deposit  \
# 0      \n                            € 50\n          ...    500.0
# 1      \n                            € 0\n           ...    895.0
# 2      \n                            -\n             ...   1000.0
# 3                                                    -      290.0
# 4      \n                            -\n             ...    500.0
# ...                                                  ...      ...
# 46717                                              € 200   1000.0
# 46718                                                 NA      NaN
# 46719                                              € 300   1250.0
# 46720                                              € 300   1350.0
# 46721                                                 NA      NaN
#
#                                               depositRaw  \
# 0      \n                            € 500\n         ...
# 1      \n                            € 895\n         ...
# 2      \n                            € 1000\n        ...
# 3                                                € 290
# 4      \n                            € 500\n         ...
# ...                                                  ...
# 46717                                           € 1000
# 46718                                                -
# 46719                                           € 1250
# 46720                                           € 1350
# 46721                                                -
#
#                                 descriptionNonTranslated  \
# 0      Nice room for rent, accros the Feyenoord stadi...
# 1      Efficiently furnished, with a large balcony, a...
# 2      Kamer van 11m2 vlakbij het Vondelpark. Met een...
# 3      De kamer is 16m2De kamer is voorzien van een z...
# 4      gedeeltelijk gemeubileerd,met een kitchenette ...
# ...                                                  ...
# 46717  Recent available, completely furnished room in...
# 46718  Gerenoveerde zolderkamer te huur per direct.De...
# 46719  Beautiful, new furnished room/apartment in 5 m...
# 46720  Large, completely furnished room in 5 minutes ...
# 46721  Private room in apartment available from now!T...
#
#                              descriptionNonTranslatedRaw  \
# 0      \nNice room for rent, accros the Feyenoord sta...
# 1      \nEfficiently furnished, with a large balcony,...
# 2      \nKamer van 11m2 vlakbij het Vondelpark. Met e...
# 3       De kamer is 16m2<br><br>De kamer is voorzien ...
# 4      \ngedeeltelijk gemeubileerd,met een kitchenett...
# ...                                                  ...
# 46717   Recent available, completely furnished room i...
# 46718   Gerenoveerde zolderkamer te huur per direct.<...
# 46719   Beautiful, new furnished room/apartment in 5 ...
# 46720   Large, completely furnished room in 5 minutes...
# 46721   Private room in apartment available from now!...
#
#                                    descriptionTranslated  \
# 0      Nice room for rent, accros the Feyenoord stadi...
# 1      Efficiently furnished, with a large balcony, a...
# 2      Kamer van 11m2 vlakbij het Vondelpark. Met een...
# 3      De kamer is 16m2De kamer is voorzien van een z...
# 4
# ...                                                  ...
# 46717  Recent available, completely furnished room in...
# 46718
# 46719  Beautiful, new furnished room/apartment in 5 m...
# 46720  Large, completely furnished room in 5 minutes ...
# 46721  Private room in apartment available from now!T...
#
#                                 descriptionTranslatedRaw  \
# 0      \nNice room for rent, accros the Feyenoord sta...
# 1      \nEfficiently furnished, with a large balcony,...
# 2      \nKamer van 11m2 vlakbij het Vondelpark. Met e...
# 3       De kamer is 16m2<br><br>De kamer is voorzien ...
# 4                                             \n
# ...                                                  ...
# 46717   Recent available, completely furnished room i...
# 46718
# 46719   Beautiful, new furnished room/apartment in 5 ...
# 46720   Large, completely furnished room in 5 minutes...
# 46721   Private room in apartment available from now!...
#
#                                 detailsCrawledAt energyLabel   gender  \
# 0      {'$date': '2019-07-22T07:10:41.849+0000'}     Unknown    Mixed
# 1      {'$date': '2019-07-22T06:29:33.112+0000'}     Unknown  Unknown
# 2      {'$date': '2019-07-21T08:44:32.816+0000'}     Unknown    Mixed
# 3      {'$date': '2019-07-27T19:03:44.443+0000'}     Unknown   Female
# 4      {'$date': '2019-07-21T08:13:53.217+0000'}     Unknown     Male
# ...                                          ...         ...      ...
# 46717  {'$date': '2020-03-03T09:32:18.481+0000'}     Unknown  Unknown
# 46718  {'$date': '2020-03-03T08:30:24.981+0000'}     Unknown     Male
# 46719  {'$date': '2020-03-03T02:35:17.266+0000'}     Unknown  Unknown
# 46720  {'$date': '2020-03-03T06:31:13.654+0000'}     Unknown  Unknown
# 46721  {'$date': '2020-03-03T07:32:19.351+0000'}     Unknown     None
#
#       internet isRoomActive kitchen  living  \
# 0          Yes         true  Shared    None
# 1          Yes         true     Own     Own
# 2          Yes         true  Shared  Shared
# 3          Yes        false  Shared    None
# 4      Unknown         true     Own     Own
# ...        ...          ...     ...     ...
# 46717      Yes         true  Shared  Shared
# 46718      Yes         true  Shared  Shared
# 46719      Yes         true  Shared  Shared
# 46720      Yes         true  Shared  Shared
# 46721      Yes         true  Shared     Own
#
#                                                matchAge  \
# 0      16 years -\n                            99 years
# 1      18 years -\n                            99 years
# 2      16 years -\n                            93 years
# 3                                   18 years - 32 years
# 4      16 years -\n                            99 years
# ...                                                 ...
# 46717                               16 years - 99 years
# 46718                               16 years - 99 years
# 46719                               16 years - 99 years
# 46720                               16 years - 99 years
# 46721                               18 years - 99 years
#
#                                          matchAgeBackup matchCapacity  \
# 0      16 years -\n                            99 years      1 person
# 1      18 years -\n                            99 years      1 person
# 2      16 years -\n                            93 years      1 person
# 3                                   18 years - 32 years      1 person
# 4      16 years -\n                            99 years      1 person
# ...                                                 ...           ...
# 46717                               16 years - 99 years   > 5 persons
# 46718                               16 years - 99 years      1 person
# 46719                               16 years - 99 years   > 5 persons
# 46720                               16 years - 99 years      1 person
# 46721                               18 years - 99 years      1 person
#
#          matchGender matchGenderBackup matchLanguages  \
# 0      Not important     Not important  Not important
# 1      Not important     Not important  Not important
# 2      Not important     Not important  Not important
# 3             Female            Female  Not important
# 4               Male              Male  Not important
# ...              ...               ...            ...
# 46717  Not important     Not important  Not important
# 46718  Not important     Not important  Not important
# 46719  Not important     Not important  Not important
# 46720  Not important     Not important  Not important
# 46721         Female            Female  Not important
#
#                              matchStatus                  matchStatusBackup  \
# 0                          Not important                      Not important
# 1               Working student, Working           Working student, Working
# 2                          Not important                      Not important
# 3               Student, Working student           Student, Working student
# 4      Student, Working student, Working  Student, Working student, Working
# ...                                  ...                                ...
# 46717                      Not important                      Not important
# 46718                            Student                            Student
# 46719  Student, Working student, Working  Student, Working student, Working
# 46720  Student, Working student, Working  Student, Working student, Working
# 46721  Student, Working student, Working  Student, Working student, Working
#
#                                          pageDescription  \
# 0      Room for rent in Rotterdam,  West-Varkenoordse...
# 1      Studio for rent in Amsterdam,  Parelstraat, fo...
# 2      Room for rent in Amsterdam,  Zeilstraat, for €...
# 3      Room for rent in Assen,  Ruiterakker, for €290...
# 4      Room for rent in Rotterdam,  Zwart Janstraat, ...
# ...                                                  ...
# 46717  Room for rent in Rotterdam,  Oudedijk, for €80...
# 46718  Room for rent in Harmelen,  Wilhelminalaan, fo...
# 46719  Room for rent in Rotterdam,  Oudedijk, for €95...
# 46720  Room for rent in Rotterdam,  Oudedijk, for €10...
# 46721  Studio for rent in Rotterdam,  Henegouwerlaan,...
#
#                                           pageTitle pets registrationCost  \
# 0        Room for rent in Rotterdam €500 | Kamernet   No                0
# 1      Studio for rent in Amsterdam €950 | Kamernet   No                0
# 2       Room for rent in Amsterdam €1000 | Kamernet  Yes             None
# 3            Room for rent in Assen €290 | Kamernet   No             None
# 4        Room for rent in Rotterdam €475 | Kamernet   No             None
# ...                                             ...  ...              ...
# 46717    Room for rent in Rotterdam €800 | Kamernet   No             None
# 46718     Room for rent in Harmelen €400 | Kamernet   No             None
# 46719    Room for rent in Rotterdam €950 | Kamernet   No             None
# 46720   Room for rent in Rotterdam €1050 | Kamernet   No             None
# 46721  Studio for rent in Rotterdam €738 | Kamernet   No             None
#
#                                      registrationCostRaw roommates  shower  \
# 0      \n                            € 0\n           ...         5  Shared
# 1      \n                            € 0\n           ...      None     Own
# 2      \n                            -\n             ...         1  Shared
# 3                                                    -           4  Shared
# 4      \n                            -\n             ...         1  Shared
# ...                                                  ...       ...     ...
# 46717                                                 NA   Unknown  Shared
# 46718                                                 NA         2  Shared
# 46719                                                 NA   Unknown  Shared
# 46720                                                 NA         6  Shared
# 46721                                                 NA      None  Shared
#
#       smokingInside  toilet userDisplayName     userId userLastLoggedOn  \
# 0                No  Shared      Huize west  4680711.0       21-07-2019
# 1                No     Own             Cor  1865530.0       20-07-2019
# 2               Yes  Shared           Felix  4466569.0       20-07-2019
# 3               Yes  Shared          Albert   783341.0       26-07-2019
# 4                No  Shared            John  3338401.0       19-07-2019
# ...             ...     ...             ...        ...              ...
# 46717            No  Shared          Xandra  4490595.0       03-03-2020
# 46718            No  Shared          Michel  4356840.0       24-02-2020
# 46719            No  Shared          Xandra  4490595.0       02-03-2020
# 46720            No  Shared          Xandra  4490595.0       03-03-2020
# 46721            No  Shared       Geert-Jan  4756677.0       02-03-2020
#
#       userMemberSince                                       userPhotoUrl  \
# 0          26-06-2019  https://resources.kamernet.nl/Content/images/s...
# 1          05-01-2012  https://resources.kamernet.nl/Content/images/p...
# 2          05-07-2018  https://resources.kamernet.nl/Content/images/p...
# 3          09-11-2006  https://resources.kamernet.nl/Content/images/p...
# 4          24-08-2014  https://resources.kamernet.nl/image/3177baf7-5...
# ...               ...                                                ...
# 46717      08-08-2018  https://resources.kamernet.nl/image/1317498e-a...
# 46718      06-12-2017  https://resources.kamernet.nl/image/336ab03e-f...
# 46719      08-08-2018  https://resources.kamernet.nl/image/1317498e-a...
# 46720      08-08-2018  https://resources.kamernet.nl/image/1317498e-a...
# 46721      13-10-2019  https://resources.kamernet.nl/image/c609148f-e...
#
#       additionalCostsDescription
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 46717                        NaN
# 46718                         NA
# 46719                        NaN
# 46720                        NaN
# 46721                         NA
#
# [46722 rows x 62 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46722 entries, 0 to 46721
# Data columns (total 62 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   _id                          46722 non-null  object
#  1   externalId                   46722 non-null  object
#  2   areaRaw                      46722 non-null  object
#  3   areaSqm                      46722 non-null  int64
#  4   city                         46722 non-null  object
#  5   coverImageUrl                46722 non-null  object
#  6   crawlStatus                  46722 non-null  object
#  7   crawledAt                    46722 non-null  object
#  8   datesPublished               46722 non-null  object
#  9   firstSeenAt                  46722 non-null  object
#  10  furnish                      46722 non-null  object
#  11  lastSeenAt                   46722 non-null  object
#  12  latitude                     46722 non-null  float64
#  13  longitude                    46722 non-null  float64
#  14  postalCode                   46722 non-null  object
#  15  postedAgo                    46722 non-null  object
#  16  propertyType                 46722 non-null  object
#  17  rawAvailability              46722 non-null  object
#  18  rent                         46722 non-null  int64
#  19  rentDetail                   46722 non-null  object
#  20  rentRaw                      46722 non-null  object
#  21  source                       46722 non-null  object
#  22  title                        46722 non-null  object
#  23  url                          46722 non-null  object
#  24  additionalCosts              14301 non-null  float64
#  25  additionalCostsRaw           46622 non-null  object
#  26  deposit                      27704 non-null  float64
#  27  depositRaw                   46622 non-null  object
#  28  descriptionNonTranslated     46622 non-null  object
#  29  descriptionNonTranslatedRaw  46622 non-null  object
#  30  descriptionTranslated        46622 non-null  object
#  31  descriptionTranslatedRaw     46622 non-null  object
#  32  detailsCrawledAt             46722 non-null  object
#  33  energyLabel                  46622 non-null  object
#  34  gender                       45810 non-null  object
#  35  internet                     46622 non-null  object
#  36  isRoomActive                 46622 non-null  object
#  37  kitchen                      46622 non-null  object
#  38  living                       46622 non-null  object
#  39  matchAge                     46622 non-null  object
#  40  matchAgeBackup               46622 non-null  object
#  41  matchCapacity                46622 non-null  object
#  42  matchGender                  46622 non-null  object
#  43  matchGenderBackup            46622 non-null  object
#  44  matchLanguages               46622 non-null  object
#  45  matchStatus                  46622 non-null  object
#  46  matchStatusBackup            46622 non-null  object
#  47  pageDescription              46622 non-null  object
#  48  pageTitle                    46622 non-null  object
#  49  pets                         46622 non-null  object
#  50  registrationCost             4688 non-null   object
#  51  registrationCostRaw          46622 non-null  object
#  52  roommates                    45810 non-null  object
#  53  shower                       46622 non-null  object
#  54  smokingInside                46622 non-null  object
#  55  toilet                       46622 non-null  object
#  56  userDisplayName              46622 non-null  object
#  57  userId                       46622 non-null  float64
#  58  userLastLoggedOn             46622 non-null  object
#  59  userMemberSince              46622 non-null  object
#  60  userPhotoUrl                 46622 non-null  object
#  61  additionalCostsDescription   20546 non-null  object
# dtypes: float64(5), int64(2), object(55)
# memory usage: 22.1+ MB

# %% [markdown]
# ### Preprocessing

# %%
def preprocess_inputs(df):
    df = df.copy()

    # Drop bad rows
    bad_rows = df.query('crawlStatus == "unavailable"').index
    df = df.drop(bad_rows, axis=0).reset_index(drop=True)
    
    # Use only select features 
    df = df[[
        'areaSqm',
        'city',
        'furnish',
        'latitude',
        'longitude',
        'propertyType',
        'rent',
        'internet',
        'kitchen',
        'living',
        'pets',
        'shower',
        'smokingInside',
        'toilet'
    ]]

    # Encode improper values
    df = df.replace({'': np.NaN, 'Unknown': np.NaN})

    # Fill missing values
    missing_value_columns = df.columns[df.isna().sum() > 0]
    for column in missing_value_columns:
        df[column] = df[column].fillna(df[column].mode()[0])

    # Split df into X and y
    y = df['rent']
    X = df.drop('rent', axis=1)

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=True, random_state=1)
    
    return X_train, X_test, y_train, y_test, X

# %%
X_train, X_test, y_train, y_test, X = preprocess_inputs(data)

# %%
X_train
# Out:
#        areaSqm       city      furnish   latitude  longitude propertyType  \
# 29791       61  Rotterdam  Unfurnished  51.925125   4.486212    Apartment
# 44827       45  Rotterdam  Unfurnished  51.893369   4.517075    Apartment
# 37089      105  Amsterdam    Furnished  52.376979   4.839116    Apartment
# 13269       20      Delft   Uncarpeted  51.996010   4.352954         Room
# 14654       44  Rotterdam    Furnished  51.891709   4.480317    Apartment
# ...        ...        ...          ...        ...        ...          ...
# 43723       11   Enschede  Unfurnished  52.234413   6.849043         Room
# 32511       21    Utrecht    Furnished  52.086425   5.125311         Room
# 5192        16  Groningen    Furnished  53.229623   6.524759         Room
# 12172        7    Utrecht    Furnished  52.102119   5.096010         Room
# 33003       80    Utrecht    Furnished  52.096510   5.112070    Apartment
#
#       internet kitchen  living                 pets  shower  smokingInside  \
# 29791      Yes  Shared  Shared                   No  Shared             No
# 44827      Yes     Own     Own                   No     Own             No
# 37089      Yes     Own     Own                   No     Own             No
# 13269      Yes  Shared  Shared  By mutual agreement  Shared  Not important
# 14654      Yes  Shared  Shared                   No  Shared             No
# ...        ...     ...     ...                  ...     ...            ...
# 43723      Yes  Shared  Shared                   No  Shared             No
# 32511      Yes  Shared  Shared                   No  Shared             No
# 5192       Yes  Shared  Shared                   No  Shared             No
# 12172      Yes  Shared    None                   No  Shared             No
# 33003      Yes     Own     Own                   No     Own             No
#
#        toilet
# 29791  Shared
# 44827     Own
# 37089     Own
# 13269  Shared
# 14654  Shared
# ...       ...
# 43723  Shared
# 32511  Shared
# 5192   Shared
# 12172  Shared
# 33003     Own
#
# [32635 rows x 13 columns]

# %%
y_train
# Out:
# 29791    1195
# 44827     950
# 37089    1500
# 13269     330
# 14654     845
#          ...
# 43723     310
# 32511     435
# 5192      325
# 12172     175
# 33003    1495
# Name: rent, Length: 32635, dtype: int64

# %%
{column: list(X[column].unique()) for column in X.select_dtypes('object').columns}
# Out:
# {'city': ['Rotterdam',
#   'Amsterdam',
#   'Assen',
#   'Groningen',
#   'Zeist',
#   'Maastricht',
#   'Callantsoog',
#   'Alphen aan den Rijn',
#   'Tilburg',
#   'Enschede',
#   'Leeuwarden',
#   'Eindhoven',
#   'Wageningen',
#   'Diemen',
#   'Utrecht',
#   'Almere',
#   'Alkmaar',
#   'Harderwijk',
#   'Hilversum',
#   'Delft',
#   'Den Bosch',
#   'Stoutenburg',
#   'Leiden',
#   'Den Haag',
#   'Boxtel',
#   'Badhoevedorp',
#   'Veenendaal',
#   'Amstelveen',
#   'Nijmegen',
#   'Venlo',
#   'Zwolle',
#   'Ubbena',
#   'Arnhem',
#   'Leimuiden',
#   'Riel',
#   'Nieuwegein',
#   'Haren Gn',
#   'Uitgeest',
#   'Beverwijk',
#   'Ede',
#   'Nijkerk',
#   'Amersfoort',
#   'Loosdrecht',
#   'Apeldoorn',
#   'Vaals',
#   'Velp',
#   'Vlaardingen',
#   'Montfoort',
#   'Heemstede',
#   'Breda',
#   'Purmerend',
#   'Baarn',
#   'Spijkenisse',
#   'Deventer',
#   'Hengelo',
#   'Capelle aan den IJssel',
#   'Bovenkarspel',
#   'Weesp',
#   'Harskamp',
#   'Zeeland',
#   'Waalre',
#   'IJsselstein',
#   'Pijnacker',
#   'Sittard',
#   'Putten',
#   'Vlissingen',
#   'Haarlem',
#   'Rijswijk',
#   'Zandvoort',
#   'Zutphen',
#   'Heerlen',
#   'Breukeleveen',
#   'Hoofddorp',
#   'Hoensbroek',
#   'Rosmalen',
#   'Son en Breugel',
#   'Etten-Leur',
#   'Dordrecht',
#   'Bergschenhoek',
#   'Almelo',
#   'Wijchen',
#   'Zaandam',
#   'Zoetermeer',
#   'Gouda',
#   'Oudorp',
#   'Haule',
#   'Uithoorn',
#   'Oss',
#   'Beuningen Gld',
#   'Lelystad',
#   'Houten',
#   'Wenum Wiesel',
#   'Warmenhuizen',
#   'Hattem',
#   'Schiedam',
#   'Leerdam',
#   'Hellevoetsluis',
#   'Delden',
#   'Veldhoven',
#   'Best',
#   'Leersum',
#   'Twello',
#   'Wassenaar',
#   'De Bilt',
#   'Oud-Beijerland',
#   'Halfweg',
#   'Vreeland',
#   'Winterswijk',
#   'Stadskanaal',
#   'Heemskerk',
#   'Ammerzoden',
#   'Vries',
#   'Voorburg',
#   'Coevorden',
#   'Wijk aan Zee',
#   'Haelen',
#   'Zaltbommel',
#   'Bedum',
#   'Werkhoven',
#   'Sint Pancras',
#   'Raamsdonksveer',
#   'Hooghalen',
#   'Moergestel',
#   'Vinkeveen',
#   'Beek (gem Ubbergen)',
#   'Bunnik',
#   'Cuijk',
#   'Berg en Dal',
#   'Barneveld',
#   'Uden',
#   'Keijenborg',
#   'Roden',
#   'Abcoude',
#   'Wormerveer',
#   'Katwijk',
#   'Medemblik',
#   'Valkenswaard',
#   'Neerkant',
#   'Wehl',
#   'Weert',
#   'Schermerhorn',
#   'Gieten',
#   'Geldrop',
#   'Mierlo',
#   'Roermond',
#   'Bemmel',
#   'Lisse',
#   'Beneden-Leeuwen',
#   'Berlicum',
#   'Valkenburg',
#   'Nuenen',
#   'Leiderdorp',
#   'Soest',
#   'De Rijp',
#   'Hattemerbroek',
#   'Maassluis',
#   'Maarssen',
#   'Marsum',
#   'Helmond',
#   'Malden',
#   'Cadier en Keer',
#   'Hoorn',
#   'Nieuwveen',
#   'Slochteren',
#   'Dongen',
#   'Ouderkerk aan de Amstel',
#   'Scherpenzeel',
#   'Terneuzen',
#   'Zoeterwoude',
#   'Heeswijk-Dinther',
#   'Sassenheim',
#   'Voorschoten',
#   'Oudehaske',
#   'Peize',
#   'Beilen',
#   'Heesch',
#   'Wierden',
#   'Geleen',
#   'Ommen',
#   'IJmuiden',
#   'Vijfhuizen',
#   'Huizen',
#   'Castricum',
#   'Vrouwenparochie',
#   'Emmen',
#   'Doorn',
#   'Hoevelaken',
#   'Roelofarendsveen',
#   'Zuidhorn',
#   'Grou',
#   'Zwaag',
#   'Bussum',
#   'Haaften',
#   'Cromvoirt',
#   'Zeddam',
#   'Vught',
#   'Budel',
#   'Bunschoten-Spakenburg',
#   'Venhorst',
#   'Aalsmeer',
#   'Smilde',
#   'Nieuwe Pekela',
#   'De Wilp',
#   'Tolbert',
#   'Termunterzijl',
#   'Visvliet',
#   'Elst',
#   'Bennekom',
#   'Leusden',
#   'Lunteren',
#   'Westervoort',
#   'Doetinchem',
#   'Oudenbosch',
#   'Oudkarspel',
#   'De Meern',
#   'Exloo',
#   'Voerendaal',
#   'Dalfsen',
#   'Hoogerheide',
#   'Bilthoven',
#   'Woerden',
#   'Surhuizum',
#   'Woubrugge',
#   'Voorhout',
#   'Eijsden',
#   'Tegelen',
#   'Sprang-Capelle',
#   'Doorwerth',
#   'Hoogeveen',
#   'Eygelshoven',
#   'Groenekan',
#   'Dronten',
#   'Nistelrode',
#   'Duivendrecht',
#   'Hoenderloo',
#   'Meppel',
#   'Noordwijk',
#   'Roosendaal',
#   'Olst',
#   'Wateringen',
#   'Dokkum',
#   'Steenwijk',
#   'Rijpwetering',
#   'Hoogezand',
#   'Den Helder',
#   'Moordrecht',
#   'Reusel',
#   'Velsen-Noord',
#   'Beekbergen',
#   'Teuge',
#   'Vianen',
#   'Nieuwersluis',
#   'Bentveld',
#   'De Kwakel',
#   'Barendrecht',
#   'Kudelstaart',
#   'Didam',
#   'Baak',
#   'Leuth',
#   'Veendam',
#   'Molenhoek',
#   'Velserbroek',
#   'Gronsveld',
#   'Middenmeer',
#   'Eerbeek',
#   'Goirle',
#   'Gaanderen',
#   'Renkum',
#   'Sliedrecht',
#   'Oost West en Middelbeers',
#   'Ewijk',
#   'Geulle',
#   'Puttershoek',
#   'Belfeld',
#   'Delfgauw',
#   'Oosterbeek',
#   'Lisserbroek',
#   'Enkhuizen',
#   'Mill',
#   'Heumen',
#   'Meerssen',
#   'Nuland',
#   'Loenen',
#   'Huissen',
#   'Heerenveen',
#   'Dwingeloo',
#   'Persingen',
#   'Voorst',
#   'Naarden',
#   'Rheden',
#   'Markelo',
#   'Laren',
#   'Rilland',
#   'Groesbeek',
#   'Zennewijnen',
#   'Hasselt',
#   'Vroomshoop',
#   'Heino',
#   'Elburg',
#   'Nieuwleusen',
#   'Hillegom',
#   'Wijhe',
#   'Oldenzaal',
#   'Bunde',
#   'Brunssum',
#   'Venhuizen',
#   "'s-Graveland",
#   'Landgraaf',
#   'Mander',
#   'Oene',
#   'Eersel',
#   'Linden',
#   'Veghel',
#   'Buitenkaag',
#   'Monnickendam',
#   'Maarheeze',
#   'Heel',
#   'Kerkrade',
#   'Oirschot',
#   'Dieren',
#   'Oisterwijk',
#   'Haaksbergen',
#   'Heeze',
#   'Huisseling',
#   'Kampen',
#   'Harmelen',
#   'Angerlo',
#   'Goes',
#   'Oostrum',
#   'Oegstgeest',
#   'Klazienaveen',
#   'Baarlo (LB)',
#   'Mijdrecht',
#   'Ruinerwold',
#   'Gemert',
#   'Sappemeer',
#   'Wagenberg',
#   'Berkel-Enschot',
#   'Staphorst',
#   'Ermelo',
#   'Leidschendam',
#   'Nieuw-Vennep',
#   'Deurne',
#   'Werkendam',
#   'Koog aan de Zaan',
#   'Velp (NB)',
#   'Wilnis',
#   'Montfort',
#   'Limmen',
#   'Kerkdriel',
#   'Assendelft',
#   'Schoorl',
#   'Oosterhout',
#   'Foxhol',
#   'Hoogvliet Rotterdam',
#   'Rhenen',
#   'Boxmeer',
#   'Bavel',
#   'Drempt',
#   'Hummelo',
#   'Zuiderwoude',
#   'Kortenhoef',
#   'Garderen',
#   'Bemelen',
#   'Rijsenhout',
#   'Vaassen',
#   'Lieshout',
#   'Ulvenhout AC',
#   'Rhenoy',
#   'Waalwijk',
#   'Nederweert',
#   'Burgum',
#   'Rijnsburg',
#   'Katwijk NB',
#   'Ridderkerk',
#   'Groot-Ammers',
#   'Winsum',
#   'Wervershoof',
#   'Nijensleek',
#   'Zuidwolde',
#   'Randwijk',
#   'Klarenbeek',
#   'Noordwijkerhout',
#   'Zevenaar',
#   'Hengevelde',
#   'Appingedam',
#   'Delfzijl',
#   'Bergen (NH)',
#   'Heerhugowaard',
#   'Borger',
#   'Wieringerwaard',
#   'Odijk',
#   'Koedijk',
#   'Boksum',
#   'Ingen',
#   'Epse',
#   'Voorthuizen',
#   'Drachten',
#   'Schijndel',
#   'Soesterberg',
#   'Culemborg',
#   'Driebergen-Rijsenburg',
#   'Heusden',
#   'Zwijndrecht',
#   'Ubbergen',
#   'Rozenburg',
#   'Wanneperveen',
#   'Asten',
#   'Epe',
#   'Loenen aan de Vecht',
#   'Schellinkhout',
#   'Heerde',
#   'Zevenbergen',
#   'Eibergen',
#   'Wolvega',
#   'Opmeer',
#   'Warmond',
#   'Ressen',
#   'Lathum',
#   'Schipluiden',
#   'Leende',
#   'Hooge Zwaluwe',
#   'Hoogland',
#   'Goutum',
#   'Wormer',
#   'Zwanenburg',
#   'Vlijmen',
#   "'t Waar",
#   'Bleskensgraaf ca',
#   'Kockengen',
#   'Ten Post',
#   'Sint Odilienberg',
#   'Musselkanaal',
#   'de Lutte',
#   'Waarland',
#   'Albergen',
#   'Budel-Dorplein',
#   'Nunspeet',
#   'Meerkerk',
#   'Hoek van Holland',
#   'Waddinxveen',
#   'Eemnes',
#   'Lage Zwaluwe',
#   'Overloon',
#   'Zeegse',
#   'Loon op Zand',
#   'Overveen',
#   'Beinsdorp',
#   'Deest',
#   'Bosch en Duin',
#   'Benthuizen',
#   'Rijen',
#   'Geffen',
#   'Meteren',
#   'Weurt',
#   'Hardenberg',
#   'Wapenveld',
#   'Lith',
#   'Zuidlaren',
#   'Beuningen',
#   'Maria Hoop',
#   'Vleuten',
#   'Wezep',
#   'Tiendeveen',
#   'Naaldwijk',
#   'Boskoop',
#   'Heteren',
#   'Tiel',
#   'Swifterbant',
#   'Alblasserdam',
#   'Merselo',
#   'Vinkel',
#   'Ambt Delden',
#   'Sneek',
#   'St. Willebrord',
#   'Ankeveen',
#   'Aalst',
#   'Pernis Rotterdam',
#   'Twijzel',
#   'Stolwijk',
#   'Herveld',
#   'Haarsteeg',
#   'Grave',
#   'Brakel',
#   'Bergen op Zoom',
#   'Oost-Souburg',
#   'Maren-Kessel',
#   'Noordbroek',
#   'Hem',
#   'Mook',
#   'Buitenpost',
#   'Lopikerkapel',
#   'Onstwedde',
#   'Brantgum',
#   'Tynaarlo',
#   'Horn',
#   'Tricht',
#   'Stellendam',
#   'Goedereede',
#   'Egmond aan Zee',
#   'Bad Nieuweschans',
#   'Anloo',
#   'Wamel',
#   'Groenlo',
#   'Wessem',
#   'Edam',
#   'Burgerbrug',
#   'Raalte',
#   'Heelsum',
#   'Liempde',
#   'Doesburg',
#   'Koudekerk aan den Rijn',
#   'Wittem',
#   'Amerongen',
#   'Sint Jansklooster',
#   'Galder',
#   'Wijk bij Duurstede',
#   'Nijverdal',
#   'Westzaan',
#   'Middelburg',
#   'Akkrum',
#   'Plasmolen',
#   'Lent',
#   'Rijssen',
#   'Heiloo',
#   'Sint-Michielsgestel',
#   'Leek',
#   'Venray',
#   'Simpelveld',
#   'Gorinchem',
#   'Maarn',
#   'Nijeveen',
#   'Schagen',
#   'Mantinge',
#   'Deursen-Dennenburg',
#   'Dedemsvaart',
#   'Bleiswijk',
#   'Huis ter Heide',
#   "'s-Gravenzande",
#   'Melick',
#   'Achterveld (UT)',
#   'Woudenberg',
#   'Hulshorst',
#   'Woerdense Verlaat',
#   'Hardinxveld-Giessendam',
#   'Nootdorp',
#   'Wesepe',
#   'Berkel en Rodenrijs',
#   'Gilze',
#   'Hilvarenbeek',
#   'Winssen',
#   'Grootebroek',
#   'Groet',
#   'Heerewaarden',
#   'Hazerswoude-Dorp',
#   'Kamerik',
#   'Gennep',
#   'Kwintsheul',
#   'Breukelen',
#   'Sint Geertruid',
#   'Warnsveld',
#   'Kraggenburg',
#   'Hooglanderveen',
#   'Rheezerveen',
#   'Wernhout',
#   'Westerbroek',
#   'Ysselsteyn',
#   'Lochem',
#   'Kolhorn',
#   'Kesteren',
#   'Colijnsplaat',
#   'Bakel',
#   'Nieuw-Balinge',
#   'Made',
#   'Aadorp',
#   'Buggenum',
#   'Krommenie',
#   'Zaandijk',
#   'Ameide',
#   'Den Ilp',
#   'Geldermalsen',
#   'Nederhorst den Berg',
#   'Egmond aan den Hoef',
#   'Hendrik-Ido-Ambacht',
#   'De Steeg',
#   'Drongelen',
#   'Kamperland',
#   'Veeningen',
#   'Sint-Oedenrode',
#   'Zeewolde',
#   'Ter Aar',
#   'Den Ham (GR)',
#   'Borne',
#   'Etten',
#   'Zwartsluis',
#   'Drunen',
#   'Landsmeer',
#   'Stevensweert',
#   'Herkenbosch',
#   'Reeuwijk',
#   'Hoogmade',
#   'Hoeven',
#   'Oud Gastel',
#   'Kimswerd',
#   'Lijnden',
#   'Dorst',
#   'Geeuwenbrug',
#   'Garmerwolde',
#   'Aduard',
#   'Koudekerke',
#   'Hall',
#   'Langbroek',
#   'Knegsel',
#   'Berg en Terblijt',
#   'Papendrecht',
#   'Winterswijk Woold',
#   'Lierop',
#   'Nuth',
#   'Blaricum',
#   'Aarle-Rixtel',
#   'Krimpen aan den IJssel',
#   'Nieuwkuijk',
#   'Axel',
#   'Kropswolde',
#   'Schalkwijk',
#   'Westerland',
#   'Vierhouten',
#   'Duiven',
#   'Tubbergen',
#   'Schinveld',
#   'Waardenburg',
#   'Nieuwe Niedorp',
#   'Oostvoorne',
#   'Loenersloot',
#   'Ospel',
#   'Schalkhaar',
#   'Gendt',
#   'Margraten',
#   'Kaatsheuvel',
#   'Schin op Geul',
#   'Hurdegaryp',
#   'Vessem',
#   'Eelde',
#   'De Lier',
#   'Jorwert',
#   'Bergeijk',
#   'Surhuisterveen',
#   'Terborg',
#   'Raamsdonk',
#   'Marum',
#   'Aldtsjerk',
#   'Farmsum',
#   'Vijlen',
#   'Den Horn',
#   "'t Goy",
#   'Oudeschip',
#   'Noordscheschut',
#   'Zundert',
#   'Barsingerhorn',
#   'Oosthuizen',
#   'Middenbeemster',
#   'Cadzand',
#   'Schaijk',
#   'Zwammerdam',
#   'Stiens',
#   'Klundert',
#   'Bocholtz',
#   'Schoonhoven',
#   "'t Harde",
#   'Rijsbergen',
#   'IJsselmuiden',
#   'Aarlanderveen',
#   'Biezenmortel',
#   'Harkstede GN',
#   'Wintelre',
#   'Gulpen',
#   'Boekel',
#   'Berghem',
#   'Oldehove',
#   'Warffum',
#   'Harlingen',
#   'Avenhorn',
#   'Purmerland',
#   'Veenhuizen',
#   'Winschoten',
#   'Rhoon',
#   'Oude Pekela',
#   'Bitgummole',
#   'Lopik',
#   'Escharen',
#   'Oude Meer',
#   'Stein',
#   'Deil',
#   'Thesinge',
#   'Prinsenbeek',
#   'Franeker',
#   'Herten',
#   'Steensel',
#   'Netersel',
#   'Hoogkarspel',
#   'Eethen',
#   "'s-Heerenberg",
#   'Austerlitz',
#   'Nietap',
#   'Otterlo',
#   'Hedel',
#   'Godlinze',
#   'Elsloo',
#   'Zierikzee',
#   'Est',
#   'Vasse',
#   'Diessen',
#   'Stieltjeskanaal',
#   'Terheijden',
#   'Broekhuizenvorst',
#   'Bentelo',
#   'Den Hoorn (ZH)',
#   'Winkel',
#   'Luyksgestel',
#   'Born',
#   'Geertruidenberg',
#   'Blije',
#   'Krimpen aan de Lek',
#   'Liessel',
#   'Genemuiden',
#   'Rockanje',
#   'Brielle',
#   'amsterdam',
#   'Kiel-Windeweer',
#   'Rumpt',
#   'Serooskerke',
#   'Beek (LB)',
#   'Kloosterburen',
#   'Rekken',
#   'Berltsum',
#   'Benschop',
#   'Elst Ut'],
#  'furnish': ['Unfurnished', 'Furnished', 'Uncarpeted'],
#  'propertyType': ['Room',
#   'Studio',
#   'Apartment',
#   'Anti-squat',
#   'Student residence'],
#  'internet': ['Yes', 'No'],
#  'kitchen': ['Shared', 'Own', 'None'],
#  'living': ['None', 'Own', 'Shared'],
#  'pets': ['No', 'Yes', 'By mutual agreement'],
#  'shower': ['Shared', 'Own', 'None'],
#  'smokingInside': ['No', 'Yes', 'Not important'],
#  'toilet': ['Shared', 'Own', 'None']}

# %%
X.isna().mean()
# Out:
# areaSqm          0.0
# city             0.0
# furnish          0.0
# latitude         0.0
# longitude        0.0
# propertyType     0.0
# rent             0.0
# internet         0.0
# kitchen          0.0
# living           0.0
# pets             0.0
# shower           0.0
# smokingInside    0.0
# toilet           0.0
# dtype: float64

# %% [markdown]
# ### Building Pipeline and Training

# %%
{column: len(X[column].unique()) for column in X.select_dtypes('object').columns}
# Out:
# {'city': 737,
#  'furnish': 3,
#  'propertyType': 5,
#  'internet': 2,
#  'kitchen': 3,
#  'living': 3,
#  'pets': 3,
#  'shower': 3,
#  'smokingInside': 3,
#  'toilet': 3}

# %%
pd.get_dummies(X['internet'], dtype=int).drop('No', axis=1)
# Out:
#        Yes
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 46617    1
# 46618    1
# 46619    1
# 46620    1
# 46621    1
#
# [46622 rows x 1 columns]

# %%
nominal_features = [
    'city',
    'furnish',
    'propertyType',
    'kitchen',
    'living',
    'pets',
    'shower',
    'smokingInside',
    'toilet'
]

binary_transformer = Pipeline(steps=[
    ('ordinal', OrdinalEncoder())
])

nominal_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(sparse_output=False, handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(transformers=[
    ('binary', binary_transformer, ['internet']),
    ('nominal', nominal_transformer, nominal_features)
], remainder='passthrough')

model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor())
])

# %%
model.fit(X_train, y_train)
# Out:
# /home/aditya/miniconda3/envs/ds-env/lib/python3.10/site-packages/sklearn/compose/_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('binary',
#                                                   Pipeline(steps=[('ordinal',
#                                                                    OrdinalEncoder())]),
#                                                   ['internet']),
#                                                  ('nominal',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['city', 'furnish',
#                                                    'propertyType', 'kitchen',
#                                                    'living', 'pets', 'shower',
#                                                    'smokingInside',
#                                                    'toilet'])])),
#                 ('regressor', RandomForestRegressor())])

# %% [markdown]
# ### Results

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([ 444.195     ,  911.9       ,  339.985     , ..., 1334.43333333,
#         362.47238095,  447.27      ])

# %%
np.sqrt(np.mean((y_test - y_pred)**2))
# Out:
# 157.26574575056125

# %%
y_test.describe()
# Out:
# count    13987.000000
# mean       664.911561
# std        413.872062
# min          1.000000
# 25%        390.000000
# 50%        550.000000
# 75%        800.000000
# max       5000.000000
# Name: rent, dtype: float64

# %%
r2 = 1 - (np.sum((y_test - y_pred)**2) / np.sum((y_test - y_test.mean())**2))
rmse = np.sqrt(np.mean((y_test - y_pred)**2))
print('RMSE: {:.2f}'.format(rmse))
print('R^2 Score: {:.5f}'.format(r2))
# Out:
# RMSE: 157.27
# R^2 Score: 0.85560

# %%
# Out:
# 157.26574575056125
