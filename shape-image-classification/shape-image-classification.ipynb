# %% [markdown]
# ## Shape Image Classification
#
# Given *images of shapes,* let's try to predict which **stage** is present in a given image.
#
# We will use a Tensorflow/Keras convolutional neural network to make our predictions.
#
# Data Source: https://www.kaggle.com/datasets/cactus3/basicshapes

# %% [markdown]
# ### Getting Started

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path

from sklearn.model_selection import train_test_split

import tensorflow as tf
# Out:
# 2024-12-11 09:35:23.024898: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
image_dir = Path('shapes')

# %% [markdown]
# ### Creating File DataFrame

# %%
filepaths = list(image_dir.glob(r'**/*.png'))
filepaths
# Out:
# [PosixPath('shapes/circles/drawing(78).png'),
#  PosixPath('shapes/circles/drawing(2).png'),
#  PosixPath('shapes/circles/drawing(92).png'),
#  PosixPath('shapes/circles/drawing(58).png'),
#  PosixPath('shapes/circles/drawing(10).png'),
#  PosixPath('shapes/circles/drawing(31).png'),
#  PosixPath('shapes/circles/drawing(13).png'),
#  PosixPath('shapes/circles/drawing(55).png'),
#  PosixPath('shapes/circles/drawing(27).png'),
#  PosixPath('shapes/circles/drawing(24).png'),
#  PosixPath('shapes/circles/drawing(74).png'),
#  PosixPath('shapes/circles/drawing(59).png'),
#  PosixPath('shapes/circles/drawing(67).png'),
#  PosixPath('shapes/circles/drawing(39).png'),
#  PosixPath('shapes/circles/drawing(3).png'),
#  PosixPath('shapes/circles/drawing(30).png'),
#  PosixPath('shapes/circles/drawing(18).png'),
#  PosixPath('shapes/circles/drawing(42).png'),
#  PosixPath('shapes/circles/drawing(45).png'),
#  PosixPath('shapes/circles/drawing(7).png'),
#  PosixPath('shapes/circles/drawing(56).png'),
#  PosixPath('shapes/circles/drawing(79).png'),
#  PosixPath('shapes/circles/drawing(33).png'),
#  PosixPath('shapes/circles/drawing(4).png'),
#  PosixPath('shapes/circles/drawing(65).png'),
#  PosixPath('shapes/circles/drawing(26).png'),
#  PosixPath('shapes/circles/drawing(38).png'),
#  PosixPath('shapes/circles/drawing(43).png'),
#  PosixPath('shapes/circles/drawing(15).png'),
#  PosixPath('shapes/circles/drawing(36).png'),
#  PosixPath('shapes/circles/drawing(25).png'),
#  PosixPath('shapes/circles/drawing(40).png'),
#  PosixPath('shapes/circles/drawing(72).png'),
#  PosixPath('shapes/circles/drawing(28).png'),
#  PosixPath('shapes/circles/drawing(47).png'),
#  PosixPath('shapes/circles/drawing(97).png'),
#  PosixPath('shapes/circles/drawing(17).png'),
#  PosixPath('shapes/circles/drawing(52).png'),
#  PosixPath('shapes/circles/drawing(71).png'),
#  PosixPath('shapes/circles/drawing(23).png'),
#  PosixPath('shapes/circles/drawing(90).png'),
#  PosixPath('shapes/circles/drawing(46).png'),
#  PosixPath('shapes/circles/drawing(50).png'),
#  PosixPath('shapes/circles/drawing(70).png'),
#  PosixPath('shapes/circles/drawing(60).png'),
#  PosixPath('shapes/circles/drawing(63).png'),
#  PosixPath('shapes/circles/drawing(51).png'),
#  PosixPath('shapes/circles/drawing(99).png'),
#  PosixPath('shapes/circles/drawing(87).png'),
#  PosixPath('shapes/circles/drawing(73).png'),
#  PosixPath('shapes/circles/drawing(68).png'),
#  PosixPath('shapes/circles/drawing(77).png'),
#  PosixPath('shapes/circles/drawing(5).png'),
#  PosixPath('shapes/circles/drawing(1).png'),
#  PosixPath('shapes/circles/drawing(12).png'),
#  PosixPath('shapes/circles/drawing(80).png'),
#  PosixPath('shapes/circles/drawing(49).png'),
#  PosixPath('shapes/circles/drawing(75).png'),
#  PosixPath('shapes/circles/drawing(89).png'),
#  PosixPath('shapes/circles/drawing(32).png'),
#  PosixPath('shapes/circles/drawing(64).png'),
#  PosixPath('shapes/circles/drawing(20).png'),
#  PosixPath('shapes/circles/drawing(76).png'),
#  PosixPath('shapes/circles/drawing(85).png'),
#  PosixPath('shapes/circles/drawing(9).png'),
#  PosixPath('shapes/circles/drawing(84).png'),
#  PosixPath('shapes/circles/drawing(19).png'),
#  PosixPath('shapes/circles/drawing(98).png'),
#  PosixPath('shapes/circles/drawing(94).png'),
#  PosixPath('shapes/circles/drawing(54).png'),
#  PosixPath('shapes/circles/drawing(66).png'),
#  PosixPath('shapes/circles/drawing(16).png'),
#  PosixPath('shapes/circles/drawing(53).png'),
#  PosixPath('shapes/circles/drawing(91).png'),
#  PosixPath('shapes/circles/drawing(83).png'),
#  PosixPath('shapes/circles/drawing(29).png'),
#  PosixPath('shapes/circles/drawing(41).png'),
#  PosixPath('shapes/circles/drawing(86).png'),
#  PosixPath('shapes/circles/drawing(82).png'),
#  PosixPath('shapes/circles/drawing(34).png'),
#  PosixPath('shapes/circles/drawing(88).png'),
#  PosixPath('shapes/circles/drawing(93).png'),
#  PosixPath('shapes/circles/drawing(57).png'),
#  PosixPath('shapes/circles/drawing(21).png'),
#  PosixPath('shapes/circles/drawing(6).png'),
#  PosixPath('shapes/circles/drawing(44).png'),
#  PosixPath('shapes/circles/drawing(35).png'),
#  PosixPath('shapes/circles/drawing(69).png'),
#  PosixPath('shapes/circles/drawing(100).png'),
#  PosixPath('shapes/circles/drawing(14).png'),
#  PosixPath('shapes/circles/drawing(61).png'),
#  PosixPath('shapes/circles/drawing(48).png'),
#  PosixPath('shapes/circles/drawing(95).png'),
#  PosixPath('shapes/circles/drawing(22).png'),
#  PosixPath('shapes/circles/drawing(8).png'),
#  PosixPath('shapes/circles/drawing(96).png'),
#  PosixPath('shapes/circles/drawing(11).png'),
#  PosixPath('shapes/circles/drawing(37).png'),
#  PosixPath('shapes/circles/drawing(81).png'),
#  PosixPath('shapes/circles/drawing(62).png'),
#  PosixPath('shapes/triangles/drawing(78).png'),
#  PosixPath('shapes/triangles/drawing(2).png'),
#  PosixPath('shapes/triangles/drawing(92).png'),
#  PosixPath('shapes/triangles/drawing(58).png'),
#  PosixPath('shapes/triangles/drawing(10).png'),
#  PosixPath('shapes/triangles/drawing(31).png'),
#  PosixPath('shapes/triangles/drawing(13).png'),
#  PosixPath('shapes/triangles/drawing(55).png'),
#  PosixPath('shapes/triangles/drawing(27).png'),
#  PosixPath('shapes/triangles/drawing(24).png'),
#  PosixPath('shapes/triangles/drawing(74).png'),
#  PosixPath('shapes/triangles/drawing(59).png'),
#  PosixPath('shapes/triangles/drawing(67).png'),
#  PosixPath('shapes/triangles/drawing(39).png'),
#  PosixPath('shapes/triangles/drawing(3).png'),
#  PosixPath('shapes/triangles/drawing(30).png'),
#  PosixPath('shapes/triangles/drawing(18).png'),
#  PosixPath('shapes/triangles/drawing(42).png'),
#  PosixPath('shapes/triangles/drawing(45).png'),
#  PosixPath('shapes/triangles/drawing(7).png'),
#  PosixPath('shapes/triangles/drawing(56).png'),
#  PosixPath('shapes/triangles/drawing(79).png'),
#  PosixPath('shapes/triangles/drawing(33).png'),
#  PosixPath('shapes/triangles/drawing(4).png'),
#  PosixPath('shapes/triangles/drawing(65).png'),
#  PosixPath('shapes/triangles/drawing(26).png'),
#  PosixPath('shapes/triangles/drawing(38).png'),
#  PosixPath('shapes/triangles/drawing(43).png'),
#  PosixPath('shapes/triangles/drawing(15).png'),
#  PosixPath('shapes/triangles/drawing(36).png'),
#  PosixPath('shapes/triangles/drawing(25).png'),
#  PosixPath('shapes/triangles/drawing(40).png'),
#  PosixPath('shapes/triangles/drawing(72).png'),
#  PosixPath('shapes/triangles/drawing(28).png'),
#  PosixPath('shapes/triangles/drawing(47).png'),
#  PosixPath('shapes/triangles/drawing(97).png'),
#  PosixPath('shapes/triangles/drawing(17).png'),
#  PosixPath('shapes/triangles/drawing(52).png'),
#  PosixPath('shapes/triangles/drawing(71).png'),
#  PosixPath('shapes/triangles/drawing(23).png'),
#  PosixPath('shapes/triangles/drawing(90).png'),
#  PosixPath('shapes/triangles/drawing(46).png'),
#  PosixPath('shapes/triangles/drawing(50).png'),
#  PosixPath('shapes/triangles/drawing(70).png'),
#  PosixPath('shapes/triangles/drawing(60).png'),
#  PosixPath('shapes/triangles/drawing(63).png'),
#  PosixPath('shapes/triangles/drawing(51).png'),
#  PosixPath('shapes/triangles/drawing(99).png'),
#  PosixPath('shapes/triangles/drawing(87).png'),
#  PosixPath('shapes/triangles/drawing(73).png'),
#  PosixPath('shapes/triangles/drawing(68).png'),
#  PosixPath('shapes/triangles/drawing(77).png'),
#  PosixPath('shapes/triangles/drawing(5).png'),
#  PosixPath('shapes/triangles/drawing(1).png'),
#  PosixPath('shapes/triangles/drawing(12).png'),
#  PosixPath('shapes/triangles/drawing(80).png'),
#  PosixPath('shapes/triangles/drawing(49).png'),
#  PosixPath('shapes/triangles/drawing(75).png'),
#  PosixPath('shapes/triangles/drawing(89).png'),
#  PosixPath('shapes/triangles/drawing(32).png'),
#  PosixPath('shapes/triangles/drawing(64).png'),
#  PosixPath('shapes/triangles/drawing(20).png'),
#  PosixPath('shapes/triangles/drawing(76).png'),
#  PosixPath('shapes/triangles/drawing(85).png'),
#  PosixPath('shapes/triangles/drawing(9).png'),
#  PosixPath('shapes/triangles/drawing(84).png'),
#  PosixPath('shapes/triangles/drawing(19).png'),
#  PosixPath('shapes/triangles/drawing(98).png'),
#  PosixPath('shapes/triangles/drawing(94).png'),
#  PosixPath('shapes/triangles/drawing(54).png'),
#  PosixPath('shapes/triangles/drawing(66).png'),
#  PosixPath('shapes/triangles/drawing(16).png'),
#  PosixPath('shapes/triangles/drawing(53).png'),
#  PosixPath('shapes/triangles/drawing(91).png'),
#  PosixPath('shapes/triangles/drawing(83).png'),
#  PosixPath('shapes/triangles/drawing(29).png'),
#  PosixPath('shapes/triangles/drawing(41).png'),
#  PosixPath('shapes/triangles/drawing(86).png'),
#  PosixPath('shapes/triangles/drawing(82).png'),
#  PosixPath('shapes/triangles/drawing(34).png'),
#  PosixPath('shapes/triangles/drawing(88).png'),
#  PosixPath('shapes/triangles/drawing(93).png'),
#  PosixPath('shapes/triangles/drawing(57).png'),
#  PosixPath('shapes/triangles/drawing(21).png'),
#  PosixPath('shapes/triangles/drawing(6).png'),
#  PosixPath('shapes/triangles/drawing(44).png'),
#  PosixPath('shapes/triangles/drawing(35).png'),
#  PosixPath('shapes/triangles/drawing(69).png'),
#  PosixPath('shapes/triangles/drawing(100).png'),
#  PosixPath('shapes/triangles/drawing(14).png'),
#  PosixPath('shapes/triangles/drawing(61).png'),
#  PosixPath('shapes/triangles/drawing(48).png'),
#  PosixPath('shapes/triangles/drawing(95).png'),
#  PosixPath('shapes/triangles/drawing(22).png'),
#  PosixPath('shapes/triangles/drawing(8).png'),
#  PosixPath('shapes/triangles/drawing(96).png'),
#  PosixPath('shapes/triangles/drawing(11).png'),
#  PosixPath('shapes/triangles/drawing(37).png'),
#  PosixPath('shapes/triangles/drawing(81).png'),
#  PosixPath('shapes/triangles/drawing(62).png'),
#  PosixPath('shapes/squares/drawing(78).png'),
#  PosixPath('shapes/squares/drawing(2).png'),
#  PosixPath('shapes/squares/drawing(92).png'),
#  PosixPath('shapes/squares/drawing(58).png'),
#  PosixPath('shapes/squares/drawing(10).png'),
#  PosixPath('shapes/squares/drawing(31).png'),
#  PosixPath('shapes/squares/drawing(13).png'),
#  PosixPath('shapes/squares/drawing(55).png'),
#  PosixPath('shapes/squares/drawing(27).png'),
#  PosixPath('shapes/squares/drawing(24).png'),
#  PosixPath('shapes/squares/drawing(74).png'),
#  PosixPath('shapes/squares/drawing(59).png'),
#  PosixPath('shapes/squares/drawing(67).png'),
#  PosixPath('shapes/squares/drawing(39).png'),
#  PosixPath('shapes/squares/drawing(3).png'),
#  PosixPath('shapes/squares/drawing(30).png'),
#  PosixPath('shapes/squares/drawing(18).png'),
#  PosixPath('shapes/squares/drawing(42).png'),
#  PosixPath('shapes/squares/drawing(45).png'),
#  PosixPath('shapes/squares/drawing(7).png'),
#  PosixPath('shapes/squares/drawing(56).png'),
#  PosixPath('shapes/squares/drawing(79).png'),
#  PosixPath('shapes/squares/drawing(33).png'),
#  PosixPath('shapes/squares/drawing(4).png'),
#  PosixPath('shapes/squares/drawing(65).png'),
#  PosixPath('shapes/squares/drawing(26).png'),
#  PosixPath('shapes/squares/drawing(38).png'),
#  PosixPath('shapes/squares/drawing(43).png'),
#  PosixPath('shapes/squares/drawing(15).png'),
#  PosixPath('shapes/squares/drawing(36).png'),
#  PosixPath('shapes/squares/drawing(25).png'),
#  PosixPath('shapes/squares/drawing(40).png'),
#  PosixPath('shapes/squares/drawing(72).png'),
#  PosixPath('shapes/squares/drawing(28).png'),
#  PosixPath('shapes/squares/drawing(47).png'),
#  PosixPath('shapes/squares/drawing(97).png'),
#  PosixPath('shapes/squares/drawing(17).png'),
#  PosixPath('shapes/squares/drawing(52).png'),
#  PosixPath('shapes/squares/drawing(71).png'),
#  PosixPath('shapes/squares/drawing(23).png'),
#  PosixPath('shapes/squares/drawing(90).png'),
#  PosixPath('shapes/squares/drawing(46).png'),
#  PosixPath('shapes/squares/drawing(50).png'),
#  PosixPath('shapes/squares/drawing(70).png'),
#  PosixPath('shapes/squares/drawing(60).png'),
#  PosixPath('shapes/squares/drawing(63).png'),
#  PosixPath('shapes/squares/drawing(51).png'),
#  PosixPath('shapes/squares/drawing(99).png'),
#  PosixPath('shapes/squares/drawing(87).png'),
#  PosixPath('shapes/squares/drawing(73).png'),
#  PosixPath('shapes/squares/drawing(68).png'),
#  PosixPath('shapes/squares/drawing(77).png'),
#  PosixPath('shapes/squares/drawing(5).png'),
#  PosixPath('shapes/squares/drawing(1).png'),
#  PosixPath('shapes/squares/drawing(12).png'),
#  PosixPath('shapes/squares/drawing(80).png'),
#  PosixPath('shapes/squares/drawing(49).png'),
#  PosixPath('shapes/squares/drawing(75).png'),
#  PosixPath('shapes/squares/drawing(89).png'),
#  PosixPath('shapes/squares/drawing(32).png'),
#  PosixPath('shapes/squares/drawing(64).png'),
#  PosixPath('shapes/squares/drawing(20).png'),
#  PosixPath('shapes/squares/drawing(76).png'),
#  PosixPath('shapes/squares/drawing(85).png'),
#  PosixPath('shapes/squares/drawing(9).png'),
#  PosixPath('shapes/squares/drawing(84).png'),
#  PosixPath('shapes/squares/drawing(19).png'),
#  PosixPath('shapes/squares/drawing(98).png'),
#  PosixPath('shapes/squares/drawing(94).png'),
#  PosixPath('shapes/squares/drawing(54).png'),
#  PosixPath('shapes/squares/drawing(66).png'),
#  PosixPath('shapes/squares/drawing(16).png'),
#  PosixPath('shapes/squares/drawing(53).png'),
#  PosixPath('shapes/squares/drawing(91).png'),
#  PosixPath('shapes/squares/drawing(83).png'),
#  PosixPath('shapes/squares/drawing(29).png'),
#  PosixPath('shapes/squares/drawing(41).png'),
#  PosixPath('shapes/squares/drawing(86).png'),
#  PosixPath('shapes/squares/drawing(82).png'),
#  PosixPath('shapes/squares/drawing(34).png'),
#  PosixPath('shapes/squares/drawing(88).png'),
#  PosixPath('shapes/squares/drawing(93).png'),
#  PosixPath('shapes/squares/drawing(57).png'),
#  PosixPath('shapes/squares/drawing(21).png'),
#  PosixPath('shapes/squares/drawing(6).png'),
#  PosixPath('shapes/squares/drawing(44).png'),
#  PosixPath('shapes/squares/drawing(35).png'),
#  PosixPath('shapes/squares/drawing(69).png'),
#  PosixPath('shapes/squares/drawing(100).png'),
#  PosixPath('shapes/squares/drawing(14).png'),
#  PosixPath('shapes/squares/drawing(61).png'),
#  PosixPath('shapes/squares/drawing(48).png'),
#  PosixPath('shapes/squares/drawing(95).png'),
#  PosixPath('shapes/squares/drawing(22).png'),
#  PosixPath('shapes/squares/drawing(8).png'),
#  PosixPath('shapes/squares/drawing(96).png'),
#  PosixPath('shapes/squares/drawing(11).png'),
#  PosixPath('shapes/squares/drawing(37).png'),
#  PosixPath('shapes/squares/drawing(81).png'),
#  PosixPath('shapes/squares/drawing(62).png')]

# %%
os.path.split(os.path.split('shapes/circles/drawing(39).png')[0])[1]
# Out:
# 'circles'

# %%
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))
labels
# Out:
# ['circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'circles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'triangles',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares',
#  'squares']

# %%
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

image_df = pd.concat([filepaths, labels], axis=1)
image_df
# Out:
#                            Filepath    Label
# 0    shapes/circles/drawing(78).png  circles
# 1     shapes/circles/drawing(2).png  circles
# 2    shapes/circles/drawing(92).png  circles
# 3    shapes/circles/drawing(58).png  circles
# 4    shapes/circles/drawing(10).png  circles
# ..                              ...      ...
# 295  shapes/squares/drawing(96).png  squares
# 296  shapes/squares/drawing(11).png  squares
# 297  shapes/squares/drawing(37).png  squares
# 298  shapes/squares/drawing(81).png  squares
# 299  shapes/squares/drawing(62).png  squares
#
# [300 rows x 2 columns]

# %%
train_df, test_df = train_test_split(image_df, train_size=0.7, shuffle=True, random_state=1)

# %%
train_df
# Out:
#                            Filepath    Label
# 253   shapes/squares/drawing(1).png  squares
# 19    shapes/circles/drawing(7).png  circles
# 14    shapes/circles/drawing(3).png  circles
# 91   shapes/circles/drawing(48).png  circles
# 296  shapes/squares/drawing(11).png  squares
# ..                              ...      ...
# 203  shapes/squares/drawing(58).png  squares
# 255  shapes/squares/drawing(80).png  squares
# 72   shapes/circles/drawing(53).png  circles
# 235  shapes/squares/drawing(97).png  squares
# 37   shapes/circles/drawing(52).png  circles
#
# [210 rows x 2 columns]

# %%
test_df
# Out:
#                              Filepath      Label
# 189  shapes/triangles/drawing(14).png  triangles
# 123   shapes/triangles/drawing(4).png  triangles
# 185  shapes/triangles/drawing(44).png  triangles
# 213    shapes/squares/drawing(39).png    squares
# 106  shapes/triangles/drawing(13).png  triangles
# ..                                ...        ...
# 181  shapes/triangles/drawing(93).png  triangles
# 290    shapes/squares/drawing(61).png    squares
# 244    shapes/squares/drawing(60).png    squares
# 197  shapes/triangles/drawing(37).png  triangles
# 279    shapes/squares/drawing(34).png    squares
#
# [90 rows x 2 columns]

# %% [markdown]
# ### Loading Image Data

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1./255,
    validation_split = 0.2,
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1./255
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe = train_df,
    x_col = 'Filepath',
    y_col = 'Label',
    target_size = (28, 28),
    color_mode = 'grayscale',
    class_mode = 'categorical',
    batch_size = 32,
    shuffle=True,
    seed = 42,
    subset = 'training'
)
# Out:
# Found 168 validated image filenames belonging to 3 classes.

# %%
val_images = train_generator.flow_from_dataframe(
    dataframe = train_df,
    x_col = 'Filepath',
    y_col = 'Label',
    target_size = (28, 28),
    color_mode = 'grayscale',
    class_mode = 'categorical',
    batch_size = 32,
    shuffle=True,
    seed = 42,
    subset = 'validation'
)
# Out:
# Found 42 validated image filenames belonging to 3 classes.

# %%
test_images = test_generator.flow_from_dataframe(
    dataframe = test_df,
    x_col = 'Filepath',
    y_col = 'Label',
    target_size = (28, 28),
    color_mode = 'grayscale',
    class_mode = 'categorical',
    batch_size = 32,
    shuffle=False
)
# Out:
# Found 90 validated image filenames belonging to 3 classes.

# %% [markdown]
# ### Training

# %%
inputs = tf.keras.Input(shape=(28, 28, 1))
x = tf.keras.layers.Conv2D(filters=6, kernel_size=(3,3), activation='relu')(inputs)
inputs
# Out:
# <KerasTensor: shape=(None, 28, 28, 1) dtype=float32 (created by layer 'input_4')>

# %%
x
# Out:
# <KerasTensor: shape=(None, 26, 26, 6) dtype=float32 (created by layer 'conv2d_6')>

# %%
x = tf.keras.layers.MaxPool2D()(x)
x
# Out:
# <KerasTensor: shape=(None, 13, 13, 6) dtype=float32 (created by layer 'max_pooling2d_5')>

# %%
x = tf.keras.layers.Conv2D(filters=16, kernel_size=(3,3), activation='relu')(x)
x = tf.keras.layers.MaxPool2D()(x)
x
# Out:
# <KerasTensor: shape=(None, 5, 5, 16) dtype=float32 (created by layer 'max_pooling2d_6')>

# %%
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x
# Out:
# <KerasTensor: shape=(None, 16) dtype=float32 (created by layer 'global_average_pooling2d')>

# %%
x = tf.keras.layers.Dense(64, activation='relu')(x)
x = tf.keras.layers.Dense(64, activation='relu')(x)
outputs = tf.keras.layers.Dense(3, activation='softmax')(x)

# %%
model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer = 'adam',
    loss = 'categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    validation_data = val_images,
    epochs=100,
    callbacks=[
        tf.keras.callbacks.ModelCheckpoint('./model.h5', save_best_only=True, save_weights_only=True)
    ]
)
# Out:
# Epoch 1/100
# 2024-12-11 10:26:17.984130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 4/6 [===================>..........] - ETA: 0s - loss: 0.5898 - accuracy: 0.7266
# 2024-12-11 10:26:19.429310: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 6/6 [==============================] - 2s 101ms/step - loss: 0.5493 - accuracy: 0.7560 - val_loss: 0.4667 - val_accuracy: 0.8571
# Epoch 2/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.5160 - accuracy: 0.7321 - val_loss: 0.4134 - val_accuracy: 0.8095
# Epoch 3/100
# 6/6 [==============================] - 0s 60ms/step - loss: 0.5093 - accuracy: 0.7381 - val_loss: 0.4128 - val_accuracy: 0.8571
# Epoch 4/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.4888 - accuracy: 0.7798 - val_loss: 0.3992 - val_accuracy: 0.8333
# Epoch 5/100
# 6/6 [==============================] - 0s 36ms/step - loss: 0.5021 - accuracy: 0.7798 - val_loss: 0.3949 - val_accuracy: 0.8571
# Epoch 6/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.4898 - accuracy: 0.8036 - val_loss: 0.3963 - val_accuracy: 0.8333
# Epoch 7/100
# 6/6 [==============================] - 0s 64ms/step - loss: 0.4894 - accuracy: 0.7976 - val_loss: 0.3970 - val_accuracy: 0.8333
# Epoch 8/100
# 6/6 [==============================] - 0s 76ms/step - loss: 0.4965 - accuracy: 0.7738 - val_loss: 0.3991 - val_accuracy: 0.8571
# Epoch 9/100
# 6/6 [==============================] - 0s 52ms/step - loss: 0.5361 - accuracy: 0.6964 - val_loss: 0.4231 - val_accuracy: 0.7381
# Epoch 10/100
# 6/6 [==============================] - 0s 41ms/step - loss: 0.5353 - accuracy: 0.7381 - val_loss: 0.4204 - val_accuracy: 0.8571
# Epoch 11/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.4932 - accuracy: 0.7917 - val_loss: 0.4085 - val_accuracy: 0.8810
# Epoch 12/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4995 - accuracy: 0.7917 - val_loss: 0.4493 - val_accuracy: 0.8571
# Epoch 13/100
# 6/6 [==============================] - 0s 36ms/step - loss: 0.5004 - accuracy: 0.7738 - val_loss: 0.3987 - val_accuracy: 0.8333
# Epoch 14/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.4919 - accuracy: 0.8036 - val_loss: 0.4233 - val_accuracy: 0.8810
# Epoch 15/100
# 6/6 [==============================] - 0s 59ms/step - loss: 0.4995 - accuracy: 0.7857 - val_loss: 0.3963 - val_accuracy: 0.8571
# Epoch 16/100
# 6/6 [==============================] - 0s 78ms/step - loss: 0.4736 - accuracy: 0.7917 - val_loss: 0.3921 - val_accuracy: 0.8571
# Epoch 17/100
# 6/6 [==============================] - 0s 47ms/step - loss: 0.4698 - accuracy: 0.7976 - val_loss: 0.3811 - val_accuracy: 0.8810
# Epoch 18/100
# 6/6 [==============================] - 0s 58ms/step - loss: 0.4796 - accuracy: 0.7976 - val_loss: 0.3790 - val_accuracy: 0.8571
# Epoch 19/100
# 6/6 [==============================] - 0s 68ms/step - loss: 0.4692 - accuracy: 0.8036 - val_loss: 0.3769 - val_accuracy: 0.8333
# Epoch 20/100
# 6/6 [==============================] - 0s 75ms/step - loss: 0.4829 - accuracy: 0.7738 - val_loss: 0.3778 - val_accuracy: 0.8333
# Epoch 21/100
# 6/6 [==============================] - 0s 65ms/step - loss: 0.4662 - accuracy: 0.7798 - val_loss: 0.3777 - val_accuracy: 0.8571
# Epoch 22/100
# 6/6 [==============================] - 0s 55ms/step - loss: 0.4661 - accuracy: 0.7917 - val_loss: 0.3809 - val_accuracy: 0.8571
# Epoch 23/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.4840 - accuracy: 0.8036 - val_loss: 0.3864 - val_accuracy: 0.8810
# Epoch 24/100
# 6/6 [==============================] - 0s 67ms/step - loss: 0.5003 - accuracy: 0.7679 - val_loss: 0.3780 - val_accuracy: 0.8571
# Epoch 25/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.4701 - accuracy: 0.7798 - val_loss: 0.3857 - val_accuracy: 0.8571
# Epoch 26/100
# 6/6 [==============================] - 0s 63ms/step - loss: 0.4665 - accuracy: 0.7857 - val_loss: 0.3862 - val_accuracy: 0.8571
# Epoch 27/100
# 6/6 [==============================] - 0s 52ms/step - loss: 0.4581 - accuracy: 0.7976 - val_loss: 0.3816 - val_accuracy: 0.8333
# Epoch 28/100
# 6/6 [==============================] - 0s 55ms/step - loss: 0.4601 - accuracy: 0.8155 - val_loss: 0.3813 - val_accuracy: 0.8571
# Epoch 29/100
# 6/6 [==============================] - 0s 74ms/step - loss: 0.4934 - accuracy: 0.7857 - val_loss: 0.3781 - val_accuracy: 0.8810
# Epoch 30/100
# 6/6 [==============================] - 0s 68ms/step - loss: 0.4769 - accuracy: 0.7976 - val_loss: 0.3695 - val_accuracy: 0.8571
# Epoch 31/100
# 6/6 [==============================] - 0s 54ms/step - loss: 0.4526 - accuracy: 0.8036 - val_loss: 0.3608 - val_accuracy: 0.8571
# Epoch 32/100
# 6/6 [==============================] - 0s 85ms/step - loss: 0.4518 - accuracy: 0.8155 - val_loss: 0.3592 - val_accuracy: 0.8810
# Epoch 33/100
# 6/6 [==============================] - 0s 39ms/step - loss: 0.4491 - accuracy: 0.8214 - val_loss: 0.3625 - val_accuracy: 0.8810
# Epoch 34/100
# 6/6 [==============================] - 0s 49ms/step - loss: 0.4518 - accuracy: 0.8095 - val_loss: 0.3721 - val_accuracy: 0.8571
# Epoch 35/100
# 6/6 [==============================] - 0s 75ms/step - loss: 0.4625 - accuracy: 0.7976 - val_loss: 0.3757 - val_accuracy: 0.8810
# Epoch 36/100
# 6/6 [==============================] - 0s 57ms/step - loss: 0.4511 - accuracy: 0.8095 - val_loss: 0.3947 - val_accuracy: 0.8810
# Epoch 37/100
# 6/6 [==============================] - 0s 80ms/step - loss: 0.5389 - accuracy: 0.7679 - val_loss: 0.3794 - val_accuracy: 0.8810
# Epoch 38/100
# 6/6 [==============================] - 0s 49ms/step - loss: 0.4586 - accuracy: 0.8214 - val_loss: 0.3762 - val_accuracy: 0.8810
# Epoch 39/100
# 6/6 [==============================] - 1s 76ms/step - loss: 0.4729 - accuracy: 0.7976 - val_loss: 0.3869 - val_accuracy: 0.8810
# Epoch 40/100
# 6/6 [==============================] - 0s 74ms/step - loss: 0.4499 - accuracy: 0.8036 - val_loss: 0.3641 - val_accuracy: 0.8810
# Epoch 41/100
# 6/6 [==============================] - 1s 100ms/step - loss: 0.4404 - accuracy: 0.7976 - val_loss: 0.3592 - val_accuracy: 0.8810
# Epoch 42/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.4585 - accuracy: 0.7857 - val_loss: 0.3608 - val_accuracy: 0.8571
# Epoch 43/100
# 6/6 [==============================] - 1s 91ms/step - loss: 0.4545 - accuracy: 0.8274 - val_loss: 0.3488 - val_accuracy: 0.8810
# Epoch 44/100
# 6/6 [==============================] - 1s 101ms/step - loss: 0.4423 - accuracy: 0.8036 - val_loss: 0.3553 - val_accuracy: 0.8810
# Epoch 45/100
# 6/6 [==============================] - 0s 61ms/step - loss: 0.4313 - accuracy: 0.8036 - val_loss: 0.3460 - val_accuracy: 0.8571
# Epoch 46/100
# 6/6 [==============================] - 0s 58ms/step - loss: 0.4299 - accuracy: 0.8095 - val_loss: 0.3481 - val_accuracy: 0.8810
# Epoch 47/100
# 6/6 [==============================] - 0s 50ms/step - loss: 0.4359 - accuracy: 0.8274 - val_loss: 0.3398 - val_accuracy: 0.8810
# Epoch 48/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.4232 - accuracy: 0.8393 - val_loss: 0.3444 - val_accuracy: 0.8571
# Epoch 49/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.4213 - accuracy: 0.8214 - val_loss: 0.3386 - val_accuracy: 0.8571
# Epoch 50/100
# 6/6 [==============================] - 0s 63ms/step - loss: 0.4320 - accuracy: 0.8214 - val_loss: 0.3815 - val_accuracy: 0.7619
# Epoch 51/100
# 6/6 [==============================] - 0s 44ms/step - loss: 0.4527 - accuracy: 0.8036 - val_loss: 0.3479 - val_accuracy: 0.8571
# Epoch 52/100
# 6/6 [==============================] - 0s 54ms/step - loss: 0.4198 - accuracy: 0.8274 - val_loss: 0.3420 - val_accuracy: 0.8571
# Epoch 53/100
# 6/6 [==============================] - 0s 57ms/step - loss: 0.4205 - accuracy: 0.8274 - val_loss: 0.3435 - val_accuracy: 0.8571
# Epoch 54/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.4249 - accuracy: 0.8036 - val_loss: 0.3393 - val_accuracy: 0.8810
# Epoch 55/100
# 6/6 [==============================] - 0s 50ms/step - loss: 0.4194 - accuracy: 0.8214 - val_loss: 0.3364 - val_accuracy: 0.8571
# Epoch 56/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.4233 - accuracy: 0.8155 - val_loss: 0.3423 - val_accuracy: 0.8571
# Epoch 57/100
# 6/6 [==============================] - 0s 52ms/step - loss: 0.4208 - accuracy: 0.8155 - val_loss: 0.3361 - val_accuracy: 0.8571
# Epoch 58/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.4237 - accuracy: 0.8214 - val_loss: 0.3315 - val_accuracy: 0.8810
# Epoch 59/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.4329 - accuracy: 0.8274 - val_loss: 0.3500 - val_accuracy: 0.8571
# Epoch 60/100
# 6/6 [==============================] - 0s 56ms/step - loss: 0.4190 - accuracy: 0.8393 - val_loss: 0.3806 - val_accuracy: 0.8810
# Epoch 61/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.4213 - accuracy: 0.8333 - val_loss: 0.3358 - val_accuracy: 0.9286
# Epoch 62/100
# 6/6 [==============================] - 0s 57ms/step - loss: 0.4062 - accuracy: 0.8452 - val_loss: 0.3324 - val_accuracy: 0.8810
# Epoch 63/100
# 6/6 [==============================] - 0s 45ms/step - loss: 0.4032 - accuracy: 0.8333 - val_loss: 0.3419 - val_accuracy: 0.8571
# Epoch 64/100
# 6/6 [==============================] - 0s 48ms/step - loss: 0.4224 - accuracy: 0.8274 - val_loss: 0.3544 - val_accuracy: 0.8810
# Epoch 65/100
# 6/6 [==============================] - 1s 97ms/step - loss: 0.4150 - accuracy: 0.7976 - val_loss: 0.3248 - val_accuracy: 0.9286
# Epoch 66/100
# 6/6 [==============================] - 0s 73ms/step - loss: 0.4211 - accuracy: 0.8155 - val_loss: 0.3222 - val_accuracy: 0.8810
# Epoch 67/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.4110 - accuracy: 0.8274 - val_loss: 0.3322 - val_accuracy: 0.8810
# Epoch 68/100
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4029 - accuracy: 0.8393 - val_loss: 0.3165 - val_accuracy: 0.8810
# Epoch 69/100
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3868 - accuracy: 0.8571 - val_loss: 0.3713 - val_accuracy: 0.8810
# Epoch 70/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4122 - accuracy: 0.8155 - val_loss: 0.3355 - val_accuracy: 0.8333
# Epoch 71/100
# 6/6 [==============================] - 0s 45ms/step - loss: 0.4133 - accuracy: 0.8274 - val_loss: 0.3188 - val_accuracy: 0.9048
# Epoch 72/100
# 6/6 [==============================] - 0s 49ms/step - loss: 0.4207 - accuracy: 0.8155 - val_loss: 0.3376 - val_accuracy: 0.8810
# Epoch 73/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3915 - accuracy: 0.8214 - val_loss: 0.3265 - val_accuracy: 0.9286
# Epoch 74/100
# 6/6 [==============================] - 0s 48ms/step - loss: 0.4348 - accuracy: 0.7976 - val_loss: 0.3197 - val_accuracy: 0.8810
# Epoch 75/100
# 6/6 [==============================] - 0s 69ms/step - loss: 0.4248 - accuracy: 0.8274 - val_loss: 0.3228 - val_accuracy: 0.8810
# Epoch 76/100
# 6/6 [==============================] - 0s 39ms/step - loss: 0.3963 - accuracy: 0.8333 - val_loss: 0.3346 - val_accuracy: 0.8810
# Epoch 77/100
# 6/6 [==============================] - 0s 30ms/step - loss: 0.4923 - accuracy: 0.7798 - val_loss: 0.3190 - val_accuracy: 0.8810
# Epoch 78/100
# 6/6 [==============================] - 0s 52ms/step - loss: 0.4237 - accuracy: 0.8155 - val_loss: 0.3102 - val_accuracy: 0.9048
# Epoch 79/100
# 6/6 [==============================] - 1s 71ms/step - loss: 0.4225 - accuracy: 0.8155 - val_loss: 0.3097 - val_accuracy: 0.9286
# Epoch 80/100
# 6/6 [==============================] - 0s 72ms/step - loss: 0.4117 - accuracy: 0.8393 - val_loss: 0.3275 - val_accuracy: 0.8810
# Epoch 81/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.3761 - accuracy: 0.8571 - val_loss: 0.3934 - val_accuracy: 0.7619
# Epoch 82/100
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4739 - accuracy: 0.7976 - val_loss: 0.3374 - val_accuracy: 0.8810
# Epoch 83/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.3932 - accuracy: 0.8333 - val_loss: 0.3128 - val_accuracy: 0.9048
# Epoch 84/100
# 6/6 [==============================] - 0s 50ms/step - loss: 0.4066 - accuracy: 0.8393 - val_loss: 0.3474 - val_accuracy: 0.8571
# Epoch 85/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3973 - accuracy: 0.8452 - val_loss: 0.3560 - val_accuracy: 0.8810
# Epoch 86/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4345 - accuracy: 0.8214 - val_loss: 0.3171 - val_accuracy: 0.9286
# Epoch 87/100
# 6/6 [==============================] - 0s 61ms/step - loss: 0.4152 - accuracy: 0.8452 - val_loss: 0.3205 - val_accuracy: 0.8810
# Epoch 88/100
# 6/6 [==============================] - 0s 77ms/step - loss: 0.3979 - accuracy: 0.8512 - val_loss: 0.3277 - val_accuracy: 0.8810
# Epoch 89/100
# 6/6 [==============================] - 0s 60ms/step - loss: 0.3908 - accuracy: 0.8452 - val_loss: 0.3084 - val_accuracy: 0.9048
# Epoch 90/100
# 6/6 [==============================] - 0s 58ms/step - loss: 0.3769 - accuracy: 0.8393 - val_loss: 0.3079 - val_accuracy: 0.8810
# Epoch 91/100
# 6/6 [==============================] - 0s 48ms/step - loss: 0.3723 - accuracy: 0.8512 - val_loss: 0.3021 - val_accuracy: 0.9286
# Epoch 92/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3647 - accuracy: 0.8512 - val_loss: 0.3275 - val_accuracy: 0.8810
# Epoch 93/100
# 6/6 [==============================] - 0s 72ms/step - loss: 0.3914 - accuracy: 0.8393 - val_loss: 0.2987 - val_accuracy: 0.9286
# Epoch 94/100
# 6/6 [==============================] - 0s 68ms/step - loss: 0.3762 - accuracy: 0.8393 - val_loss: 0.3704 - val_accuracy: 0.8810
# Epoch 95/100
# 6/6 [==============================] - 0s 57ms/step - loss: 0.4045 - accuracy: 0.8452 - val_loss: 0.3711 - val_accuracy: 0.7857
# Epoch 96/100
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4842 - accuracy: 0.7917 - val_loss: 0.3029 - val_accuracy: 0.9048
# Epoch 97/100
# 6/6 [==============================] - 0s 55ms/step - loss: 0.4370 - accuracy: 0.8214 - val_loss: 0.3038 - val_accuracy: 0.9048
# Epoch 98/100
# 6/6 [==============================] - 0s 64ms/step - loss: 0.4171 - accuracy: 0.8274 - val_loss: 0.3068 - val_accuracy: 0.9048
# Epoch 99/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.3953 - accuracy: 0.8214 - val_loss: 0.3335 - val_accuracy: 0.8810
# Epoch 100/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3975 - accuracy: 0.8214 - val_loss: 0.2963 - val_accuracy: 0.9286

# %%
model.load_weights('model.h5')

# %% [markdown]
# ### Results

# %%
results = model.evaluate(test_images, verbose=0)

print("    Loss: {:.4f}".format(results[0]))
print("Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
#     Loss: 0.4033
# Accuracy: 80.00%
# 2024-12-11 10:29:44.301356: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
