# %% [markdown]
# ## Using PCA to understand College Admissions
#
# Given *data about various mertis of a student*, we need to predict the **chance of admission** to a graduate program.
#
# Data source: https://www.kaggle.com/datasets/mohansacharya/graduate-admissions

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
# Out:
# /home/aditya/miniconda3/envs/dsenv/lib/python3.10/site-packages/numpy/_core/getlimits.py:551: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)

# %%
data = pd.read_csv("Admission_Predict_Ver1.1.csv", index_col='Serial No.')
data
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
# ...               ...          ...                ...  ...   ...   ...
# 496               332          108                  5  4.5   4.0  9.02
# 497               337          117                  5  5.0   5.0  9.87
# 498               330          120                  5  4.5   5.0  9.56
# 499               312          103                  4  4.0   5.0  8.43
# 500               327          113                  4  4.5   4.5  9.04
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# ...

# %%
# Split data into X and y
y = data['Chance of Admit ']
X = data.drop('Chance of Admit ', axis=1)

# %%
y
# Out:
# Serial No.
# 1      0.92
# 2      0.76
# 3      0.72
# 4      0.80
# 5      0.65
#        ...
# 496    0.87
# 497    0.96
# 498    0.93
# 499    0.73
# 500    0.84
# Name: Chance of Admit , Length: 500, dtype: float64

# %%
X
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
# ...               ...          ...                ...  ...   ...   ...
# 496               332          108                  5  4.5   4.0  9.02
# 497               337          117                  5  5.0   5.0  9.87
# 498               330          120                  5  4.5   5.0  9.56
# 499               312          103                  4  4.0   5.0  8.43
# 500               327          113                  4  4.5   4.5  9.04
#
#             Research
# Serial No.
# 1                  1
# 2                  1
# 3                  1
# ...

# %%
pca = PCA(n_components=2)
pca.fit(X)
X_PCA = pca.transform(X)

# %%
X_PCA = pd.DataFrame(X_PCA, columns=['PC1', 'PC2'])
X_PCA
# Out:
#            PC1       PC2
# 0    23.273887  0.783279
# 1     6.811715 -3.351076
# 2    -1.841991 -2.687708
# 3     6.140811  0.024660
# 4    -4.212021 -2.824404
# ..         ...       ...
# 495  14.484897 -5.912684
# 496  22.957009  0.008506
# 497  17.942750  5.731901
# 498  -5.690921 -1.610405
# 499  12.103936  0.724204
#
# [500 rows x 2 columns]

# %%
plt.figure(figsize=(12, 10))
plt.scatter(X_PCA['PC1'], X_PCA['PC2'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %%
PCA_max = np.argmax(X_PCA['PC1'])
PCA_min = np.argmin(X_PCA['PC1'])

print(PCA_max)
print(PCA_min)
# Out:
# 202
# 377

# %%
X.iloc[PCA_max, :]
# Out:
# GRE Score            340.00
# TOEFL Score          120.00
# University Rating      5.00
# SOP                    4.50
# LOR                    4.50
# CGPA                   9.91
# Research               1.00
# Name: 203, dtype: float64

# %%
X.iloc[PCA_min, :]
# Out:
# GRE Score            290.00
# TOEFL Score          100.00
# University Rating      1.00
# SOP                    1.50
# LOR                    2.00
# CGPA                   7.56
# Research               0.00
# Name: 378, dtype: float64

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
pd.DataFrame(X)
# Out:
#         0         1     2      3      4         5    6
# 0    0.94  0.928571  0.75  0.875  0.875  0.913462  1.0
# 1    0.68  0.535714  0.75  0.750  0.875  0.663462  1.0
# 2    0.52  0.428571  0.50  0.500  0.625  0.384615  1.0
# 3    0.64  0.642857  0.50  0.625  0.375  0.599359  1.0
# 4    0.48  0.392857  0.25  0.250  0.500  0.451923  0.0
# ..    ...       ...   ...    ...    ...       ...  ...
# 495  0.84  0.571429  1.00  0.875  0.750  0.711538  1.0
# 496  0.94  0.892857  1.00  1.000  1.000  0.983974  1.0
# 497  0.80  1.000000  1.00  0.875  1.000  0.884615  1.0
# 498  0.44  0.392857  0.75  0.750  1.000  0.522436  0.0
# 499  0.74  0.750000  0.75  0.875  0.875  0.717949  0.0
#
# [500 rows x 7 columns]

# %%
# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=True)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.8098041789104137

# %%
pred = model.predict(X_test)

# %%
pred
# Out:
# array([0.81433275, 0.78770002, 0.71248782, 0.57125285, 0.79284576,
#        0.65782847, 0.56493388, 0.88893093, 0.82093283, 0.83187765,
#        0.72565971, 0.88500265, 0.59428821, 0.61284785, 0.83104649,
#        0.75623664, 0.96492162, 0.70167075, 0.95098333, 0.66065512,
#        0.81670067, 0.74537152, 0.95386675, 0.62549807, 0.74848317,
#        0.92528523, 0.74558474, 0.77238421, 0.7838345 , 0.80604172,
#        0.58090379, 0.62628928, 0.73579864, 0.71093116, 0.96810861,
#        0.44499296, 0.47243659, 0.85075733, 0.75294848, 0.51555983,
#        0.82830073, 0.65948008, 0.73785186, 0.70696664, 0.6181199 ,
#        0.59914039, 0.58801524, 0.93686409, 0.72076006, 0.55584699,
#        0.90879937, 0.82149356, 0.67506826, 0.64923555, 0.8469938 ,
#        0.70013847, 0.68519114, 0.51893197, 0.75383167, 0.54970481,
#        0.91871471, 0.78628253, 0.95581031, 0.85977622, 0.53467326,
#        0.90956651, 0.62633527, 0.58466941, 0.73015294, 0.78689046,
# ...

# %%
plt.figure(figsize=(14, 10))
plt.plot(pred, y_test, 'o')
plt.xlabel('Predicted Value')
plt.ylabel('Actual Value')
plt.show()
