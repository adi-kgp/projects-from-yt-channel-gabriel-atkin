# %% [markdown]
# ## Health Insurance Customer Response Prediction
#
# Given *data about a health insurance marketing campaign*, let's try to predict whether a given customer **will purchase** the insurance or not.
#
# We will use a logistic regression model to make our predictions.
#
# Data Source: https://www.kaggle.com/datasets/klmsathishkumar/health-insurance-lead-prediction

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import confusion_matrix, classification_report

import warnings
warnings.filterwarnings(action='ignore')

# %%
data = pd.read_csv('train.csv')
data
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1        C3         3213            Rented          Individual
# 1          2        C5         1117             Owned               Joint
# 2          3        C5         3732             Owned          Individual
# 3          4       C24         4378             Owned               Joint
# 4          5        C8         2190            Rented          Individual
# ...      ...       ...          ...               ...                 ...
# 50877  50878        C4          845            Rented          Individual
# 50878  50879        C5         4188            Rented          Individual
# 50879  50880        C1          442            Rented          Individual
# 50880  50881        C1            4             Owned               Joint
# 50881  50882        C3         3866            Rented          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# 0             36         36        No               X1
# 1             75         22        No               X2
# 2             32         32        No              NaN
# 3             52         48        No               X1
# 4             44         44        No               X2
# ...          ...        ...       ...              ...
# 50877         22         22        No               X3
# 50878         27         27        No               X3
# 50879         63         63        No               X2
# 50880         71         49        No               X2
# 50881         24         24        No               X3
#
#       Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 0                         14+                  3.0               22
# 1                         NaN                  NaN               22
# 2                         1.0                  1.0               19
# 3                         14+                  3.0               19
# 4                         3.0                  1.0               16
# ...                       ...                  ...              ...
# 50877                     NaN                  NaN               18
# 50878                     7.0                  3.0                4
# 50879                     14+                  1.0               12
# 50880                     2.0                  2.0               16
# 50881                     2.0                  3.0               18
#
#        Reco_Policy_Premium  Response
# 0                  11628.0         0
# 1                  30510.0         0
# 2                   7450.0         1
# 3                  17780.0         0
# 4                  10404.0         0
# ...                    ...       ...
# 50877               7704.0         0
# 50878               5408.0         0
# 50879              11374.0         0
# 50880              28179.2         1
# 50881              11424.0         0
#
# [50882 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50882 entries, 0 to 50881
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       50882 non-null  int64
#  1   City_Code                50882 non-null  object
#  2   Region_Code              50882 non-null  int64
#  3   Accomodation_Type        50882 non-null  object
#  4   Reco_Insurance_Type      50882 non-null  object
#  5   Upper_Age                50882 non-null  int64
#  6   Lower_Age                50882 non-null  int64
#  7   Is_Spouse                50882 non-null  object
#  8   Health Indicator         39191 non-null  object
#  9   Holding_Policy_Duration  30631 non-null  object
#  10  Holding_Policy_Type      30631 non-null  float64
#  11  Reco_Policy_Cat          50882 non-null  int64
#  12  Reco_Policy_Premium      50882 non-null  float64
#  13  Response                 50882 non-null  int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 5.4+ MB

# %% [markdown]
# ### Preprocessing

# %%
df = data.copy()
df
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1        C3         3213            Rented          Individual
# 1          2        C5         1117             Owned               Joint
# 2          3        C5         3732             Owned          Individual
# 3          4       C24         4378             Owned               Joint
# 4          5        C8         2190            Rented          Individual
# ...      ...       ...          ...               ...                 ...
# 50877  50878        C4          845            Rented          Individual
# 50878  50879        C5         4188            Rented          Individual
# 50879  50880        C1          442            Rented          Individual
# 50880  50881        C1            4             Owned               Joint
# 50881  50882        C3         3866            Rented          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# 0             36         36        No               X1
# 1             75         22        No               X2
# 2             32         32        No              NaN
# 3             52         48        No               X1
# 4             44         44        No               X2
# ...          ...        ...       ...              ...
# 50877         22         22        No               X3
# 50878         27         27        No               X3
# 50879         63         63        No               X2
# 50880         71         49        No               X2
# 50881         24         24        No               X3
#
#       Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 0                         14+                  3.0               22
# 1                         NaN                  NaN               22
# 2                         1.0                  1.0               19
# 3                         14+                  3.0               19
# 4                         3.0                  1.0               16
# ...                       ...                  ...              ...
# 50877                     NaN                  NaN               18
# 50878                     7.0                  3.0                4
# 50879                     14+                  1.0               12
# 50880                     2.0                  2.0               16
# 50881                     2.0                  3.0               18
#
#        Reco_Policy_Premium  Response
# 0                  11628.0         0
# 1                  30510.0         0
# 2                   7450.0         1
# 3                  17780.0         0
# 4                  10404.0         0
# ...                    ...       ...
# 50877               7704.0         0
# 50878               5408.0         0
# 50879              11374.0         0
# 50880              28179.2         1
# 50881              11424.0         0
#
# [50882 rows x 14 columns]

# %%
# Dropping ID column
df = df.drop('ID', axis=1)
df
# Out:
#       City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0            C3         3213            Rented          Individual         36
# 1            C5         1117             Owned               Joint         75
# 2            C5         3732             Owned          Individual         32
# 3           C24         4378             Owned               Joint         52
# 4            C8         2190            Rented          Individual         44
# ...         ...          ...               ...                 ...        ...
# 50877        C4          845            Rented          Individual         22
# 50878        C5         4188            Rented          Individual         27
# 50879        C1          442            Rented          Individual         63
# 50880        C1            4             Owned               Joint         71
# 50881        C3         3866            Rented          Individual         24
#
#        Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0             36        No               X1                     14+
# 1             22        No               X2                     NaN
# 2             32        No              NaN                     1.0
# 3             48        No               X1                     14+
# 4             44        No               X2                     3.0
# ...          ...       ...              ...                     ...
# 50877         22        No               X3                     NaN
# 50878         27        No               X3                     7.0
# 50879         63        No               X2                     14+
# 50880         49        No               X2                     2.0
# 50881         24        No               X3                     2.0
#
#        Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response
# 0                      3.0               22              11628.0         0
# 1                      NaN               22              30510.0         0
# 2                      1.0               19               7450.0         1
# 3                      3.0               19              17780.0         0
# 4                      1.0               16              10404.0         0
# ...                    ...              ...                  ...       ...
# 50877                  NaN               18               7704.0         0
# 50878                  3.0                4               5408.0         0
# 50879                  1.0               12              11374.0         0
# 50880                  2.0               16              28179.2         1
# 50881                  3.0               18              11424.0         0
#
# [50882 rows x 13 columns]

# %%
df.isna().mean()*100
# Out:
# City_Code                   0.000000
# Region_Code                 0.000000
# Accomodation_Type           0.000000
# Reco_Insurance_Type         0.000000
# Upper_Age                   0.000000
# Lower_Age                   0.000000
# Is_Spouse                   0.000000
# Health Indicator           22.976691
# Holding_Policy_Duration    39.799929
# Holding_Policy_Type        39.799929
# Reco_Policy_Cat             0.000000
# Reco_Policy_Premium         0.000000
# Response                    0.000000
# dtype: float64

# %%
# Drop columns with too many missing values
df = df.drop(['Holding_Policy_Duration', 'Holding_Policy_Type'], axis=1)

# %%
df.isna().mean()*100
# Out:
# City_Code               0.000000
# Region_Code             0.000000
# Accomodation_Type       0.000000
# Reco_Insurance_Type     0.000000
# Upper_Age               0.000000
# Lower_Age               0.000000
# Is_Spouse               0.000000
# Health Indicator       22.976691
# Reco_Policy_Cat         0.000000
# Reco_Policy_Premium     0.000000
# Response                0.000000
# dtype: float64

# %%
df['Health Indicator'].mode()
# Out:
# 0    X1
# Name: Health Indicator, dtype: object

# %%
# Fill remaining missing values
df['Health Indicator'] = df['Health Indicator'].fillna(df['Health Indicator'].mode()[0])

# %%
df.isna().mean()*100
# Out:
# City_Code              0.0
# Region_Code            0.0
# Accomodation_Type      0.0
# Reco_Insurance_Type    0.0
# Upper_Age              0.0
# Lower_Age              0.0
# Is_Spouse              0.0
# Health Indicator       0.0
# Reco_Policy_Cat        0.0
# Reco_Policy_Premium    0.0
# Response               0.0
# dtype: float64

# %%
{column: len(df[column].unique()) for column in df.columns}
# Out:
# {'City_Code': 36,
#  'Region_Code': 5316,
#  'Accomodation_Type': 2,
#  'Reco_Insurance_Type': 2,
#  'Upper_Age': 58,
#  'Lower_Age': 60,
#  'Is_Spouse': 2,
#  'Health Indicator': 9,
#  'Reco_Policy_Cat': 22,
#  'Reco_Policy_Premium': 6977,
#  'Response': 2}

# %%
# Drop Region_Code (high cardinality categorical column)
df = df.drop('Region_Code', axis=1)

# %%
{column: len(df[column].unique()) for column in df.columns}
# Out:
# {'City_Code': 36,
#  'Accomodation_Type': 2,
#  'Reco_Insurance_Type': 2,
#  'Upper_Age': 58,
#  'Lower_Age': 60,
#  'Is_Spouse': 2,
#  'Health Indicator': 9,
#  'Reco_Policy_Cat': 22,
#  'Reco_Policy_Premium': 6977,
#  'Response': 2}

# %%
# Binary Encoding
df['Accomodation_Type'] = df['Accomodation_Type'].replace({'Rented': 0, 'Owned': 1})

# %%
df['Reco_Insurance_Type'] = df['Reco_Insurance_Type'].replace({'Individual':0, 'Joint': 1})

# %%
df['Is_Spouse'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Is_Spouse'] = df['Is_Spouse'].replace({'No':0, 'Yes': 1})

# %%
df
# Out:
#       City_Code  Accomodation_Type  Reco_Insurance_Type  Upper_Age  Lower_Age  \
# 0            C3                  0                    0         36         36
# 1            C5                  1                    1         75         22
# 2            C5                  1                    0         32         32
# 3           C24                  1                    1         52         48
# 4            C8                  0                    0         44         44
# ...         ...                ...                  ...        ...        ...
# 50877        C4                  0                    0         22         22
# 50878        C5                  0                    0         27         27
# 50879        C1                  0                    0         63         63
# 50880        C1                  1                    1         71         49
# 50881        C3                  0                    0         24         24
#
#        Is_Spouse Health Indicator  Reco_Policy_Cat  Reco_Policy_Premium  \
# 0              0               X1               22              11628.0
# 1              0               X2               22              30510.0
# 2              0               X1               19               7450.0
# 3              0               X1               19              17780.0
# 4              0               X2               16              10404.0
# ...          ...              ...              ...                  ...
# 50877          0               X3               18               7704.0
# 50878          0               X3                4               5408.0
# 50879          0               X2               12              11374.0
# 50880          0               X2               16              28179.2
# 50881          0               X3               18              11424.0
#
#        Response
# 0             0
# 1             0
# 2             1
# 3             0
# 4             0
# ...         ...
# 50877         0
# 50878         0
# 50879         0
# 50880         1
# 50881         0
#
# [50882 rows x 10 columns]

# %%
# One Hot Encoding
for column in ['City_Code', 'Health Indicator', 'Reco_Policy_Cat']:
    dummies = pd.get_dummies(df[column], prefix=column)
    df = pd.concat([df, dummies], axis=1)
    df = df.drop(column, axis=1)

# %%
df
# Out:
#        Accomodation_Type  Reco_Insurance_Type  Upper_Age  Lower_Age  \
# 0                      0                    0         36         36
# 1                      1                    1         75         22
# 2                      1                    0         32         32
# 3                      1                    1         52         48
# 4                      0                    0         44         44
# ...                  ...                  ...        ...        ...
# 50877                  0                    0         22         22
# 50878                  0                    0         27         27
# 50879                  0                    0         63         63
# 50880                  1                    1         71         49
# 50881                  0                    0         24         24
#
#        Is_Spouse  Reco_Policy_Premium  Response  City_Code_C1  City_Code_C10  \
# 0              0              11628.0         0         False          False
# 1              0              30510.0         0         False          False
# 2              0               7450.0         1         False          False
# 3              0              17780.0         0         False          False
# 4              0              10404.0         0         False          False
# ...          ...                  ...       ...           ...            ...
# 50877          0               7704.0         0         False          False
# 50878          0               5408.0         0         False          False
# 50879          0              11374.0         0          True          False
# 50880          0              28179.2         1          True          False
# 50881          0              11424.0         0         False          False
#
#        City_Code_C11  City_Code_C12  City_Code_C13  City_Code_C14  \
# 0              False          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 50877          False          False          False          False
# 50878          False          False          False          False
# 50879          False          False          False          False
# 50880          False          False          False          False
# 50881          False          False          False          False
#
#        City_Code_C15  City_Code_C16  City_Code_C17  City_Code_C18  \
# 0              False          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 50877          False          False          False          False
# 50878          False          False          False          False
# 50879          False          False          False          False
# 50880          False          False          False          False
# 50881          False          False          False          False
#
#        City_Code_C19  City_Code_C2  City_Code_C20  City_Code_C21  \
# 0              False         False          False          False
# 1              False         False          False          False
# 2              False         False          False          False
# 3              False         False          False          False
# 4              False         False          False          False
# ...              ...           ...            ...            ...
# 50877          False         False          False          False
# 50878          False         False          False          False
# 50879          False         False          False          False
# 50880          False         False          False          False
# 50881          False         False          False          False
#
#        City_Code_C22  City_Code_C23  City_Code_C24  City_Code_C25  \
# 0              False          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False           True          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 50877          False          False          False          False
# 50878          False          False          False          False
# 50879          False          False          False          False
# 50880          False          False          False          False
# 50881          False          False          False          False
#
#        City_Code_C26  City_Code_C27  City_Code_C28  City_Code_C29  \
# 0              False          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 50877          False          False          False          False
# 50878          False          False          False          False
# 50879          False          False          False          False
# 50880          False          False          False          False
# 50881          False          False          False          False
#
#        City_Code_C3  City_Code_C30  City_Code_C31  City_Code_C32  \
# 0              True          False          False          False
# 1             False          False          False          False
# 2             False          False          False          False
# 3             False          False          False          False
# 4             False          False          False          False
# ...             ...            ...            ...            ...
# 50877         False          False          False          False
# 50878         False          False          False          False
# 50879         False          False          False          False
# 50880         False          False          False          False
# 50881          True          False          False          False
#
#        City_Code_C33  City_Code_C34  City_Code_C35  City_Code_C36  \
# 0              False          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 50877          False          False          False          False
# 50878          False          False          False          False
# 50879          False          False          False          False
# 50880          False          False          False          False
# 50881          False          False          False          False
#
#        City_Code_C4  City_Code_C5  City_Code_C6  City_Code_C7  City_Code_C8  \
# 0             False         False         False         False         False
# 1             False          True         False         False         False
# 2             False          True         False         False         False
# 3             False         False         False         False         False
# 4             False         False         False         False          True
# ...             ...           ...           ...           ...           ...
# 50877          True         False         False         False         False
# 50878         False          True         False         False         False
# 50879         False         False         False         False         False
# 50880         False         False         False         False         False
# 50881         False         False         False         False         False
#
#        City_Code_C9  Health Indicator_X1  Health Indicator_X2  \
# 0             False                 True                False
# 1             False                False                 True
# 2             False                 True                False
# 3             False                 True                False
# 4             False                False                 True
# ...             ...                  ...                  ...
# 50877         False                False                False
# 50878         False                False                False
# 50879         False                False                 True
# 50880         False                False                 True
# 50881         False                False                False
#
#        Health Indicator_X3  Health Indicator_X4  Health Indicator_X5  \
# 0                    False                False                False
# 1                    False                False                False
# 2                    False                False                False
# 3                    False                False                False
# 4                    False                False                False
# ...                    ...                  ...                  ...
# 50877                 True                False                False
# 50878                 True                False                False
# 50879                False                False                False
# 50880                False                False                False
# 50881                 True                False                False
#
#        Health Indicator_X6  Health Indicator_X7  Health Indicator_X8  \
# 0                    False                False                False
# 1                    False                False                False
# 2                    False                False                False
# 3                    False                False                False
# 4                    False                False                False
# ...                    ...                  ...                  ...
# 50877                False                False                False
# 50878                False                False                False
# 50879                False                False                False
# 50880                False                False                False
# 50881                False                False                False
#
#        Health Indicator_X9  Reco_Policy_Cat_1  Reco_Policy_Cat_2  \
# 0                    False              False              False
# 1                    False              False              False
# 2                    False              False              False
# 3                    False              False              False
# 4                    False              False              False
# ...                    ...                ...                ...
# 50877                False              False              False
# 50878                False              False              False
# 50879                False              False              False
# 50880                False              False              False
# 50881                False              False              False
#
#        Reco_Policy_Cat_3  Reco_Policy_Cat_4  Reco_Policy_Cat_5  \
# 0                  False              False              False
# 1                  False              False              False
# 2                  False              False              False
# 3                  False              False              False
# 4                  False              False              False
# ...                  ...                ...                ...
# 50877              False              False              False
# 50878              False               True              False
# 50879              False              False              False
# 50880              False              False              False
# 50881              False              False              False
#
#        Reco_Policy_Cat_6  Reco_Policy_Cat_7  Reco_Policy_Cat_8  \
# 0                  False              False              False
# 1                  False              False              False
# 2                  False              False              False
# 3                  False              False              False
# 4                  False              False              False
# ...                  ...                ...                ...
# 50877              False              False              False
# 50878              False              False              False
# 50879              False              False              False
# 50880              False              False              False
# 50881              False              False              False
#
#        Reco_Policy_Cat_9  Reco_Policy_Cat_10  Reco_Policy_Cat_11  \
# 0                  False               False               False
# 1                  False               False               False
# 2                  False               False               False
# 3                  False               False               False
# 4                  False               False               False
# ...                  ...                 ...                 ...
# 50877              False               False               False
# 50878              False               False               False
# 50879              False               False               False
# 50880              False               False               False
# 50881              False               False               False
#
#        Reco_Policy_Cat_12  Reco_Policy_Cat_13  Reco_Policy_Cat_14  \
# 0                   False               False               False
# 1                   False               False               False
# 2                   False               False               False
# 3                   False               False               False
# 4                   False               False               False
# ...                   ...                 ...                 ...
# 50877               False               False               False
# 50878               False               False               False
# 50879                True               False               False
# 50880               False               False               False
# 50881               False               False               False
#
#        Reco_Policy_Cat_15  Reco_Policy_Cat_16  Reco_Policy_Cat_17  \
# 0                   False               False               False
# 1                   False               False               False
# 2                   False               False               False
# 3                   False               False               False
# 4                   False                True               False
# ...                   ...                 ...                 ...
# 50877               False               False               False
# 50878               False               False               False
# 50879               False               False               False
# 50880               False                True               False
# 50881               False               False               False
#
#        Reco_Policy_Cat_18  Reco_Policy_Cat_19  Reco_Policy_Cat_20  \
# 0                   False               False               False
# 1                   False               False               False
# 2                   False                True               False
# 3                   False                True               False
# 4                   False               False               False
# ...                   ...                 ...                 ...
# 50877                True               False               False
# 50878               False               False               False
# 50879               False               False               False
# 50880               False               False               False
# 50881                True               False               False
#
#        Reco_Policy_Cat_21  Reco_Policy_Cat_22
# 0                   False                True
# 1                   False                True
# 2                   False               False
# 3                   False               False
# 4                   False               False
# ...                   ...                 ...
# 50877               False               False
# 50878               False               False
# 50879               False               False
# 50880               False               False
# 50881               False               False
#
# [50882 rows x 74 columns]

# %%
# Split df into X and y
y = df['Response']
X = df.drop('Response', axis=1)

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=True, random_state=1)

# %%
X_train
# Out:
#        Accomodation_Type  Reco_Insurance_Type  Upper_Age  Lower_Age  \
# 47215                  0                    0         33         33
# 18464                  1                    0         60         60
# 33790                  0                    1         52         28
# 11408                  1                    0         41         41
# 14159                  1                    0         40         40
# ...                  ...                  ...        ...        ...
# 50057                  0                    0         36         36
# 32511                  1                    0         28         28
# 5192                   1                    1         67         42
# 12172                  0                    0         41         41
# 33003                  1                    0         50         50
#
#        Is_Spouse  Reco_Policy_Premium  City_Code_C1  City_Code_C10  \
# 47215          0              12480.0         False          False
# 18464          0              14352.0          True          False
# 33790          0              21846.0         False          False
# 11408          0              14674.0         False          False
# 14159          0              13772.0         False          False
# ...          ...                  ...           ...            ...
# 50057          0               7680.0         False          False
# 32511          0               7404.0         False          False
# 5192           0              26544.0          True          False
# 12172          0              13740.0         False          False
# 33003          0              12780.0         False          False
#
#        City_Code_C11  City_Code_C12  City_Code_C13  City_Code_C14  \
# 47215          False          False          False          False
# 18464          False          False          False          False
# 33790          False          False          False          False
# 11408          False          False          False          False
# 14159          False          False          False          False
# ...              ...            ...            ...            ...
# 50057          False          False          False          False
# 32511          False          False          False          False
# 5192           False          False          False          False
# 12172          False          False          False          False
# 33003          False          False          False          False
#
#        City_Code_C15  City_Code_C16  City_Code_C17  City_Code_C18  \
# 47215          False          False          False          False
# 18464          False          False          False          False
# 33790          False          False          False          False
# 11408          False          False           True          False
# 14159          False          False          False          False
# ...              ...            ...            ...            ...
# 50057          False          False          False          False
# 32511          False          False          False          False
# 5192           False          False          False          False
# 12172          False          False          False          False
# 33003          False          False          False          False
#
#        City_Code_C19  City_Code_C2  City_Code_C20  City_Code_C21  \
# 47215          False         False          False          False
# 18464          False         False          False          False
# 33790          False         False          False          False
# 11408          False         False          False          False
# 14159          False         False          False          False
# ...              ...           ...            ...            ...
# 50057           True         False          False          False
# 32511          False         False          False          False
# 5192           False         False          False          False
# 12172          False         False          False          False
# 33003          False          True          False          False
#
#        City_Code_C22  City_Code_C23  City_Code_C24  City_Code_C25  \
# 47215          False          False          False          False
# 18464          False          False          False          False
# 33790          False          False           True          False
# 11408          False          False          False          False
# 14159          False          False          False          False
# ...              ...            ...            ...            ...
# 50057          False          False          False          False
# 32511          False          False          False          False
# 5192           False          False          False          False
# 12172          False          False          False          False
# 33003          False          False          False          False
#
#        City_Code_C26  City_Code_C27  City_Code_C28  City_Code_C29  \
# 47215          False          False          False          False
# 18464          False          False          False          False
# 33790          False          False          False          False
# 11408          False          False          False          False
# 14159          False          False          False          False
# ...              ...            ...            ...            ...
# 50057          False          False          False          False
# 32511          False          False          False          False
# 5192           False          False          False          False
# 12172          False          False          False          False
# 33003          False          False          False          False
#
#        City_Code_C3  City_Code_C30  City_Code_C31  City_Code_C32  \
# 47215          True          False          False          False
# 18464         False          False          False          False
# 33790         False          False          False          False
# 11408         False          False          False          False
# 14159          True          False          False          False
# ...             ...            ...            ...            ...
# 50057         False          False          False          False
# 32511         False          False          False          False
# 5192          False          False          False          False
# 12172          True          False          False          False
# 33003         False          False          False          False
#
#        City_Code_C33  City_Code_C34  City_Code_C35  City_Code_C36  \
# 47215          False          False          False          False
# 18464          False          False          False          False
# 33790          False          False          False          False
# 11408          False          False          False          False
# 14159          False          False          False          False
# ...              ...            ...            ...            ...
# 50057          False          False          False          False
# 32511          False          False          False          False
# 5192           False          False          False          False
# 12172          False          False          False          False
# 33003          False          False          False          False
#
#        City_Code_C4  City_Code_C5  City_Code_C6  City_Code_C7  City_Code_C8  \
# 47215         False         False         False         False         False
# 18464         False         False         False         False         False
# 33790         False         False         False         False         False
# 11408         False         False         False         False         False
# 14159         False         False         False         False         False
# ...             ...           ...           ...           ...           ...
# 50057         False         False         False         False         False
# 32511         False         False         False         False         False
# 5192          False         False         False         False         False
# 12172         False         False         False         False         False
# 33003         False         False         False         False         False
#
#        City_Code_C9  Health Indicator_X1  Health Indicator_X2  \
# 47215         False                False                 True
# 18464         False                False                False
# 33790         False                False                False
# 11408         False                False                 True
# 14159         False                 True                False
# ...             ...                  ...                  ...
# 50057         False                 True                False
# 32511          True                False                False
# 5192          False                 True                False
# 12172         False                 True                False
# 33003         False                 True                False
#
#        Health Indicator_X3  Health Indicator_X4  Health Indicator_X5  \
# 47215                False                False                False
# 18464                False                False                False
# 33790                False                False                 True
# 11408                False                False                False
# 14159                False                False                False
# ...                    ...                  ...                  ...
# 50057                False                False                False
# 32511                 True                False                False
# 5192                 False                False                False
# 12172                False                False                False
# 33003                False                False                False
#
#        Health Indicator_X6  Health Indicator_X7  Health Indicator_X8  \
# 47215                False                False                False
# 18464                 True                False                False
# 33790                False                False                False
# 11408                False                False                False
# 14159                False                False                False
# ...                    ...                  ...                  ...
# 50057                False                False                False
# 32511                False                False                False
# 5192                 False                False                False
# 12172                False                False                False
# 33003                False                False                False
#
#        Health Indicator_X9  Reco_Policy_Cat_1  Reco_Policy_Cat_2  \
# 47215                False              False              False
# 18464                False              False              False
# 33790                False              False              False
# 11408                False              False              False
# 14159                False              False              False
# ...                    ...                ...                ...
# 50057                False              False              False
# 32511                False              False              False
# 5192                 False              False              False
# 12172                False              False              False
# 33003                False              False              False
#
#        Reco_Policy_Cat_3  Reco_Policy_Cat_4  Reco_Policy_Cat_5  \
# 47215              False              False              False
# 18464              False              False              False
# 33790              False              False              False
# 11408              False              False              False
# 14159              False              False              False
# ...                  ...                ...                ...
# 50057              False              False              False
# 32511              False              False              False
# 5192               False              False              False
# 12172              False              False              False
# 33003              False              False              False
#
#        Reco_Policy_Cat_6  Reco_Policy_Cat_7  Reco_Policy_Cat_8  \
# 47215              False              False              False
# 18464              False              False              False
# 33790              False              False              False
# 11408              False              False              False
# 14159              False              False              False
# ...                  ...                ...                ...
# 50057              False              False              False
# 32511              False              False              False
# 5192               False              False              False
# 12172              False              False              False
# 33003              False              False              False
#
#        Reco_Policy_Cat_9  Reco_Policy_Cat_10  Reco_Policy_Cat_11  \
# 47215              False               False               False
# 18464              False               False               False
# 33790              False               False               False
# 11408              False               False               False
# 14159              False               False               False
# ...                  ...                 ...                 ...
# 50057              False               False               False
# 32511              False               False               False
# 5192               False               False               False
# 12172              False               False               False
# 33003              False               False               False
#
#        Reco_Policy_Cat_12  Reco_Policy_Cat_13  Reco_Policy_Cat_14  \
# 47215               False               False               False
# 18464               False               False               False
# 33790               False               False               False
# 11408               False               False               False
# 14159               False               False               False
# ...                   ...                 ...                 ...
# 50057               False               False               False
# 32511               False               False               False
# 5192                False               False               False
# 12172               False               False               False
# 33003               False               False               False
#
#        Reco_Policy_Cat_15  Reco_Policy_Cat_16  Reco_Policy_Cat_17  \
# 47215               False               False               False
# 18464               False                True               False
# 33790               False               False               False
# 11408               False               False               False
# 14159               False               False                True
# ...                   ...                 ...                 ...
# 50057               False                True               False
# 32511               False               False               False
# 5192                False                True               False
# 12172               False               False               False
# 33003               False               False                True
#
#        Reco_Policy_Cat_18  Reco_Policy_Cat_19  Reco_Policy_Cat_20  \
# 47215               False               False                True
# 18464               False               False               False
# 33790               False               False                True
# 11408               False               False                True
# 14159               False               False               False
# ...                   ...                 ...                 ...
# 50057               False               False               False
# 32511               False               False               False
# 5192                False               False               False
# 12172                True               False               False
# 33003               False               False               False
#
#        Reco_Policy_Cat_21  Reco_Policy_Cat_22
# 47215               False               False
# 18464               False               False
# 33790               False               False
# 11408               False               False
# 14159               False               False
# ...                   ...                 ...
# 50057               False               False
# 32511               False                True
# 5192                False               False
# 12172               False               False
# 33003               False               False
#
# [35617 rows x 73 columns]

# %%
y_train.value_counts()
# Out:
# Response
# 0    27121
# 1     8496
# Name: count, dtype: int64

# %%
# Scale X
scaler = StandardScaler()
scaler.fit(X_train)
X_train = pd.DataFrame(scaler.transform(X_train), index=X_train.index, columns=X_train.columns)
X_test = pd.DataFrame(scaler.transform(X_test), index=X_test.index, columns=X_test.columns)

# %% [markdown]
# ### Training

# %%
model = LogisticRegression(
    class_weight = {
        0: 1.0,
        1: 2.5
    }
)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight={0: 1.0, 1: 2.5})

# %% [markdown]
# ### Results

# %%
acc = model.score(X_test, y_test)
y_pred = model.predict(X_test)

print("Test Accuracy: {:.2f}%".format(acc*100))

cm = confusion_matrix(y_test, y_pred, labels=[0, 1])
clr = classification_report(y_test, y_pred, labels=[0,1], target_names=['Negative', 'Positive'])

plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False)
plt.xticks(ticks=[0.5, 1.5], labels=["Negative", "Positive"])
plt.yticks(ticks=[0.5, 1.5], labels=["Negative", "Positive"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

print("Classification Report:\n--------------------------\n", clr)
# Out:
# Test Accuracy: 66.58%
# Classification Report:
# --------------------------
#                precision    recall  f1-score   support
#
#     Negative       0.80      0.75      0.77     11552
#     Positive       0.34      0.40      0.37      3713
#
#     accuracy                           0.67     15265
#    macro avg       0.57      0.58      0.57     15265
# weighted avg       0.69      0.67      0.67     15265
