# %% [markdown]
# ## Wild Blueberry Yield Prediction (hyperparamater Optimization)
#
# Given data about *wild blueberries*, let's try to predict the *yield* for a given record.
#
# We will use a random forest regression model to make our predictions.
#
# Data source: https://www.kaggle.com/datasets/shashwatwork/wild-blueberry-yield-prediction-dataset

# %% [markdown]
# ### Getting Started

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.ensemble import RandomForestRegressor

# %%
data = pd.read_csv('WildBlueberryPollinationSimulationData.csv')
data
# Out:
#      Row#  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0       0       37.5     0.750    0.250    0.250  0.250              86.0
# 1       1       37.5     0.750    0.250    0.250  0.250              86.0
# 2       2       37.5     0.750    0.250    0.250  0.250              94.6
# 3       3       37.5     0.750    0.250    0.250  0.250              94.6
# 4       4       37.5     0.750    0.250    0.250  0.250              86.0
# ..    ...        ...       ...      ...      ...    ...               ...
# 772   772       10.0     0.537    0.117    0.409  0.058              86.0
# 773   773       40.0     0.537    0.117    0.409  0.058              86.0
# 774   774       20.0     0.537    0.117    0.409  0.058              86.0
# 775   775       20.0     0.537    0.117    0.409  0.058              89.0
# 776   776       20.0     0.537    0.117    0.409  0.058              89.0
#
#      MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  \
# 0                52.0                  71.9              62.0
# 1                52.0                  71.9              62.0
# 2                57.2                  79.0              68.2
# 3                57.2                  79.0              68.2
# 4                52.0                  71.9              62.0
# ..                ...                   ...               ...
# 772              52.0                  71.9              62.0
# 773              52.0                  71.9              62.0
# 774              52.0                  71.9              62.0
# 775              39.0                  65.6              66.0
# 776              39.0                  65.6              66.0
#
#      MinOfLowerTRange  AverageOfLowerTRange  RainingDays  AverageRainingDays  \
# 0                30.0                  50.8        16.00                0.26
# 1                30.0                  50.8         1.00                0.10
# 2                33.0                  55.9        16.00                0.26
# 3                33.0                  55.9         1.00                0.10
# 4                30.0                  50.8        24.00                0.39
# ..                ...                   ...          ...                 ...
# 772              30.0                  50.8         3.77                0.06
# 773              30.0                  50.8         3.77                0.06
# 774              30.0                  50.8        24.00                0.39
# 775              28.0                  45.3         3.77                0.06
# 776              28.0                  45.3        24.00                0.39
#
#      fruitset  fruitmass      seeds        yield
# 0    0.410652   0.408159  31.678898  3813.165795
# 1    0.444254   0.425458  33.449385  4947.605663
# 2    0.383787   0.399172  30.546306  3866.798965
# 3    0.407564   0.408789  31.562586  4303.943030
# 4    0.354413   0.382703  28.873714  3436.493543
# ..        ...        ...        ...          ...
# 772  0.486815   0.428012  33.447471  5333.873335
# 773  0.342841   0.377915  28.462005  3373.436842
# 774  0.404617   0.401670  30.748240  4203.027624
# 775  0.401538   0.399935  30.582161  4166.299735
# 776  0.384646   0.392303  29.742583  3943.131681
#
# [777 rows x 18 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row#                  777 non-null    int64
#  1   clonesize             777 non-null    float64
#  2   honeybee              777 non-null    float64
#  3   bumbles               777 non-null    float64
#  4   andrena               777 non-null    float64
#  5   osmia                 777 non-null    float64
#  6   MaxOfUpperTRange      777 non-null    float64
#  7   MinOfUpperTRange      777 non-null    float64
#  8   AverageOfUpperTRange  777 non-null    float64
#  9   MaxOfLowerTRange      777 non-null    float64
#  10  MinOfLowerTRange      777 non-null    float64
#  11  AverageOfLowerTRange  777 non-null    float64
#  12  RainingDays           777 non-null    float64
#  13  AverageRainingDays    777 non-null    float64
#  14  fruitset              777 non-null    float64
#  15  fruitmass             777 non-null    float64
#  16  seeds                 777 non-null    float64
#  17  yield                 777 non-null    float64
# dtypes: float64(17), int64(1)
# memory usage: 109.4 KB

# %% [markdown]
# ### Preprocessing

# %%
def preprocess_inputs(df):
    df = df.copy()

    # Drop row# column
    df = df.drop('Row#', axis=1)

    # Split df into X and y
    y = df['yield']
    X = df.drop('yield', axis=1)

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=True, random_state=1)
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = preprocess_inputs(data)
X_train
# Out:
#      clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 214       12.5      0.25    0.250     0.50   0.50              94.6
# 88        12.5      0.25    0.250     0.25   0.50              86.0
# 479       25.0      0.50    0.250     0.38   0.63              94.6
# 602       25.0      0.50    0.250     0.75   0.50              86.0
# 147       12.5      0.25    0.250     0.38   0.38              86.0
# ..         ...       ...      ...      ...    ...               ...
# 715       25.0      0.50    0.380     0.50   0.63              94.6
# 767       20.0      0.00    0.585     0.00   0.00              86.0
# 72        12.5      0.25    0.250     0.25   0.38              86.0
# 235       12.5      0.25    0.250     0.50   0.63              77.4
# 37        25.0      0.25    0.250     0.25   0.25              77.4
#
#      MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  \
# 214              57.2                  79.0              68.2
# 88               52.0                  71.9              62.0
# 479              57.2                  79.0              68.2
# 602              52.0                  71.9              62.0
# 147              52.0                  71.9              62.0
# ..                ...                   ...               ...
# 715              57.2                  79.0              68.2
# 767              52.0                  71.9              62.0
# 72               52.0                  71.9              62.0
# 235              46.8                  64.7              55.8
# 37               46.8                  64.7              55.8
#
#      MinOfLowerTRange  AverageOfLowerTRange  RainingDays  AverageRainingDays  \
# 214              33.0                  55.9         1.00                0.10
# 88               30.0                  50.8        34.00                0.56
# 479              33.0                  55.9        24.00                0.39
# 602              30.0                  50.8         1.00                0.10
# 147              30.0                  50.8        16.00                0.26
# ..                ...                   ...          ...                 ...
# 715              33.0                  55.9        16.00                0.26
# 767              30.0                  50.8         3.77                0.06
# 72               30.0                  50.8        34.00                0.56
# 235              27.0                  45.8        16.00                0.26
# 37               27.0                  45.8        24.00                0.39
#
#      fruitset  fruitmass      seeds
# 214  0.582954   0.488176  40.559770
# 88   0.435969   0.419720  32.815794
# 479  0.364565   0.391617  29.908518
# 602  0.523846   0.460305  37.277297
# 147  0.553730   0.471250  38.534569
# ..        ...        ...        ...
# 715  0.527592   0.464639  37.782288
# 767  0.599984   0.529791  46.585105
# 72   0.416271   0.409438  31.577558
# 235  0.589306   0.488616  40.546480
# 37   0.426065   0.420188  32.849238
#
# [543 rows x 16 columns]

# %%
X_train.describe()
# Out:
#         clonesize    honeybee     bumbles     andrena       osmia  \
# count  543.000000  543.000000  543.000000  543.000000  543.000000
# mean    18.775322    0.389118    0.283116    0.476162    0.559987
# std      6.922487    0.787501    0.063583    0.160474    0.162965
# min     12.500000    0.000000    0.000000    0.000000    0.000000
# 25%     12.500000    0.250000    0.250000    0.380000    0.500000
# 50%     12.500000    0.250000    0.250000    0.500000    0.630000
# 75%     25.000000    0.500000    0.380000    0.630000    0.630000
# max     40.000000   18.430000    0.585000    0.750000    0.750000
#
#        MaxOfUpperTRange  MinOfUpperTRange  AverageOfUpperTRange  \
# count        543.000000        543.000000            543.000000
# mean          82.078637         49.563720             68.547514
# std            9.197620          5.606868              7.678822
# min           69.700000         39.000000             58.200000
# 25%           77.400000         46.800000             64.700000
# 50%           86.000000         52.000000             71.900000
# 75%           86.000000         52.000000             71.900000
# max           94.600000         57.200000             79.000000
#
#        MaxOfLowerTRange  MinOfLowerTRange  AverageOfLowerTRange  RainingDays  \
# count        543.000000        543.000000            543.000000   543.000000
# mean          59.167956         28.617495             48.487845    18.121418
# std            6.652775          3.209863              5.418443    12.188437
# min           50.200000         24.300000             41.200000     1.000000
# 25%           55.800000         27.000000             45.800000     1.000000
# 50%           62.000000         30.000000             50.800000    16.000000
# 75%           62.000000         30.000000             50.800000    24.000000
# max           68.200000         33.000000             55.900000    34.000000
#
#        AverageRainingDays    fruitset   fruitmass       seeds
# count          543.000000  543.000000  543.000000  543.000000
# mean             0.317827    0.503151    0.446645   36.201995
# std              0.171467    0.078537    0.039988    4.319438
# min              0.060000    0.192732    0.311921   22.079199
# 25%              0.100000    0.458556    0.417076   33.225444
# 50%              0.260000    0.508992    0.446576   36.250838
# 75%              0.390000    0.562291    0.476229   39.285339
# max              0.560000    0.645641    0.532772   46.585105

# %%
y_train
# Out:
# 214    7243.226111
# 88     4684.893205
# 479    3723.523376
# 602    6521.291119
# 147    6683.200614
#           ...
# 715    6327.477365
# 767    7575.801245
# 72     4350.424670
# 235    7560.205645
# 37     4356.945873
# Name: yield, Length: 543, dtype: float64

# %% [markdown]
# ### Training

# %%
model = RandomForestRegressor(random_state=1)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([8347.89770723, 5617.43353994, 6040.91770472, 4173.93171129,
#        8473.76616715, 7234.76702628, 6225.91778631, 6859.34549124,
#        6637.02444783, 6580.87958142, 5669.79024112, 5777.39852827,
#        4465.31845819, 7805.50049886, 6675.22715612, 5921.94715828,
#        4530.86721559, 7435.78687431, 7823.00351099, 5233.51084744,
#        6296.30291283, 3738.70103395, 7624.08015921, 5626.33850482,
#        5209.72012965, 5977.9733837 , 3630.90959874, 4334.47925919,
#        5753.88279328, 4614.79823169, 6710.7406748 , 3790.68113273,
#        5144.07202304, 8407.99085595, 7423.64841492, 6837.64713186,
#        6755.38550009, 5670.1757635 , 5379.44014731, 8732.92815879,
#        8170.96906526, 6758.20597224, 2611.7916052 , 5807.17117923,
#        7103.17276231, 5410.07050787, 4690.53921909, 5777.89016355,
#        4335.91768002, 5830.45196381, 5043.65935806, 7566.67442886,
#        7822.88966909, 7255.44162752, 3539.58488246, 6306.49081446,
#        4780.87702349, 5272.44565973, 5129.63675496, 6462.19274094,
#        4105.96188047, 5474.44985035, 7168.7289933 , 7281.7082198 ,
#        7137.62703533, 2736.03161888, 7182.16954735, 5881.83195428,
#        4851.87158653, 7765.11149765, 6693.88215409, 3968.29746443,
#        7559.47337843, 4905.10859643, 7155.2552564 , 4909.81113744,
#        3931.04479329, 6225.551205  , 6004.54389571, 5928.59432482,
#        6345.60444218, 6552.9695638 , 6647.13012344, 3721.19093236,
#        3472.45173948, 5314.30475747, 6741.18921214, 6680.04797891,
#        6228.02700752, 6473.96426068, 6048.7057627 , 6468.02611086,
#        4763.57013742, 6106.82149951, 4653.59860308, 5122.51833418,
#        8151.51871754, 7233.23144882, 6127.07832193, 7345.99960452,
#        6546.4939989 , 7196.95703203, 3288.42793381, 7410.08890628,
#        6463.9531102 , 6905.58449538, 4943.84723174, 5979.0456697 ,
#        3703.31656125, 6441.48383674, 4052.53825385, 6755.74081927,
#        4314.52469907, 5631.72201132, 5993.04102585, 7996.59334947,
#        7554.18554716, 5652.2691996 , 7422.33746286, 6086.38602176,
#        8486.86060857, 5199.68212637, 6736.95050587, 4374.71770848,
#        3801.07541713, 6470.49872125, 6380.49593125, 5621.78517505,
#        5142.0898915 , 8346.25491038, 8191.24859464, 7394.68787672,
#        6417.91061433, 5206.23954018, 4960.92024636, 4314.50284135,
#        6337.09489936, 5454.65693652, 5594.49170561, 5929.73208947,
#        5775.03325154, 3458.72325358, 8195.25184672, 4252.86280474,
#        8694.02247464, 4418.00728341, 6704.56957211, 3373.63217065,
#        5820.47827351, 4286.36969322, 7187.58440714, 7475.29258447,
#        7421.12227902, 4439.6397203 , 6428.79767723, 7499.18885442,
#        4105.73898349, 5413.06437015, 7879.17190633, 7394.40146096,
#        6271.99155878, 3717.08023476, 5254.57051606, 6701.70714396,
#        6270.42005801, 6825.69473396, 7861.10927134, 6924.54224167,
#        4963.84611027, 6320.85131546, 5975.36274813, 5403.30332141,
#        5558.96138946, 5391.43311646, 5426.94914543, 6738.1625643 ,
#        3488.75541581, 7533.08938643, 8481.69209159, 4929.72640611,
#        7158.89833316, 4166.9246541 , 4895.91480608, 3352.97195922,
#        2960.40194876, 7394.03663901, 7603.91460509, 8158.14595491,
#        6475.6025077 , 6901.10042278, 6576.31438851, 4024.98534054,
#        5485.12598987, 7811.60329196, 5169.11607136, 7805.91809722,
#        6576.68110012, 6254.69150937, 6034.69318312, 5005.12455355,
#        5398.13305616, 6211.79676097, 3631.80350241, 5977.82021108,
#        6916.71332177, 3987.31766744, 3902.91074994, 4667.57149924,
#        6731.76542949, 4735.68304941, 7423.73123181, 5475.63912977,
#        5792.03995637, 7561.04849135, 2633.52343075, 7380.22772285,
#        7841.08250591, 5817.84802489, 6467.17992105, 6486.05794569,
#        6848.20373058, 5097.60128943, 5519.27722278, 4987.58139076,
#        7470.90869798, 3405.31400858, 6051.60161031, 6166.04370225,
#        6871.83395188, 7485.62928257, 8478.17529801, 6639.61535849,
#        3367.72229024, 4191.20450196])

# %%
# Error
rmse = np.sqrt(np.mean((y_test - y_pred)**2))
r2 = 1 - (np.sum((y_test - y_pred)**2) / np.sum((y_test - y_test.mean())**2))
print("     RMSE: {:.2f}".format(rmse))
print("R^2 Score: {:.5f}".format(r2))
# Out:
#      RMSE: 186.23
# R^2 Score: 0.98244

# %% [markdown]
# #### Hyperparameter optimization

# %%
params = {
    'n_estimators': [50, 100, 150, 200],
    'max_depth': [2, 4, 6, 8, 10]
}

model = GridSearchCV(RandomForestRegressor(random_state=1), params)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

rmse = np.sqrt(np.mean((y_test - y_pred)**2))
r2 = 1 - (np.sum((y_test - y_pred)**2) / np.sum((y_test - y_test.mean())**2))
print("     RMSE: {:.2f}".format(rmse))
print("R^2 Score: {:.5f}".format(r2))
# Out:
#      RMSE: 185.37
# R^2 Score: 0.98260

# %%
model.best_params_
# Out:
# {'max_depth': 10, 'n_estimators': 200}
